# %%
# %matplotlib inline 
import matplotlib
import matplotlib.pyplot as plt


import time
import heatmap_setup as hm
import numpy as np


from SES_setup import *
from utils import *
from style import *
colourWheel =['#329932',
            '#ff6961',
            'b',
            '#6a3d9a',
            '#fb9a99',
            '#e31a1c',
            '#fdbf6f',
            '#ff7f00',
            '#cab2d6',
            '#6a3d9a',
            '#ffff99',
            '#b15928',
            '#67001f',
            '#b2182b',
            '#d6604d',
            '#f4a582',
            '#fddbc7',
            '#f7f7f7',
            '#d1e5f0',
            '#92c5de',
            '#4393c3',
            '#2166ac',
            '#053061'][::-1]
plt.rcParams['axes.labelsize'] = 25
plt.rcParams['legend.fontsize'] = 'large'

def steadystate_observable(ss_array, PARAMS, observable):
    ss_obs_array = np.zeros(shape=ss_array.shape)
    for y, ss_row in enumerate(ss_array):
        for x, ss_dm in enumerate(ss_row):
            dim, size = ss_dm.dims[0][1::], int(ss_dm.shape[0]/PARAMS['sys_dim'])
            
            nstates, state2idx, idx2state = qt.enr_state_dictionaries(dim, dim[0]+0)
            exc_diff = 0 # function finds the correct exc_diff given some dm
            while nstates != size:
                nstates, state2idx, idx2state = qt.enr_state_dictionaries(dim, dim[0]+exc_diff)
            
            #print exc_diff, dim[0]+exc_diff
            PARAMS.update({'N_1':dim[0], 'N_2':dim[1], 'exc':dim[0]+exc_diff})
            obs_op = make_expectation_operators(PARAMS)[observable]
            #print obs_op.shape, ss_dm.shape
            ss_obs_array[y][x] = (obs_op*ss_dm).tr().real #info_test[y][x]['solution_time']
    return ss_obs_array

# With saved data, we can calculte things differently

def heatmap_loader(num, dir_name="heatmap"):
    # Only loads data of heatmap into memory, does not plot
    directory = 'DATA/'+dir_name+'_'+str(num)
    ss_array = load_obj(directory+'/ss_array')
    PARAMS = load_obj(directory+'/PARAMS')
    info_array = load_obj(directory+'/info_array') # reverse ordering -> lower_N-higher_N
    return ss_array, PARAMS, info_array


def heatmap_plotter(num=-1, plot_SD=True, dir_name="heatmap", 
                     print_params=False, observable='sigma_x', ylim=False):
    
    # If ss_info_params list is provided, then makes heatmap from memory not disk
    
    if num>=0:
        ss_array, PARAMS, info_array = heatmap_loader(num, dir_name=dir_name)
        ss_array_add, PARAMS, info_array_add = heatmap_loader(num, dir_name=dir_name+'_add')
        data = {'non-add.': [ss_array,'solid'], 'add.': [ss_array_add, 'dashed']}
    info = info_array[0][0]
    try:
        # To catch an old bug where these were in "info" not in PARAMS
        keys = ['x_values', 'y_values', 'y_axis_parameters', 'x_axis_parameters']
        PARAMS.update(dict((key, info[key]) for key in keys))
    except Exception as err:
        print "plotting in new style"
    #print info
    
    if plot_SD:
        plot_UD_SD(PARAMS["Gamma_1"], PARAMS["alpha_1"], PARAMS["w0_1"], eps=8000.)
    eta = np.sqrt(PARAMS['bias']**2 + 4*PARAMS['V']**2)
    f, axes = plt.subplots(1,1, figsize=(13,6))
    for key in data.keys():
        if observable=='DS/GS':
            ss_arrayGS = steadystate_observable(data[key][0], PARAMS, 'OO')
            ss_arrayDS = steadystate_observable(data[key][0], PARAMS, 'dark')
            ss_arrayBS = steadystate_observable(data[key][0], PARAMS, 'bright')
            ss_array = (ss_arrayDS+ss_arrayBS)/ss_arrayGS
        else:
            ss_array = steadystate_observable(data[key][0], PARAMS, observable)
        
        ylab = ' = '.join(["$"+l+"$" for l in PARAMS['y_axis_parameters']])
        for i, y_val in enumerate(PARAMS['y_values']):
            x_values = PARAMS['x_values']

            lbl = ylab+"="+"{:0.1f}".format(y_val)
            if key == 'add.':
                lbl = None
            axes.plot(x_values, ss_array[i], label=lbl, 
                      linestyle=data[key][1], color=colourWheel[i*8])
            
        if print_params:
            print_PARAMS(PARAMS)
        labs = ("$\\"+l+"$" for l in PARAMS['x_axis_parameters'])
        xlab = ' , '.join(labs)
        
        plt.xlabel(xlab+" (cm$^{-1}$)")
        #plt.xlabel(', '.join(PARAMS['x_axis_parameters']))
        try:
            plt.ylabel(r"Steadystate "+make_expectation_labels()[observable])
        except:
            plt.ylabel(r"Steadystate "+observable)
    #plt.ylabel(', '.join(info['y_axis_parameters']))
    plt.legend()
    #plt.grid()
    plt.xlim(x_values[0], x_values[-1])
    if ylim:
        plt.ylim(ylim[0], ylim[-1])
    plot_filename = 'PLOTS/'+dir_name+'_'+observable+'_'+str(num)+'.pdf'
    plt.savefig(plot_filename,bbox_inches='tight')
    plt.show()
    print "saved at {}".format(plot_filename)

# Example of loading data to memory
"""ss_info_params = [ss_array, info_array, PARAMS]

heatmap_plotter(ss_info_params=ss_info_params, plot_SD=False,
                print_params=False, observable='sigma_x')
heatmap_plotter(num=5, plot_SD=False, dir_name="heatmap_excvN",
                print_params=False, observable='sigma_x')"""
# Out:
# SES_setup loaded globally
# 'ss_info_params = [ss_array, info_array, PARAMS]\n\nheatmap_plotter(ss_info_params=ss_info_params, plot_SD=False,\n                print_params=False, observable=\'sigma_x\')\nheatmap_plotter(num=5, plot_SD=False, dir_name="heatmap_excvN",\n                print_params=False, observable=\'sigma_x\')'

# %% [markdown]
# First things first, we look at heterodimers. Low-T and high-T on separate plots, to see whether additivity is pronounced or not. Then explore a higher RC frequency.

# %%
reload(hm)
w_2 = 1.4*ev_to_inv_cm
bias=0.01*ev_to_inv_cm
V=0.01*ev_to_inv_cm
alpha = 200./pi
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =4
wc = 100.
w_0 = 200.
site_basis = True
Gamma = (w_0**2)/wc
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=2*N)

dirname = 'heatmap_hetero'


x_values = np.linspace(0.5,V, 30)

y_values = [77, 100] #np.linspace(77,300, 2)

"""

ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname, save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.1, conv_obs='bright')
"""

# %%
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname+'_add', save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.1, conv_obs='bright', additive=True)

# %%
dirname = 'heatmap_hetero'
num=1
heatmap_plotter(num=num, plot_SD=True, dir_name=dirname,
                print_params=False, observable='bright')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='dark')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='sigma_z')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='sigma_x')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='eig_x')

# %%
dirname = 'heatmap_hetero'

# %%
reload(hm)
w_2 = 1.4*ev_to_inv_cm
bias=0.01*ev_to_inv_cm
V=0.01*ev_to_inv_cm
alpha = 200./pi
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =4
wc = 100.
w_0 = 400.
site_basis = True
Gamma = 400.
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=2*N)



x_values = np.linspace(0.5,100, 50)

y_values = [200.,600] #np.linspace(77,300, 2)

ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['w0_1', 'w0_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname, save_data=True,
                            persistent=False, method='direct', threshold=0, 
                                              conv_percent_tol=0.05, 
                                              conv_obs='OO', N_min=5)

ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['w0_1', 'w0_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname+'_add', save_data=True,
                            persistent=False, method='direct', threshold=0, 
                                              conv_percent_tol=0.05, conv_obs='OO', 
                                              additive=True, N_min=5)
# Out:
# alpha_1=0.50, w_1=11372.35, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, exc=12.00, alpha_EM=0.01, sys_dim=3.00, N_1=4.00, N_2=4.00, mu=0.99, alpha_2=0.50, w_2=11291.70, w_xx=22664.06
# None
# Steady state for 5 took 0.481 seconds with direct, OO changed by 61.4415%
# calculation converged - 0.5, 200.0 (1/100)
# alpha_1=2.53, w_1=11372.35, kappa_1=12.53, kappa_2=12.53, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=0.79, exc=5.00, shift_1=0.79, alpha_EM=0.01, sys_dim=3.00, N_1=5.00, N_2=5.00, mu=0.99, alpha_2=2.53, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.490 seconds with direct, OO changed by 168.5481%
# Steady state for 6 took 3.143 seconds with direct, OO changed by 0.0021%
# calculation converged - 2.5, 200.0 (2/100)
# alpha_1=4.56, w_1=11372.35, kappa_1=28.20, kappa_2=28.20, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=3.98, exc=6.00, shift_1=3.98, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=4.56, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.539 seconds with direct, OO changed by 232.7170%
# Steady state for 6 took 2.671 seconds with direct, OO changed by 0.0036%
# calculation converged - 4.6, 200.0 (3/100)
# alpha_1=6.59, w_1=11372.35, kappa_1=37.85, kappa_2=37.85, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=7.16, exc=6.00, shift_1=7.16, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=6.59, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.500 seconds with direct, OO changed by 0.6691%
# Steady state for 6 took 2.853 seconds with direct, OO changed by 0.0051%
# calculation converged - 6.6, 200.0 (4/100)
# alpha_1=8.62, w_1=11372.35, kappa_1=45.51, kappa_2=45.51, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=10.35, exc=6.00, shift_1=10.35, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=8.62, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.514 seconds with direct, OO changed by 97.8476%
# Steady state for 6 took 2.685 seconds with direct, OO changed by 0.0067%
# calculation converged - 8.6, 200.0 (5/100)
# alpha_1=10.65, w_1=11372.35, kappa_1=52.05, kappa_2=52.05, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=13.54, exc=6.00, shift_1=13.54, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=10.65, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.494 seconds with direct, OO changed by 9.7050%
# Steady state for 6 took 2.590 seconds with direct, OO changed by 0.0082%
# calculation converged - 10.7, 200.0 (6/100)
# alpha_1=12.68, w_1=11372.35, kappa_1=57.85, kappa_2=57.85, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=16.73, exc=6.00, shift_1=16.73, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=12.68, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.504 seconds with direct, OO changed by 1.2917%
# Steady state for 6 took 2.943 seconds with direct, OO changed by 0.0098%
# calculation converged - 12.7, 200.0 (7/100)
# alpha_1=14.71, w_1=11372.35, kappa_1=63.12, kappa_2=63.12, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=19.92, exc=6.00, shift_1=19.92, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=14.71, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.504 seconds with direct, OO changed by 1.6792%
# Steady state for 6 took 2.723 seconds with direct, OO changed by 0.0113%
# calculation converged - 14.7, 200.0 (8/100)
# alpha_1=16.74, w_1=11372.35, kappa_1=67.99, kappa_2=67.99, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=23.11, exc=6.00, shift_1=23.11, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=16.74, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.497 seconds with direct, OO changed by 13.5065%
# Steady state for 6 took 2.711 seconds with direct, OO changed by 0.0129%
# calculation converged - 16.7, 200.0 (9/100)
# alpha_1=18.78, w_1=11372.35, kappa_1=72.53, kappa_2=72.53, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=26.30, exc=6.00, shift_1=26.30, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=18.78, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.541 seconds with direct, OO changed by 373.2543%
# Steady state for 6 took 2.345 seconds with direct, OO changed by 0.0144%
# calculation converged - 18.8, 200.0 (10/100)
# alpha_1=20.81, w_1=11372.35, kappa_1=76.80, kappa_2=76.80, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=29.49, exc=6.00, shift_1=29.49, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=20.81, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.521 seconds with direct, OO changed by 204.4749%
# Steady state for 6 took 2.514 seconds with direct, OO changed by 0.0160%
# calculation converged - 20.8, 200.0 (11/100)
# alpha_1=22.84, w_1=11372.35, kappa_1=80.85, kappa_2=80.85, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=32.68, exc=6.00, shift_1=32.68, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=22.84, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.483 seconds with direct, OO changed by 209.8716%
# Steady state for 6 took 2.921 seconds with direct, OO changed by 0.0175%
# calculation converged - 22.8, 200.0 (12/100)
# alpha_1=24.87, w_1=11372.35, kappa_1=84.70, kappa_2=84.70, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=35.87, exc=6.00, shift_1=35.87, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=24.87, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.494 seconds with direct, OO changed by 9.6626%
# Steady state for 6 took 2.625 seconds with direct, OO changed by 0.0190%
# calculation converged - 24.9, 200.0 (13/100)
# alpha_1=26.90, w_1=11372.35, kappa_1=88.39, kappa_2=88.39, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=39.06, exc=6.00, shift_1=39.06, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=26.90, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.494 seconds with direct, OO changed by 78.3534%
# Steady state for 6 took 2.618 seconds with direct, OO changed by 0.0206%
# calculation converged - 26.9, 200.0 (14/100)
# alpha_1=28.93, w_1=11372.35, kappa_1=91.93, kappa_2=91.93, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=42.25, exc=6.00, shift_1=42.25, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=28.93, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.537 seconds with direct, OO changed by 9.5999%
# Steady state for 6 took 2.860 seconds with direct, OO changed by 0.0221%
# calculation converged - 28.9, 200.0 (15/100)
# alpha_1=30.96, w_1=11372.35, kappa_1=95.33, kappa_2=95.33, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=45.44, exc=6.00, shift_1=45.44, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=30.96, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.537 seconds with direct, OO changed by 7.2952%
# Steady state for 6 took 2.412 seconds with direct, OO changed by 0.0236%
# calculation converged - 31.0, 200.0 (16/100)
# alpha_1=32.99, w_1=11372.35, kappa_1=98.62, kappa_2=98.62, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=48.63, exc=6.00, shift_1=48.63, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=32.99, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.497 seconds with direct, OO changed by 1125.3916%
# Steady state for 6 took 2.335 seconds with direct, OO changed by 0.0251%
# calculation converged - 33.0, 200.0 (17/100)
# alpha_1=35.02, w_1=11372.35, kappa_1=101.80, kappa_2=101.80, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=51.82, exc=6.00, shift_1=51.82, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=35.02, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.561 seconds with direct, OO changed by 15.8136%
# Steady state for 6 took 2.721 seconds with direct, OO changed by 0.0266%
# calculation converged - 35.0, 200.0 (18/100)
# alpha_1=37.05, w_1=11372.35, kappa_1=104.89, kappa_2=104.89, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=55.01, exc=6.00, shift_1=55.01, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=37.05, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.483 seconds with direct, OO changed by 213.7356%
# Steady state for 6 took 4.790 seconds with direct, OO changed by 0.0281%
# calculation converged - 37.1, 200.0 (19/100)
# alpha_1=39.08, w_1=11372.35, kappa_1=107.89, kappa_2=107.89, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=58.20, exc=6.00, shift_1=58.20, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=39.08, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.588 seconds with direct, OO changed by 405.2882%
# Steady state for 6 took 2.704 seconds with direct, OO changed by 0.0296%
# calculation converged - 39.1, 200.0 (20/100)
# alpha_1=41.11, w_1=11372.35, kappa_1=110.81, kappa_2=110.81, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=61.39, exc=6.00, shift_1=61.39, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=41.11, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.469 seconds with direct, OO changed by 1674.0930%
# Steady state for 6 took 2.636 seconds with direct, OO changed by 0.0310%
# calculation converged - 41.1, 200.0 (21/100)
# alpha_1=43.14, w_1=11372.35, kappa_1=113.65, kappa_2=113.65, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=64.58, exc=6.00, shift_1=64.58, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=43.14, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.458 seconds with direct, OO changed by 1045.2900%
# Steady state for 6 took 3.097 seconds with direct, OO changed by 0.0325%
# calculation converged - 43.1, 200.0 (22/100)
# alpha_1=45.17, w_1=11372.35, kappa_1=116.42, kappa_2=116.42, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=67.77, exc=6.00, shift_1=67.77, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=45.17, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.456 seconds with direct, OO changed by 9.9515%
# Steady state for 6 took 2.711 seconds with direct, OO changed by 0.0340%
# calculation converged - 45.2, 200.0 (23/100)
# alpha_1=47.20, w_1=11372.35, kappa_1=119.13, kappa_2=119.13, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=70.96, exc=6.00, shift_1=70.96, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=47.20, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.457 seconds with direct, OO changed by 227.7330%
# Steady state for 6 took 3.071 seconds with direct, OO changed by 0.0354%
# calculation converged - 47.2, 200.0 (24/100)
# alpha_1=49.23, w_1=11372.35, kappa_1=121.78, kappa_2=121.78, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=74.15, exc=6.00, shift_1=74.15, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=49.23, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.501 seconds with direct, OO changed by 9.4387%
# Steady state for 6 took 2.713 seconds with direct, OO changed by 0.0368%
# calculation converged - 49.2, 200.0 (25/100)
# alpha_1=51.27, w_1=11372.35, kappa_1=124.37, kappa_2=124.37, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=77.34, exc=6.00, shift_1=77.34, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=51.27, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.552 seconds with direct, OO changed by 70.5007%
# Steady state for 6 took 2.969 seconds with direct, OO changed by 0.0382%
# calculation converged - 51.3, 200.0 (26/100)
# alpha_1=53.30, w_1=11372.35, kappa_1=126.91, kappa_2=126.91, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=80.53, exc=6.00, shift_1=80.53, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=53.30, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.480 seconds with direct, OO changed by 85.3305%
# Steady state for 6 took 2.758 seconds with direct, OO changed by 0.0396%
# calculation converged - 53.3, 200.0 (27/100)
# alpha_1=55.33, w_1=11372.35, kappa_1=129.40, kappa_2=129.40, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=83.72, exc=6.00, shift_1=83.72, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=55.33, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.461 seconds with direct, OO changed by 537.4724%
# Steady state for 6 took 2.630 seconds with direct, OO changed by 0.0410%
# calculation converged - 55.3, 200.0 (28/100)
# alpha_1=57.36, w_1=11372.35, kappa_1=131.84, kappa_2=131.84, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=86.91, exc=6.00, shift_1=86.91, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=57.36, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.509 seconds with direct, OO changed by 93.2141%
# Steady state for 6 took 2.725 seconds with direct, OO changed by 0.0424%
# calculation converged - 57.4, 200.0 (29/100)
# alpha_1=59.39, w_1=11372.35, kappa_1=134.24, kappa_2=134.24, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=90.10, exc=6.00, shift_1=90.10, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=59.39, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.494 seconds with direct, OO changed by 32.8124%
# Steady state for 6 took 2.700 seconds with direct, OO changed by 0.0438%
# calculation converged - 59.4, 200.0 (30/100)
# alpha_1=61.42, w_1=11372.35, kappa_1=136.59, kappa_2=136.59, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=93.29, exc=6.00, shift_1=93.29, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=61.42, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.642 seconds with direct, OO changed by 169.8342%
# Steady state for 6 took 2.592 seconds with direct, OO changed by 0.0451%
# calculation converged - 61.4, 200.0 (31/100)
# alpha_1=63.45, w_1=11372.35, kappa_1=138.91, kappa_2=138.91, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=96.48, exc=6.00, shift_1=96.48, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=63.45, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.539 seconds with direct, OO changed by 126.7827%
# Steady state for 6 took 2.755 seconds with direct, OO changed by 0.0465%
# calculation converged - 63.4, 200.0 (32/100)
# alpha_1=65.48, w_1=11372.35, kappa_1=141.18, kappa_2=141.18, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=99.67, exc=6.00, shift_1=99.67, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=65.48, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.473 seconds with direct, OO changed by 27.1347%
# Steady state for 6 took 2.851 seconds with direct, OO changed by 0.0478%
# calculation converged - 65.5, 200.0 (33/100)
# alpha_1=67.51, w_1=11372.35, kappa_1=143.43, kappa_2=143.43, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=102.86, exc=6.00, shift_1=102.86, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=67.51, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.477 seconds with direct, OO changed by 134.7669%
# Steady state for 6 took 2.752 seconds with direct, OO changed by 0.0491%
# calculation converged - 67.5, 200.0 (34/100)
# alpha_1=69.54, w_1=11372.35, kappa_1=145.63, kappa_2=145.63, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=106.04, exc=6.00, shift_1=106.04, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=69.54, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.459 seconds with direct, OO changed by 84.9200%
# Steady state for 6 took 2.965 seconds with direct, OO changed by 0.0504%
# Steady state for 7 took 12.780 seconds with direct, OO changed by 0.0294%
# calculation converged - 69.5, 200.0 (35/100)
# alpha_1=71.57, w_1=11372.35, kappa_1=147.81, kappa_2=147.81, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=109.23, exc=7.00, shift_1=109.23, alpha_EM=0.01, sys_dim=3.00, N_1=7.00, N_2=7.00, mu=0.99, alpha_2=71.57, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.462 seconds with direct, OO changed by 50.7668%
# Steady state for 6 took 2.690 seconds with direct, OO changed by 0.0517%
# Steady state for 7 took 13.622 seconds with direct, OO changed by 0.0302%
# calculation converged - 71.6, 200.0 (36/100)
# alpha_1=73.60, w_1=11372.35, kappa_1=149.95, kappa_2=149.95, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=112.42, exc=7.00, shift_1=112.42, alpha_EM=0.01, sys_dim=3.00, N_1=7.00, N_2=7.00, mu=0.99, alpha_2=73.60, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.477 seconds with direct, OO changed by 6.3334%
# Steady state for 6 took 2.879 seconds with direct, OO changed by 0.0530%
# Steady state for 7 took 11.966 seconds with direct, OO changed by 0.0311%
# calculation converged - 73.6, 200.0 (37/100)
# alpha_1=75.63, w_1=11372.35, kappa_1=152.06, kappa_2=152.06, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=115.61, exc=7.00, shift_1=115.61, alpha_EM=0.01, sys_dim=3.00, N_1=7.00, N_2=7.00, mu=0.99, alpha_2=75.63, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.534 seconds with direct, OO changed by 5.3126%
# Steady state for 6 took 2.299 seconds with direct, OO changed by 0.0543%
# Steady state for 7 took 13.179 seconds with direct, OO changed by 0.0319%
# calculation converged - 75.6, 200.0 (38/100)
# alpha_1=77.66, w_1=11372.35, kappa_1=154.15, kappa_2=154.15, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=118.80, exc=7.00, shift_1=118.80, alpha_EM=0.01, sys_dim=3.00, N_1=7.00, N_2=7.00, mu=0.99, alpha_2=77.66, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.512 seconds with direct, OO changed by 85.5257%
# Steady state for 6 took 2.544 seconds with direct, OO changed by 0.0555%
# Steady state for 7 took 13.314 seconds with direct, OO changed by 0.0327%
# calculation converged - 77.7, 200.0 (39/100)
# alpha_1=79.69, w_1=11372.35, kappa_1=156.20, kappa_2=156.20, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=121.99, exc=7.00, shift_1=121.99, alpha_EM=0.01, sys_dim=3.00, N_1=7.00, N_2=7.00, mu=0.99, alpha_2=79.69, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.489 seconds with direct, OO changed by 50.9937%
# Steady state for 6 took 2.912 seconds with direct, OO changed by 0.0568%
# Steady state for 7 took 13.514 seconds with direct, OO changed by 0.0335%
# calculation converged - 79.7, 200.0 (40/100)
# alpha_1=81.72, w_1=11372.35, kappa_1=158.23, kappa_2=158.23, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=125.18, exc=7.00, shift_1=125.18, alpha_EM=0.01, sys_dim=3.00, N_1=7.00, N_2=7.00, mu=0.99, alpha_2=81.72, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.476 seconds with direct, OO changed by 125.5664%
# Steady state for 6 took 2.760 seconds with direct, OO changed by 0.0580%
# Steady state for 7 took 13.838 seconds with direct, OO changed by 0.0343%
# calculation converged - 81.7, 200.0 (41/100)
# alpha_1=83.76, w_1=11372.35, kappa_1=160.23, kappa_2=160.23, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=128.37, exc=7.00, shift_1=128.37, alpha_EM=0.01, sys_dim=3.00, N_1=7.00, N_2=7.00, mu=0.99, alpha_2=83.76, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.494 seconds with direct, OO changed by 3.0416%
# Steady state for 6 took 2.393 seconds with direct, OO changed by 0.0592%
# Steady state for 7 took 13.112 seconds with direct, OO changed by 0.0351%
# calculation converged - 83.8, 200.0 (42/100)
# alpha_1=85.79, w_1=11372.35, kappa_1=162.21, kappa_2=162.21, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=131.56, exc=7.00, shift_1=131.56, alpha_EM=0.01, sys_dim=3.00, N_1=7.00, N_2=7.00, mu=0.99, alpha_2=85.79, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.485 seconds with direct, OO changed by 329.2586%
# Steady state for 6 took 2.927 seconds with direct, OO changed by 0.0604%
# Steady state for 7 took 13.602 seconds with direct, OO changed by 0.0359%
# calculation converged - 85.8, 200.0 (43/100)
# alpha_1=87.82, w_1=11372.35, kappa_1=164.17, kappa_2=164.17, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=134.75, exc=7.00, shift_1=134.75, alpha_EM=0.01, sys_dim=3.00, N_1=7.00, N_2=7.00, mu=0.99, alpha_2=87.82, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.512 seconds with direct, OO changed by 121.8957%
# Steady state for 6 took 2.442 seconds with direct, OO changed by 0.0616%
# Steady state for 7 took 14.130 seconds with direct, OO changed by 0.0367%
# calculation converged - 87.8, 200.0 (44/100)
# alpha_1=89.85, w_1=11372.35, kappa_1=166.10, kappa_2=166.10, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=137.94, exc=7.00, shift_1=137.94, alpha_EM=0.01, sys_dim=3.00, N_1=7.00, N_2=7.00, mu=0.99, alpha_2=89.85, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.491 seconds with direct, OO changed by 32.3771%
# Steady state for 6 took 2.568 seconds with direct, OO changed by 0.0628%
# Steady state for 7 took 12.855 seconds with direct, OO changed by 0.0374%
# calculation converged - 89.8, 200.0 (45/100)
# alpha_1=91.88, w_1=11372.35, kappa_1=168.01, kappa_2=168.01, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=141.13, exc=7.00, shift_1=141.13, alpha_EM=0.01, sys_dim=3.00, N_1=7.00, N_2=7.00, mu=0.99, alpha_2=91.88, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.487 seconds with direct, OO changed by 6.0208%
# Steady state for 6 took 2.591 seconds with direct, OO changed by 0.0639%
# Steady state for 7 took 14.050 seconds with direct, OO changed by 0.0382%
# calculation converged - 91.9, 200.0 (46/100)
# alpha_1=93.91, w_1=11372.35, kappa_1=169.89, kappa_2=169.89, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=144.32, exc=7.00, shift_1=144.32, alpha_EM=0.01, sys_dim=3.00, N_1=7.00, N_2=7.00, mu=0.99, alpha_2=93.91, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.498 seconds with direct, OO changed by 71.9384%
# Steady state for 6 took 2.712 seconds with direct, OO changed by 0.0651%
# Steady state for 7 took 13.639 seconds with direct, OO changed by 0.0390%
# calculation converged - 93.9, 200.0 (47/100)
# alpha_1=95.94, w_1=11372.35, kappa_1=171.76, kappa_2=171.76, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=147.51, exc=7.00, shift_1=147.51, alpha_EM=0.01, sys_dim=3.00, N_1=7.00, N_2=7.00, mu=0.99, alpha_2=95.94, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.492 seconds with direct, OO changed by 179.9995%
# Steady state for 6 took 2.885 seconds with direct, OO changed by 0.0662%
# Steady state for 7 took 12.974 seconds with direct, OO changed by 0.0397%
# calculation converged - 95.9, 200.0 (48/100)
# alpha_1=97.97, w_1=11372.35, kappa_1=173.61, kappa_2=173.61, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=150.70, exc=7.00, shift_1=150.70, alpha_EM=0.01, sys_dim=3.00, N_1=7.00, N_2=7.00, mu=0.99, alpha_2=97.97, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.507 seconds with direct, OO changed by 79.3543%
# Steady state for 6 took 2.701 seconds with direct, OO changed by 0.0673%
# Steady state for 7 took 13.346 seconds with direct, OO changed by 0.0404%
# calculation converged - 98.0, 200.0 (49/100)
# alpha_1=100.00, w_1=11372.35, kappa_1=175.44, kappa_2=175.44, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=200.00, w0_2=200.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=153.89, exc=7.00, shift_1=153.89, alpha_EM=0.01, sys_dim=3.00, N_1=7.00, N_2=7.00, mu=0.99, alpha_2=100.00, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.477 seconds with direct, OO changed by 279.7361%
# Steady state for 6 took 2.716 seconds with direct, OO changed by 0.0684%
# Steady state for 7 took 13.213 seconds with direct, OO changed by 0.0412%
# calculation converged - 100.0, 200.0 (50/100)
# alpha_1=0.50, w_1=11372.35, kappa_1=177.25, kappa_2=177.25, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=157.08, exc=7.00, shift_1=157.08, alpha_EM=0.01, sys_dim=3.00, N_1=7.00, N_2=7.00, mu=0.99, alpha_2=0.50, w_2=11291.70, gamma_1=0.32, w_xx=22664.06, gamma_2=0.32
# None
# Steady state for 5 took 0.515 seconds with direct, OO changed by 181.6429%
# calculation converged - 0.5, 600.0 (51/100)
# alpha_1=2.53, w_1=11372.35, kappa_1=21.71, kappa_2=21.71, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=0.79, exc=5.00, shift_1=0.79, alpha_EM=0.01, sys_dim=3.00, N_1=5.00, N_2=5.00, mu=0.99, alpha_2=2.53, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.532 seconds with direct, OO changed by 259.9368%
# Steady state for 6 took 3.055 seconds with direct, OO changed by 0.0000%
# calculation converged - 2.5, 600.0 (52/100)
# alpha_1=4.56, w_1=11372.35, kappa_1=48.84, kappa_2=48.84, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=3.98, exc=6.00, shift_1=3.98, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=4.56, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.573 seconds with direct, OO changed by 159.7247%
# Steady state for 6 took 3.026 seconds with direct, OO changed by 0.0000%
# calculation converged - 4.6, 600.0 (53/100)
# alpha_1=6.59, w_1=11372.35, kappa_1=65.57, kappa_2=65.57, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=7.16, exc=6.00, shift_1=7.16, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=6.59, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.495 seconds with direct, OO changed by 6.0798%
# Steady state for 6 took 2.706 seconds with direct, OO changed by 0.0000%
# calculation converged - 6.6, 600.0 (54/100)
# alpha_1=8.62, w_1=11372.35, kappa_1=78.82, kappa_2=78.82, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=10.35, exc=6.00, shift_1=10.35, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=8.62, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.453 seconds with direct, OO changed by 6.3709%
# Steady state for 6 took 2.879 seconds with direct, OO changed by 0.0000%
# calculation converged - 8.6, 600.0 (55/100)
# alpha_1=10.65, w_1=11372.35, kappa_1=90.15, kappa_2=90.15, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=13.54, exc=6.00, shift_1=13.54, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=10.65, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.465 seconds with direct, OO changed by 4861.4596%
# Steady state for 6 took 2.740 seconds with direct, OO changed by 0.0000%
# calculation converged - 10.7, 600.0 (56/100)
# alpha_1=12.68, w_1=11372.35, kappa_1=100.20, kappa_2=100.20, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=16.73, exc=6.00, shift_1=16.73, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=12.68, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.468 seconds with direct, OO changed by 89.7895%
# Steady state for 6 took 2.772 seconds with direct, OO changed by 0.0000%
# calculation converged - 12.7, 600.0 (57/100)
# alpha_1=14.71, w_1=11372.35, kappa_1=109.33, kappa_2=109.33, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=19.92, exc=6.00, shift_1=19.92, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=14.71, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.554 seconds with direct, OO changed by 957.0446%
# Steady state for 6 took 2.868 seconds with direct, OO changed by 0.0000%
# calculation converged - 14.7, 600.0 (58/100)
# alpha_1=16.74, w_1=11372.35, kappa_1=117.76, kappa_2=117.76, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=23.11, exc=6.00, shift_1=23.11, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=16.74, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.532 seconds with direct, OO changed by 15.3278%
# Steady state for 6 took 2.738 seconds with direct, OO changed by 0.0000%
# calculation converged - 16.7, 600.0 (59/100)
# alpha_1=18.78, w_1=11372.35, kappa_1=125.63, kappa_2=125.63, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=26.30, exc=6.00, shift_1=26.30, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=18.78, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.457 seconds with direct, OO changed by 5.1613%
# Steady state for 6 took 2.839 seconds with direct, OO changed by 0.0001%
# calculation converged - 18.8, 600.0 (60/100)
# alpha_1=20.81, w_1=11372.35, kappa_1=133.02, kappa_2=133.02, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=29.49, exc=6.00, shift_1=29.49, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=20.81, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.556 seconds with direct, OO changed by 369.5444%
# Steady state for 6 took 3.200 seconds with direct, OO changed by 0.0001%
# calculation converged - 20.8, 600.0 (61/100)
# alpha_1=22.84, w_1=11372.35, kappa_1=140.03, kappa_2=140.03, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=32.68, exc=6.00, shift_1=32.68, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=22.84, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.527 seconds with direct, OO changed by 116.1228%
# Steady state for 6 took 2.840 seconds with direct, OO changed by 0.0001%
# calculation converged - 22.8, 600.0 (62/100)
# alpha_1=24.87, w_1=11372.35, kappa_1=146.71, kappa_2=146.71, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=35.87, exc=6.00, shift_1=35.87, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=24.87, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.471 seconds with direct, OO changed by 46.7220%
# Steady state for 6 took 2.782 seconds with direct, OO changed by 0.0001%
# calculation converged - 24.9, 600.0 (63/100)
# alpha_1=26.90, w_1=11372.35, kappa_1=153.09, kappa_2=153.09, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=39.06, exc=6.00, shift_1=39.06, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=26.90, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.508 seconds with direct, OO changed by 64.6969%
# Steady state for 6 took 2.799 seconds with direct, OO changed by 0.0001%
# calculation converged - 26.9, 600.0 (64/100)
# alpha_1=28.93, w_1=11372.35, kappa_1=159.22, kappa_2=159.22, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=42.25, exc=6.00, shift_1=42.25, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=28.93, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.478 seconds with direct, OO changed by 149.4371%
# Steady state for 6 took 2.578 seconds with direct, OO changed by 0.0001%
# calculation converged - 28.9, 600.0 (65/100)
# alpha_1=30.96, w_1=11372.35, kappa_1=165.12, kappa_2=165.12, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=45.44, exc=6.00, shift_1=45.44, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=30.96, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.461 seconds with direct, OO changed by 8429.4948%
# Steady state for 6 took 2.960 seconds with direct, OO changed by 0.0001%
# calculation converged - 31.0, 600.0 (66/100)
# alpha_1=32.99, w_1=11372.35, kappa_1=170.82, kappa_2=170.82, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=48.63, exc=6.00, shift_1=48.63, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=32.99, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.477 seconds with direct, OO changed by 15.0354%
# Steady state for 6 took 2.956 seconds with direct, OO changed by 0.0002%
# calculation converged - 33.0, 600.0 (67/100)
# alpha_1=35.02, w_1=11372.35, kappa_1=176.33, kappa_2=176.33, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=51.82, exc=6.00, shift_1=51.82, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=35.02, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.481 seconds with direct, OO changed by 83.9709%
# Steady state for 6 took 2.983 seconds with direct, OO changed by 0.0002%
# calculation converged - 35.0, 600.0 (68/100)
# alpha_1=37.05, w_1=11372.35, kappa_1=181.68, kappa_2=181.68, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=55.01, exc=6.00, shift_1=55.01, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=37.05, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.471 seconds with direct, OO changed by 33.7763%
# Steady state for 6 took 2.757 seconds with direct, OO changed by 0.0002%
# calculation converged - 37.1, 600.0 (69/100)
# alpha_1=39.08, w_1=11372.35, kappa_1=186.87, kappa_2=186.87, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=58.20, exc=6.00, shift_1=58.20, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=39.08, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.500 seconds with direct, OO changed by 10.1834%
# Steady state for 6 took 2.745 seconds with direct, OO changed by 0.0002%
# calculation converged - 39.1, 600.0 (70/100)
# alpha_1=41.11, w_1=11372.35, kappa_1=191.92, kappa_2=191.92, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=61.39, exc=6.00, shift_1=61.39, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=41.11, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.499 seconds with direct, OO changed by 154.7246%
# Steady state for 6 took 2.824 seconds with direct, OO changed by 0.0002%
# calculation converged - 41.1, 600.0 (71/100)
# alpha_1=43.14, w_1=11372.35, kappa_1=196.84, kappa_2=196.84, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=64.58, exc=6.00, shift_1=64.58, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=43.14, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.520 seconds with direct, OO changed by 14.8950%
# Steady state for 6 took 2.699 seconds with direct, OO changed by 0.0003%
# calculation converged - 43.1, 600.0 (72/100)
# alpha_1=45.17, w_1=11372.35, kappa_1=201.65, kappa_2=201.65, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=67.77, exc=6.00, shift_1=67.77, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=45.17, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.507 seconds with direct, OO changed by 40.4463%
# Steady state for 6 took 2.427 seconds with direct, OO changed by 0.0003%
# calculation converged - 45.2, 600.0 (73/100)
# alpha_1=47.20, w_1=11372.35, kappa_1=206.34, kappa_2=206.34, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=70.96, exc=6.00, shift_1=70.96, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=47.20, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.489 seconds with direct, OO changed by 53.6464%
# Steady state for 6 took 2.575 seconds with direct, OO changed by 0.0003%
# calculation converged - 47.2, 600.0 (74/100)
# alpha_1=49.23, w_1=11372.35, kappa_1=210.92, kappa_2=210.92, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=74.15, exc=6.00, shift_1=74.15, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=49.23, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.500 seconds with direct, OO changed by 450.5541%
# Steady state for 6 took 2.598 seconds with direct, OO changed by 0.0004%
# calculation converged - 49.2, 600.0 (75/100)
# alpha_1=51.27, w_1=11372.35, kappa_1=215.41, kappa_2=215.41, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=77.34, exc=6.00, shift_1=77.34, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=51.27, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.495 seconds with direct, OO changed by 28.3394%
# Steady state for 6 took 2.517 seconds with direct, OO changed by 0.0004%
# calculation converged - 51.3, 600.0 (76/100)
# alpha_1=53.30, w_1=11372.35, kappa_1=219.81, kappa_2=219.81, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=80.53, exc=6.00, shift_1=80.53, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=53.30, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.496 seconds with direct, OO changed by 11.9663%
# Steady state for 6 took 2.505 seconds with direct, OO changed by 0.0004%
# calculation converged - 53.3, 600.0 (77/100)
# alpha_1=55.33, w_1=11372.35, kappa_1=224.12, kappa_2=224.12, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=83.72, exc=6.00, shift_1=83.72, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=55.33, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.578 seconds with direct, OO changed by 42.0385%
# Steady state for 6 took 2.868 seconds with direct, OO changed by 0.0005%
# calculation converged - 55.3, 600.0 (78/100)
# alpha_1=57.36, w_1=11372.35, kappa_1=228.35, kappa_2=228.35, T_EM=6000.00, bias=80.66, parity_flip=0.00, w0_1=600.00, w0_2=600.00, V=80.66, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, dipole_2=1.00, dipole_1=1.00, shift_2=86.91, exc=6.00, shift_1=86.91, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, alpha_2=57.36, w_2=11291.70, gamma_1=0.11, w_xx=22664.06, gamma_2=0.11
# None
# Steady state for 5 took 0.511 seconds with direct, OO changed by 129.3358%
# Steady state for 6 took 2.822 seconds with direct, OO changed by 0.0005%
# calculation converged - 57.4, 600.0 (79/100)
# ...
# None
# Steady state for 5 took 0.382 seconds with direct, OO changed by 158.7812%
# Steady state for 6 took 2.021 seconds with direct, OO changed by 0.0004%
# calculation converged - 41.1, 600.0 (71/100)
# kappa_2=196.84, kappa_1=196.84, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=64.58, shift_1=64.58, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.407 seconds with direct, OO changed by 64.6860%
# Steady state for 6 took 1.871 seconds with direct, OO changed by 0.0004%
# calculation converged - 43.1, 600.0 (72/100)
# kappa_2=201.65, kappa_1=201.65, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=67.77, shift_1=67.77, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.378 seconds with direct, OO changed by 65.8452%
# Steady state for 6 took 1.756 seconds with direct, OO changed by 0.0005%
# calculation converged - 45.2, 600.0 (73/100)
# kappa_2=206.34, kappa_1=206.34, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=70.96, shift_1=70.96, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.396 seconds with direct, OO changed by 92.0590%
# Steady state for 6 took 1.761 seconds with direct, OO changed by 0.0005%
# calculation converged - 47.2, 600.0 (74/100)
# kappa_2=210.92, kappa_1=210.92, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=74.15, shift_1=74.15, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.334 seconds with direct, OO changed by 2.9032%
# Steady state for 6 took 1.751 seconds with direct, OO changed by 0.0006%
# calculation converged - 49.2, 600.0 (75/100)
# kappa_2=215.41, kappa_1=215.41, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=77.34, shift_1=77.34, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.346 seconds with direct, OO changed by 93.8183%
# Steady state for 6 took 2.247 seconds with direct, OO changed by 0.0006%
# calculation converged - 51.3, 600.0 (76/100)
# kappa_2=219.81, kappa_1=219.81, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=80.53, shift_1=80.53, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.370 seconds with direct, OO changed by 12.5860%
# Steady state for 6 took 2.178 seconds with direct, OO changed by 0.0007%
# calculation converged - 53.3, 600.0 (77/100)
# kappa_2=224.12, kappa_1=224.12, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=83.72, shift_1=83.72, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.343 seconds with direct, OO changed by 1110.7024%
# Steady state for 6 took 2.198 seconds with direct, OO changed by 0.0007%
# calculation converged - 55.3, 600.0 (78/100)
# kappa_2=228.35, kappa_1=228.35, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=86.91, shift_1=86.91, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.440 seconds with direct, OO changed by 12.5570%
# Steady state for 6 took 2.217 seconds with direct, OO changed by 0.0008%
# calculation converged - 57.4, 600.0 (79/100)
# kappa_2=232.50, kappa_1=232.50, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=90.10, shift_1=90.10, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.352 seconds with direct, OO changed by 44.9993%
# Steady state for 6 took 2.195 seconds with direct, OO changed by 0.0009%
# calculation converged - 59.4, 600.0 (80/100)
# kappa_2=236.58, kappa_1=236.58, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=93.29, shift_1=93.29, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.407 seconds with direct, OO changed by 248.6191%
# Steady state for 6 took 2.144 seconds with direct, OO changed by 0.0009%
# calculation converged - 61.4, 600.0 (81/100)
# kappa_2=240.59, kappa_1=240.59, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=96.48, shift_1=96.48, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.373 seconds with direct, OO changed by 1240.8469%
# Steady state for 6 took 1.754 seconds with direct, OO changed by 0.0010%
# calculation converged - 63.4, 600.0 (82/100)
# kappa_2=244.54, kappa_1=244.54, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=99.67, shift_1=99.67, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.366 seconds with direct, OO changed by 17.2776%
# Steady state for 6 took 2.188 seconds with direct, OO changed by 0.0011%
# calculation converged - 65.5, 600.0 (83/100)
# kappa_2=248.42, kappa_1=248.42, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=102.86, shift_1=102.86, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.372 seconds with direct, OO changed by 534.0190%
# Steady state for 6 took 1.761 seconds with direct, OO changed by 0.0012%
# calculation converged - 67.5, 600.0 (84/100)
# kappa_2=252.24, kappa_1=252.24, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=106.04, shift_1=106.04, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.408 seconds with direct, OO changed by 170.0255%
# Steady state for 6 took 2.149 seconds with direct, OO changed by 0.0013%
# calculation converged - 69.5, 600.0 (85/100)
# kappa_2=256.01, kappa_1=256.01, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=109.23, shift_1=109.23, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.405 seconds with direct, OO changed by 2.4204%
# Steady state for 6 took 2.148 seconds with direct, OO changed by 0.0013%
# calculation converged - 71.6, 600.0 (86/100)
# kappa_2=259.72, kappa_1=259.72, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=112.42, shift_1=112.42, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.496 seconds with direct, OO changed by 493.0038%
# Steady state for 6 took 1.755 seconds with direct, OO changed by 0.0014%
# calculation converged - 73.6, 600.0 (87/100)
# kappa_2=263.38, kappa_1=263.38, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=115.61, shift_1=115.61, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.365 seconds with direct, OO changed by 1411.0728%
# Steady state for 6 took 2.232 seconds with direct, OO changed by 0.0015%
# calculation converged - 75.6, 600.0 (88/100)
# kappa_2=266.99, kappa_1=266.99, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=118.80, shift_1=118.80, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.368 seconds with direct, OO changed by 3.2662%
# Steady state for 6 took 2.191 seconds with direct, OO changed by 0.0016%
# calculation converged - 77.7, 600.0 (89/100)
# kappa_2=270.55, kappa_1=270.55, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=121.99, shift_1=121.99, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.399 seconds with direct, OO changed by 464.7563%
# Steady state for 6 took 2.153 seconds with direct, OO changed by 0.0017%
# calculation converged - 79.7, 600.0 (90/100)
# kappa_2=274.06, kappa_1=274.06, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=125.18, shift_1=125.18, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.352 seconds with direct, OO changed by 14.8916%
# Steady state for 6 took 2.234 seconds with direct, OO changed by 0.0019%
# calculation converged - 81.7, 600.0 (91/100)
# kappa_2=277.53, kappa_1=277.53, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=128.37, shift_1=128.37, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.352 seconds with direct, OO changed by 36.5016%
# Steady state for 6 took 2.284 seconds with direct, OO changed by 0.0020%
# calculation converged - 83.8, 600.0 (92/100)
# kappa_2=280.96, kappa_1=280.96, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=131.56, shift_1=131.56, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.399 seconds with direct, OO changed by 50.5864%
# Steady state for 6 took 2.162 seconds with direct, OO changed by 0.0021%
# calculation converged - 85.8, 600.0 (93/100)
# kappa_2=284.34, kappa_1=284.34, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=134.75, shift_1=134.75, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.391 seconds with direct, OO changed by 1264.9146%
# Steady state for 6 took 2.283 seconds with direct, OO changed by 0.0022%
# calculation converged - 87.8, 600.0 (94/100)
# kappa_2=287.69, kappa_1=287.69, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=137.94, shift_1=137.94, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.403 seconds with direct, OO changed by 14.3999%
# Steady state for 6 took 2.339 seconds with direct, OO changed by 0.0023%
# calculation converged - 89.8, 600.0 (95/100)
# kappa_2=291.00, kappa_1=291.00, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=141.13, shift_1=141.13, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.395 seconds with direct, OO changed by 21.3805%
# Steady state for 6 took 2.287 seconds with direct, OO changed by 0.0025%
# calculation converged - 91.9, 600.0 (96/100)
# kappa_2=294.27, kappa_1=294.27, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=144.32, shift_1=144.32, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.370 seconds with direct, OO changed by 15.5254%
# Steady state for 6 took 2.292 seconds with direct, OO changed by 0.0026%
# calculation converged - 93.9, 600.0 (97/100)
# kappa_2=297.50, kappa_1=297.50, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=147.51, shift_1=147.51, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.384 seconds with direct, OO changed by 18.5653%
# Steady state for 6 took 2.173 seconds with direct, OO changed by 0.0027%
# calculation converged - 95.9, 600.0 (98/100)
# kappa_2=300.70, kappa_1=300.70, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=150.70, shift_1=150.70, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.411 seconds with direct, OO changed by 9.8510%
# Steady state for 6 took 2.219 seconds with direct, OO changed by 0.0029%
# calculation converged - 98.0, 600.0 (99/100)
# kappa_2=303.87, kappa_1=303.87, T_EM=6000.00, bias=80.66, parity_flip=0.00, T_2=300.00, T_1=300.00, Gamma_1=400.00, Gamma_2=400.00, shift_2=153.89, shift_1=153.89, V=80.66, w_1=11372.35, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=6.00, alpha_EM=0.01, sys_dim=3.00, N_1=6.00, N_2=6.00, mu=0.99, w_xx=22664.06, gamma_1=0.11, gamma_2=0.11
# None
# Steady state for 5 took 0.365 seconds with direct, OO changed by 265.7262%
# Steady state for 6 took 2.161 seconds with direct, OO changed by 0.0030%
# calculation converged - 100.0, 600.0 (100/100)
# Files saved at DATA/heatmap_hetero_add_7

# %%
num=7
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='bright')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='dark')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='sigma_z')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='sigma_x')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='eig_x')
# Out:
# plotting in new style
# saved at PLOTS/heatmap_hetero_bright_7.pdf
# plotting in new style
# saved at PLOTS/heatmap_hetero_dark_7.pdf
# plotting in new style
# saved at PLOTS/heatmap_hetero_sigma_z_7.pdf
# plotting in new style
# saved at PLOTS/heatmap_hetero_sigma_x_7.pdf
# plotting in new style
# saved at PLOTS/heatmap_hetero_eig_x_7.pdf

# %%
reload(hm)
w_2 = 1.4*ev_to_inv_cm
bias=0.01*ev_to_inv_cm
V=0.01*ev_to_inv_cm
alpha = 200./pi
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =4
wc = 100.
w_0 = 200.
site_basis = True
Gamma = (w_0**2)/wc
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=2*N)

dirname = 'heatmap_hetero'


x_values = np.linspace(0.5,V, 30)

y_values = [300.] #np.linspace(77,300, 2)



ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname, save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.1, conv_obs='bright')
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname+'_add', save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.1, conv_obs='bright', additive=True)

# %% [markdown]
# ### Uncoupled monomers
#
# These get updated dynamically by the various functions. `SES_setup.PARAMS_setup` just imposes the relevant symmetry behind the scenes so the API is clean and so that we can reuse code for dimer case - e.g. $\alpha_1 = \alpha_2$, no doubly excited state.

# %%
w_2 = 1.4*ev_to_inv_cm
bias = 0.02*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 0.0*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 100./pi
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =7
wc = 100.
w_0 = 200.
site_basis = True
Gamma = (w_0**2)/wc
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=False, exc_diff=N)

x_values = np.logspace(-2, np.log10(100), 10, endpoint=True)
print x_values
y_values = [77, 300] #np.linspace(77,300, 2)
dirname = 'heatmap_TphvAlpha_uncoupled'

ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname+'_add', save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.025, conv_obs='OO', additive=True)
"""
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname, save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                            conv_percent_tol=0.01, conv_obs='OO', additive=False)
"""
#DATA/heatmap_TphvAlpha_uncoupled_6

# %%
num=7
dirname = 'heatmap_TphvAlpha_uncoupled'
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='XO')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='OX')

# %%
H, L = get_H_and_L(PARAMS)

# %%
eta = np.sqrt(PARAMS['bias']**2 + 4*PARAMS['V']**2)
print (2*PARAMS['V']/eta)
print (PARAMS['bias']/eta)
print (1/np.sqrt(2))

# %%
np.linspace(200, 600, 5, endpoint=False)

# %%
np.log(0.0001)
np.logspace(-5, 2, 10, endpoint=False)

# %% [markdown]
# ## Heterodimer
# Shouldn't increasing the phonon coupling strength lead to suppression of ground state population?

# %%
ss_array, PARAMS, info_array = heatmap_loader(16, dir_name="heatmap_TphvAlpha")
print zip(PARAMS['x_values'], steadystate_observable(ss_array, PARAMS, 'OO')[0])

# %%
reload(hm)
"""
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname, save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                            conv_percent_tol=0.025, conv_obs='OO', additive=False)
"""
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname+'_add', save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.025, conv_obs='OO', additive=True)

# %%
dirname = 'heatmap_TphvAlpha_hetero'
num = 5
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='bright')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='dark')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='sigma_z')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='sigma_x')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='eig_x')

# %%
num = 20
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='DS/GS')

heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='OO')

heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='XO')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='OX')

heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='eig_x')
"""heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_x_equiv')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_y')"""

# %% [markdown]
# # Homodimer

# %%
reload(hm)
w_2 = 1.40*ev_to_inv_cm
bias= 0 #0.01*ev_to_inv_cm
V=0.01*ev_to_inv_cm
alpha = 200./pi
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =4
wc = 100.
w_0 = 200.
site_basis = True
Gamma = (w_0**2)/wc
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=2*N)

x_values = np.logspace(-2, np.log10(100), 10, endpoint=True)
#x_values[0] = 0
y_values = [77, 300] #np.linspace(77,300, 2)

# %%
print inv_ps_to_inv_cm*10**(-3)
print w_0/ev_to_inv_cm
print Gamma/ev_to_inv_cm

# %%
print (x_values)

# %%
dirname = 'heatmap_TphvAlpha_homo'
reload(hm)

ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname, save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.025, conv_obs='OO', additive=False)

"""
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname+'_add', save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.025, conv_obs='OO', additive=True)"""

# %%
def steadystate_observable(ss_array, PARAMS, observable):
    ss_obs_array = np.zeros(shape=ss_array.shape)
    for y, ss_row in enumerate(ss_array):
        for x, ss_dm in enumerate(ss_row):
            dim, size = ss_dm.dims[0][1::], int(ss_dm.shape[0]/PARAMS['sys_dim'])
            
            nstates, state2idx, idx2state = qt.enr_state_dictionaries(dim, dim[0]+0)
            exc_diff = 0 # function finds the correct exc_diff given some dm
            while nstates != size:
                nstates, state2idx, idx2state = qt.enr_state_dictionaries(dim, dim[0]+exc_diff)
            
            #print exc_diff, dim[0]+exc_diff
            PARAMS.update({'N_1':dim[0], 'N_2':dim[1], 'exc':dim[0]+exc_diff})
            obs_op = make_expectation_operators(PARAMS)[observable]
            #print obs_op.shape, ss_dm.shape
            ss_obs_array[y][x] = (obs_op*ss_dm).tr().real #info_test[y][x]['solution_time']
    return ss_obs_array

# With saved data, we can calculte things differently

def heatmap_loader(num, dir_name="heatmap"):
    # Only loads data of heatmap into memory, does not plot
    directory = 'DATA/'+dir_name+'_'+str(num)
    ss_array = load_obj(directory+'/ss_array')
    PARAMS = load_obj(directory+'/PARAMS')
    info_array = load_obj(directory+'/info_array') # reverse ordering -> lower_N-higher_N
    return ss_array, PARAMS, info_array

dirname = 'heatmap_TphvAlpha_homo'
num = 3
heatmap_plotter(num=num, dir_name=dirname, 
                     print_params=False, observable='XO')
heatmap_plotter(num=num, dir_name=dirname, 
                     print_params=False, observable='dark')
heatmap_plotter(num=num, dir_name=dirname, 
                     print_params=False, observable='bright')
heatmap_plotter(num=num, dir_name=dirname, 
                     print_params=False, observable='sigma_x')

# %%
num = 3
dirname = 'heatmap_TphvAlpha_homo'
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=True, observable='DS/GS')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='bright')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='dark')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='OO')

heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='XO')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='OX')

heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_x')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_x_equiv')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_y')

heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='sigma_z')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='sigma_x')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='sigma_y')

# %%
num = 1
dir_name = 'heatmap_TphvAlpha_a19'
hm = heatmap_loader(19, dir_name='heatmap_TphvAlpha')
hm2 = heatmap_loader(1, dir_name='heatmap_TphvAlpha_a19')
print hm[0]
"""heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=True, observable='DS/GS')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='bright')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='dark')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='OO')

heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='XO')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='OX')

heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='eig_x')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='eig_x_equiv')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='eig_y')

heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='sigma_z')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='sigma_x')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='sigma_y')"""

# %% [markdown]
# # Asymmetrical phonon environments

# %%
reload(hm)
w_2 = 1.40*ev_to_inv_cm
bias= 0 #0.01*ev_to_inv_cm
V=0.01*ev_to_inv_cm
alpha = 5.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =4
wc = 100.
w_0 = 200.
site_basis = True
Gamma = (w_0**2)/wc
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=2*N)

x_values = np.logspace(-2, np.log10(100), 20, endpoint=True)
#x_values[0] = 0
y_values = [77, 300] #np.linspace(77,300, 2)
dirname = "heatmap_TphvAlpha_assymmetrical"
"""
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname, save_data=True,
                            persistent=False, method='direct', threshold=1e-7, 
                                              conv_percent_tol=0.025, conv_obs='OO')
"""
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname+'_add', save_data=True,
                            persistent=False, method='direct', threshold=1e-7, 
                                              conv_percent_tol=0.025, conv_obs='OO', additive=True)

# %%
num = 1
dirname = "heatmap_TphvAlpha_assymmetrical"
#heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
#                print_params=True, observable='DS/GS')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='bright')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='dark')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='OO')

heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='XO')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='OX')

heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='eig_x')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='eig_x_equiv')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='eig_y')

heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='sigma_z')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='sigma_x')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='sigma_y')

# %% [markdown]
# # Environments with different parity $\alpha_1 = -\alpha_2$

# %%
reload(hm)
w_2 = 1.4*ev_to_inv_cm
bias = 0.01*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 0.01*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 100./pi
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =7
wc = 100.
w_0 = 200.
site_basis = True
Gamma = (w_0**2)/wc
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=False, exc_diff=N, parity_flip=True)
print 
x_values = np.linspace(0.5,V, 30)
print x_values
y_values = [77, 110] #np.linspace(77,300, 2)
dirname = 'heatmap_TphvAlpha_phased'

ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname+'_add', save_data=True,
                            persistent=False, method='direct', threshold=1e-9, 
                            conv_percent_tol=0.025, conv_obs='OO', additive=True)
"""
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname, save_data=True,
                            persistent=False, method='direct', threshold=1e-9, 
                            conv_percent_tol=0.025, conv_obs='OO', additive=False)"""
#DATA/heatmap_TphvAlpha_phased_2

# %%
num=3
dirname = 'heatmap_TphvAlpha_phased'
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='XO', ylim=[0,0.2])
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='OX', ylim=[0.1,0.5])
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='dark', ylim=[0,0.6])
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='bright', ylim=[-0.01,0.1])
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='eig_x')

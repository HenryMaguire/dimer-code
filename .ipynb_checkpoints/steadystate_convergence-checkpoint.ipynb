# %%
# Incase we have to clear all variables
# %reset -f

# %%
from dimer_setup import *

# %% [markdown]
# # Convergence data calculations

# %%
def calculate_steadystate(H, L, fill_factor=47):
    calculated = False
    ff = fill_factor
    tol = 1e-8
    ss = 0
    while not calculated:
        try:
            ss = steadystate(H[1], [L], method='iterative-gmres',
                                   use_precond=True, fill_factor=fill_factor,
                                   drop_tol=1e-3, use_rcm=True, return_info=True,
                                   tol=tol, maxiter=60000)
            calculated=True
            return ss[0], ss[1]
        except Exception as err:
            print "Steadystate failed because {}.".format(err, fill_factor)
            return 0,0
    


def heat_map_calculator(PARAMS,
                        x_axis_parameters=['w0_1', 'w0_2'],
                        y_axis_parameters=['Gamma_1', 'Gamma_2'],
                        x_values=[100., 200., 300.],
                        y_values=[70., 200., 600.],
                        dir_name='heatmap_oG', fill_factor=47):
    info_array = np.zeros(( len(y_values), len(x_values)), dtype=dict)
    ss_array = np.zeros(( len(y_values), len(x_values)), dtype=qt.Qobj)
    for i, y in enumerate(y_values):
        for param_labels in y_axis_parameters:
            PARAMS.update({param_labels : y})
        for j, x in enumerate(x_values):
            # scan over each combination of parameters and update the PARAMS dict
            # for each point on the grid
            for param_labels in x_axis_parameters:
                PARAMS.update({param_labels : x})
            if 'exc' in x_axis_parameters:
                PARAMS.update({'exc': PARAMS['N_1']+PARAMS['exc_diff']})
            if 'exc_diff' in y_axis_parameters:
                PARAMS.update({'exc' : PARAMS['N_1']+PARAMS['exc_diff']})
            ti = time.time()
            silent = True
            if PARAMS['N_1'] >=8:
                silent = False
            H, L = get_H_and_L(PARAMS,silent=silent)
            tf = time.time()
            ss, info = calculate_steadystate(H, L, fill_factor=fill_factor)
            del H, L
            ss_array[i][j], info_array[i][j] = ss, info
            try:
                ts = info['solution_time']
                print "N_1 = {}, N_2 = {}, exc= {}".format(PARAMS['N_1'], PARAMS['N_2'], PARAMS['exc'])
                print "Build time: {:0.3f} \t | \t Solution time: {:0.3f}".format(tf-ti, 
                                                                                  ts)
            except TypeError:
                print "N_1 = {}, N_2 = {}, exc= {} - Calculation skipped...".format(PARAMS['N_1'], 
                                                                                      PARAMS['N_2'], 
                                                                                      PARAMS['exc'])
                

    # Pass variables through so heatmap_plotter knows what to do
    PARAMS.update({'x_axis_parameters': x_axis_parameters, 
                             'y_axis_parameters': y_axis_parameters,
                          'x_values': x_values, 'y_values': y_values})
    
    k = 1
    saved = False
    while not saved:
        directory = 'DATA/'+dir_name+'_'+str(k)
        if not os.path.exists(directory):
            os.makedirs(directory)
            save_obj(ss_array, directory+'/ss_array')
            save_obj(PARAMS, directory+'/PARAMS')
            save_obj(info_array, directory+'/info_array')
            saved = True
            print "Files saved at {}".format(directory)
        else:
            k+=1
    return ss_array, info_array

# %% [markdown]
# # Running the convergence tests

# %%
# T_ph vs N
w_2 = 8000.
alpha = 20.

x_values=[2,3,4,5,6,7,8][::-1] # N
#x_values=[2,3,4,5,6,7][::-1] # N
pap = alpha_to_pialpha_prop(alpha, w_2)
pars = PARAMS_setup(bias=100., w_2=8000., V = 100., pialpha_prop=pap,
                                 T_EM=6000., T_ph =300., 
                                 alpha_EM=0.1, shift=True,
                                 num_cpus=3, N=x_values[0], Gamma=200., w_0=300.,
                                 silent=False)
exc = pars['exc']

 # N
#y_values=[2,1,0] # exc
y_values=[4,3,2,1,0] # exc
try:

    ss_array, info_array= heat_map_calculator(pars,
                            x_axis_parameters=['N_1', 'N_2'],
                            y_axis_parameters=['exc_diff'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name='heatmap_excvN', 
                            fill_factor=50)
except Exception as err:
    print "Error: This means that an error has been raised internally in the SS calculator. Message {}".format(err)
# Out:
# Gap is 223.60679775. Phonon thermal energy is 208.5. Phonon SD peak is 283.528352835. N=8.
# The operators took 46.0143139362 and have dimension 244.
# Building the RC Liouvillian took 46.027 seconds.
# ****************************************************************
# It is 59536by59536. The full basis would be 65536by65536
# Full optical Liouvillian took 93.4753510952 seconds.
# Steadystate failed because Steadystate error: Did not reach tolerance after 60000 steps.
# Residual norm: 0.627656708162.
# N_1 = 8, N_2 = 8, exc= 12 - Calculation skipped...
# N_1 = 7, N_2 = 7, exc= 11
# Build time: 147.368 	 | 	 Solution time: 481.846
# N_1 = 6, N_2 = 6, exc= 10
# Build time: 57.748 	 | 	 Solution time: 75.375
# N_1 = 5, N_2 = 5, exc= 9
# Build time: 23.880 	 | 	 Solution time: 17.695
# N_1 = 4, N_2 = 4, exc= 8
# Build time: 8.817 	 | 	 Solution time: 2.018
# N_1 = 3, N_2 = 3, exc= 7
# Build time: 2.575 	 | 	 Solution time: 0.073
# N_1 = 2, N_2 = 2, exc= 6
# Build time: 0.483 	 | 	 Solution time: 0.003
# The operators took 103.387017012 and have dimension 232.
# Building the RC Liouvillian took 111.237 seconds.
# ****************************************************************
# It is 53824by53824. The full basis would be 65536by65536
# Full optical Liouvillian took 95.4650359154 seconds.
# Steadystate failed because Failed to build preconditioner. Try increasing fill_factor and/or drop_tol..
# N_1 = 8, N_2 = 8, exc= 11 - Calculation skipped...
# N_1 = 7, N_2 = 7, exc= 10
# Build time: 126.096 	 | 	 Solution time: 298.210
# N_1 = 6, N_2 = 6, exc= 9
# Build time: 63.716 	 | 	 Solution time: 80.894
# N_1 = 5, N_2 = 5, exc= 8
# Build time: 26.673 	 | 	 Solution time: 16.499
# N_1 = 4, N_2 = 4, exc= 7
# Build time: 9.963 	 | 	 Solution time: 1.334
# N_1 = 3, N_2 = 3, exc= 6
# Build time: 2.705 	 | 	 Solution time: 0.085
# N_1 = 2, N_2 = 2, exc= 5
# Build time: 0.524 	 | 	 Solution time: 0.004
# The operators took 82.1428191662 and have dimension 216.
# Building the RC Liouvillian took 88.584 seconds.
# ****************************************************************
# It is 46656by46656. The full basis would be 65536by65536
# Full optical Liouvillian took 74.5298418999 seconds.
# N_1 = 8, N_2 = 8, exc= 10
# Build time: 168.497 	 | 	 Solution time: 820.446
# N_1 = 7, N_2 = 7, exc= 9
# Build time: 102.043 	 | 	 Solution time: 351.583
# N_1 = 6, N_2 = 6, exc= 8
# Build time: 56.869 	 | 	 Solution time: 98.977
# N_1 = 5, N_2 = 5, exc= 7
# Build time: 26.569 	 | 	 Solution time: 22.302
# N_1 = 4, N_2 = 4, exc= 6
# Build time: 10.782 	 | 	 Solution time: 2.380
# N_1 = 3, N_2 = 3, exc= 5
# Build time: 3.114 	 | 	 Solution time: 0.194
# N_1 = 2, N_2 = 2, exc= 4
# Build time: 0.664 	 | 	 Solution time: 0.003
# The operators took 75.6549220085 and have dimension 196.
# Building the RC Liouvillian took 80.799 seconds.
# ****************************************************************
# It is 38416by38416. The full basis would be 65536by65536
# Full optical Liouvillian took 67.2054109573 seconds.
# N_1 = 8, N_2 = 8, exc= 9
# Build time: 151.982 	 | 	 Solution time: 269.184
# N_1 = 7, N_2 = 7, exc= 8
# Build time: 65.658 	 | 	 Solution time: 80.574
# N_1 = 6, N_2 = 6, exc= 7
# Build time: 34.834 	 | 	 Solution time: 25.155
# N_1 = 5, N_2 = 5, exc= 6
# Build time: 17.190 	 | 	 Solution time: 6.803
# N_1 = 4, N_2 = 4, exc= 5
# Build time: 7.328 	 | 	 Solution time: 1.723
# N_1 = 3, N_2 = 3, exc= 4
# Build time: 2.408 	 | 	 Solution time: 0.068
# N_1 = 2, N_2 = 2, exc= 3
# Build time: 0.456 	 | 	 Solution time: 0.003
# The operators took 40.5044767857 and have dimension 172.
# Building the RC Liouvillian took 42.976 seconds.
# ****************************************************************
# It is 29584by29584. The full basis would be 65536by65536
# Full optical Liouvillian took 42.8829271793 seconds.
# N_1 = 8, N_2 = 8, exc= 8
# Build time: 88.766 	 | 	 Solution time: 226.041
# N_1 = 7, N_2 = 7, exc= 7
# Build time: 54.047 	 | 	 Solution time: 84.926
# N_1 = 6, N_2 = 6, exc= 6
# Build time: 28.058 	 | 	 Solution time: 27.004
# N_1 = 5, N_2 = 5, exc= 5
# Build time: 13.684 	 | 	 Solution time: 4.880
# N_1 = 4, N_2 = 4, exc= 4
# Build time: 6.126 	 | 	 Solution time: 0.518
# N_1 = 3, N_2 = 3, exc= 3
# Build time: 2.125 	 | 	 Solution time: 0.046
# N_1 = 2, N_2 = 2, exc= 2
# Build time: 0.503 	 | 	 Solution time: 0.003
# Files saved at DATA/heatmap_excvN_2

# %% [markdown]
# # Plotting methods

# %%
def steadystate_observable(ss_array, PARAMS, observable):
    try:
        size = (len(PARAMS['y_values']), len(PARAMS['x_values']))
    except KeyError:
        size = (1,1)
    # deal with the case where N is being changed as an x value
    if 'N_1' in PARAMS['x_axis_parameters']:
        data_array = np.zeros(size)         # Collect data
        N_values = PARAMS['x_values']
        # NEw observable operator for each N value
        for i, N in enumerate(N_values):
            PARAMS.update({'N_1' : N, 'N_2' : N})
            exc = N+PARAMS['exc_diff']
            # Leave it so exc can be fixed or a y_parameter
            if 'exc' in PARAMS['x_axis_parameters']:
                PARAMS.update({'exc': exc})
            _obs_op = make_expectation_operators(PARAMS)[observable]
            for j, y in enumerate(PARAMS['y_values']):
                # the case where exc is on the y axis
                if 'exc_diff' in PARAMS['y_axis_parameters']:
                    PARAMS.update({'exc': N+y})
                    _obs_op = make_expectation_operators(PARAMS)[observable]
                try:
                    print ss_array[j][i].shape, _obs_op.shape
                    data_array[j][i] = (qt.Qobj(ss_array[j][i])*_obs_op).tr().real
                except AttributeError:
                    data_array[j][i] = np.nan
        return data_array
    else:
        # Much simpler if N isn't on the x-axis
        obs_op = make_expectation_operators(PARAMS)[observable]
        f = lambda x: (qt.Qobj(x)*obs_op).tr()
        ss_array = np.reshape(ss_array, (1, size[0]*size[1]))[0]

        data_array = map(f, ss_array)
        data_array = np.array(data_array).reshape(size).real
        return data_array


def heatmap_plotter(num, plot_SD=True, dir_name="heatmap", 
                     print_params=False, observable='sigma_x', 
                    reverse_x=True):
    
    directory = 'DATA/'+dir_name+'_'+str(num)
    ss_array = load_obj(directory+'/ss_array')
    PARAMS = load_obj(directory+'/PARAMS')
    info_array = load_obj(directory+'/info_array') # reverse ordering -> lower_N-higher_N
    info = info_array[0][0]
    
    try:
        # To catch an old bug where these were in "info" not in PARAMS
        keys = ['x_values', 'y_values', 'y_axis_parameters', 'x_axis_parameters']
        PARAMS.update(dict((key, info[key]) for key in keys))
    except Exception as err:
        print "new style"
    if plot_SD:
        plot_UD_SD(PARAMS["Gamma_1"], PARAMS["alpha_1"], PARAMS["w0_1"], eps=2000.)
    
    ss_array = steadystate_observable(ss_array, PARAMS, observable)

    
    f, axes = plt.subplots(1,1, figsize=(13,6))
    for i, y_val in enumerate(PARAMS['y_values']):
        x_values = PARAMS['x_values']
        if reverse_x:
            x_values = x_values[::-1]
        axes.plot(x_values, ss_array[i], 
                  label=str(PARAMS['y_axis_parameters'])+"="+str(y_val))
    
    print_PARAMS(PARAMS)
    
    plt.xlabel(', '.join(PARAMS['x_axis_parameters']))
    plt.ylabel("Steadystate "+observable)
    #plt.ylabel(', '.join(info['y_axis_parameters']))
    plt.legend()
    plt.grid()
    plot_filename = 'PLOTS/'+dir_name+'_'+str(num)+'.pdf'
    plt.savefig(plot_filename)
    print "saved at {}".format(plot_filename)
    plt.show()

# %%
heatmap_plotter(2, plot_SD=False, dir_name='heatmap_excvN', 
                     print_params=False, observable='sigma_x', 
                    reverse_x=True)
# Out:
# new style
# (216, 216) (216, 216)
# (196, 196) (196, 196)
# (172, 172) (172, 172)
# (192, 192) (192, 192)
# (184, 184) (184, 184)
# (172, 172) (172, 172)
# (156, 156) (156, 156)
# (136, 136) (136, 136)
# (144, 144) (144, 144)
# (140, 140) (140, 140)
# (132, 132) (132, 132)
# (120, 120) (120, 120)
# (104, 104) (104, 104)
# (100, 100) (100, 100)
# (100, 100) (100, 100)
# (96, 96) (96, 96)
# (88, 88) (88, 88)
# (76, 76) (76, 76)
# (64, 64) (64, 64)
# (64, 64) (64, 64)
# (64, 64) (64, 64)
# (60, 60) (60, 60)
# (52, 52) (52, 52)
# (36, 36) (36, 36)
# (36, 36) (36, 36)
# (36, 36) (36, 36)
# (36, 36) (36, 36)
# (32, 32) (32, 32)
# (16, 16) (16, 16)
# (16, 16) (16, 16)
# (16, 16) (16, 16)
# (16, 16) (16, 16)
# (16, 16) (16, 16)
# kappa_2=97.08, kappa_1=97.08, T_EM=6000.00, bias=100.00, alpha_2=20.00, alpha_1=20.00, T_2=300.00, T_1=300.00, Gamma_1=200.00, Gamma_2=200.00, mu=0.99, w_1=8100.00, w0_1=300.00, w0_2=300.00, V=100.00, w_2=8000.00, dipole_2=1.00, dipole_1=1.00, exc=2.00, alpha_EM=0.10, shift2=31.42, shift1=31.42, w_xx=16100.00, gamma_1=0.11, gamma_2=0.11
# saved at PLOTS/heatmap_excvN_2.pdf

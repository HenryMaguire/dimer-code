# %%
# %matplotlib inline 
import matplotlib
import matplotlib.pyplot as plt

import time
import heatmap_setup as hm
import numpy as np

from SES_setup import *
from utils import *
from style import *
# Out:
# SES_setup loaded globally

# %%
plt.style.use('ggplot')
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.edgecolor"] = "0.15"
plt.rcParams["axes.linewidth"]  = 1.5
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['font.size'] = 18
plt.rcParams['legend.fontsize'] = 'medium'
plt.rcParams['figure.titlesize'] = 'medium'
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'
plt.rc('text', usetex=True)
plt.rc('text.latex', preamble=r'\usepackage{amsmath} \usepackage{physics} ')
colours = ['#1E90FF', '#3CB371', '#FFA500', '#FF0000']

# %%
def calculate_expval(rho_list, op_list, obs='OO'):
    return [(op_list[i][obs]*rho).tr() for i, rho in enumerate(rho_list)]

def plot_dynamics(data_dict, figname="PLOTS/nothing.pdf"):
    PARAMS = data_dict['PARAMS']
    # code goes here to take in and plot dynamics for wc, add and non-add
    phonons = 1000*data_dict['phonons']/ev_to_inv_cm
    colours = [ '#3CB371',  '#FF0000', '#1E90FF',  '#FFA500']
    #labels = ['wc shift','s', 'Redfield', 'Add. Shift', 'Add.', 'Non-add.']
    labels = ['Redfield', 'CCME']
    f, ((ax1, ax2),(ax3, ax4))  = plt.subplots(2, 2, sharex=True, figsize=(14,8))
    # ['_add_shift', '_wc_shift', '_wcs']
    for i, suff in enumerate(['_wc', '_nonadd']):
        if suff in ['_wc_shift', '_wc', '_wcs']:
            alpha=1
            ls='solid'
            op_list = [make_expectation_operators(PARAMS, weak_coupling=True, shift=True)]*len(phonons)
        else:
            op_list =data_dict['op_list']
            alpha=1
            #ls='dotted'
        #GS pop
        ax1.plot(phonons, calculate_expval(data_dict['rho'+suff], op_list, obs='OO'), 
                 label=labels[i], alpha=alpha, ls=ls, color=colours[i])
        ax1.set_ylabel(r"$\rho_{g}^{ss}$")
        ax1.set_xlim(phonons[0], phonons[-1])
        ax1.legend()
        #DS pop
        ax2.plot(phonons, calculate_expval(data_dict['rho'+suff], op_list, obs='dark'), 
                 label=labels[i], alpha=alpha, ls=ls, color=colours[i])
        ax2.set_xlim(phonons[0], phonons[-1])
        ax2.set_ylabel(r"$\rho_{-}^{ss}$")
        ax2.legend()
        
        ax3.plot(phonons, calculate_expval(data_dict['rho'+suff], op_list, obs='bright'), 
                 label=labels[i], alpha=alpha, ls=ls, color=colours[i])
        ax3.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(meV)$")
        ax3.set_ylabel(r"$\rho_{+}^{ss}$")
        ax3.set_xlim(phonons[0], phonons[-1])
        ax3.legend()
        eig = np.array(calculate_expval(data_dict['rho'+suff],
                               op_list, obs='eig_x'))+ np.array(calculate_expval(data_dict['rho'+suff], 
                                                                      op_list, obs='eig_y'))
        ax4.plot(phonons, np.abs(eig), 
                 label=labels[i], alpha=alpha, ls=ls, color=colours[i])
        ax4.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(meV)$")
        ax4.set_ylabel(r"$|\rho_{+-}^{ss}|$")
        if sum(np.abs(eig))<1e-10:
            ax4.set_ylim(-1e-2, 1e-2)
        #ax4.set_ylabel(r"$\Re \langle\{+\rangle\!\langle -|\rangle$")
        ax4.set_xlim(phonons[0], phonons[-1])
        ax4.legend()
    #ax1.plot(phonons, calculate_expval(data_dict['rho_add'], op_list, obs='OO'), 
    #                 alpha=alpha, ls='dashed', color=colours[1])
    #ax2.plot(phonons, calculate_expval(data_dict['rho'+suff], op_list, obs='dark'), 
    #                alpha=alpha, ls='dashed', color=colours[1])
    #ax3.plot(phonons, calculate_expval(data_dict['rho'+suff], op_list, obs='bright')
    #             , alpha=alpha, ls='dashed', color=colours[1])
    #ax4.plot(phonons, np.abs(eig), alpha=alpha, ls='dashed', color=colours[1])
    plt.subplots_adjust(left=0.09, bottom=0.1, right=0.98, top=0.9, wspace=0.23, hspace=0.08)
    plt.savefig(figname)
    print(figname)

# %%
def calculate_WC_steadystate_comparison(phonons, PARAMS, num, threshold=0.):
    ti =time.time()
    rho_nonadd = []
    rho_wc = []
    op_list = []
    for j, alpha in enumerate(phonons):
        #PARAMS = get_converged_N(PARAMS, err_threshold=5., min_N=3,max_N=11, silent=True, exc_diff_N=False)
        
        PARAMS.update({'alpha_1':alpha, 'alpha_2': alpha})
        #energies, states = exciton_states(PARAMS)
        H, L, PARAMS = get_H_and_L(PARAMS,silent=True, threshold=0.)
        H_wc, L_ns, L_s = get_H_and_L_wc(PARAMS['H_sub'], PARAMS, silent=False, tol=1e-6)
        rho_nonadd.append(steadystate(H[1], [L['nonadd']]))
        rho_wc.append(steadystate(H[0], [L_ns])) # shift in wc LVN
        op_list.append(make_expectation_operators(PARAMS))
        if j in [1,10,20,30,40,49]:
            print(alpha)
        #print ss.diag()
    data_dict = {}
    filename = 'DATA/WC_validity_ss/3ls_{}'.format(num)
    PARAM_names = ['rho_nonadd', #'rho_add', 
                   'rho_wc', 'op_list', 'phonons', 'PARAMS']
    scope = locals() # Lets eval below use local variables, not global
    data_dict.update(dict((name, eval(name, scope)) for name in PARAM_names))
    print("Calculation took {} seconds".format(time.time()-ti))
    try:
        save_obj(data_dict, filename)
        print( "Filename: "+filename)
    except Exception as e:
        print("Could not save file because: {}".format(e))
    return data_dict

# %%
# # Fig 1.11 RATE MODEL 
# DS protection regime

N=6 # Change to 5
T_ph = 300.
w_2 = 1.4*ev_to_inv_cm
bias = 15*1e-3*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 15*1e-3*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 1.
T_EM = 5800.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3

eta = gap(bias, V)
w0 = 5*eta # 
wc = eta/2
Gamma = (w0**2)/wc
plot_UD_SD(Gamma, 10, w0, eps=5*eta)

phonons = np.logspace(-1, 1, 20)

PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w0,
                      silent=True, exc_diff=0)

data_dict_RM = calculate_WC_steadystate_comparison(phonons, PARAMS, 0, threshold=0.)

# %%
plot_dynamics(data_dict_RM, figname="PLOTS/RM-test.pdf")

# %%
# # Fig 1.11 RATE MODEL 30K
# DS protection regime

N=4 # Change to 5
T_ph = 30
w_2 = 1.4*ev_to_inv_cm
bias = 15*1e-3*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 15*1e-3*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 1.
T_EM = 5800.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3

eta = gap(bias, V)
w0 = 5*eta # 
wc = eta
Gamma = (w0**2)/wc
plot_UD_SD(Gamma, 10, w0, eps=5*eta)

phonons = np.logspace(-1, 1, 20)

PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w0,
                      silent=True, exc_diff=0)

data_dict_RM30 = calculate_WC_steadystate_comparison(phonons, PARAMS, 30, threshold=0.)

# %%
# # Fig 1.11 RATE MODEL 101K
# DS protection regime

N=4 # Change to 5
T_ph = 101
w_2 = 1.4*ev_to_inv_cm
bias = 15*1e-3*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 15*1e-3*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 1.
T_EM = 5800.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3

eta = gap(bias, V)
w0 = 5*eta # 
wc = eta/2
Gamma = (w0**2)/wc
plot_UD_SD(Gamma, 10, w0, eps=5*eta)

phonons = np.logspace(-1, 1, 20)

PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w0,
                      silent=True, exc_diff=0)

data_dict_RM2 = calculate_WC_steadystate_comparison(phonons, PARAMS, 101, threshold=0.)
# Out:
# Full optical Liouvillian took 0.012724876403808594 seconds.
# It took 0.01603388786315918 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 23.388367891311646 seconds
# Full optical Liouvillian took 0.013081073760986328 seconds.
# It took 0.016858816146850586 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 24.75638508796692 seconds
# 0.12742749857031338
# Full optical Liouvillian took 0.013169288635253906 seconds.
# It took 0.015905141830444336 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 24.019423007965088 seconds
# Full optical Liouvillian took 0.012764930725097656 seconds.
# It took 0.01605820655822754 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 27.525926113128662 seconds
# Full optical Liouvillian took 0.015246152877807617 seconds.
# It took 0.01920485496520996 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 32.55597424507141 seconds
# Full optical Liouvillian took 0.014194011688232422 seconds.
# It took 0.017548084259033203 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 39.49296498298645 seconds
# Full optical Liouvillian took 0.012534141540527344 seconds.
# It took 0.015636920928955078 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 41.884796142578125 seconds
# Full optical Liouvillian took 0.012569189071655273 seconds.
# It took 0.015735864639282227 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 35.39685606956482 seconds
# Full optical Liouvillian took 0.01234292984008789 seconds.
# It took 0.016928672790527344 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 39.37828493118286 seconds
# Full optical Liouvillian took 0.01288914680480957 seconds.
# It took 0.016889095306396484 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 42.48225927352905 seconds
# Full optical Liouvillian took 0.012495040893554688 seconds.
# It took 0.01586294174194336 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 42.03387999534607 seconds
# 1.1288378916846888
# Full optical Liouvillian took 0.013494014739990234 seconds.
# It took 0.02830815315246582 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 57.17571496963501 seconds
# Full optical Liouvillian took 0.012609004974365234 seconds.
# It took 0.015418767929077148 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 55.22601389884949 seconds
# Full optical Liouvillian took 0.012497186660766602 seconds.
# It took 0.015735864639282227 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 53.00846004486084 seconds
# Full optical Liouvillian took 0.012778043746948242 seconds.
# It took 0.022114038467407227 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 57.9605131149292 seconds
# Full optical Liouvillian took 0.011123895645141602 seconds.
# It took 0.015471696853637695 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 53.9872350692749 seconds
# Full optical Liouvillian took 0.01470184326171875 seconds.
# It took 0.017464876174926758 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 75.25841975212097 seconds
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-bdb40eee143a> in <module>()
#      25                       silent=True, exc_diff=0)
#      26
# ---> 27 data_dict_RM2 = calculate_WC_steadystate_comparison(phonons, PARAMS, 101, threshold=0.)
#
# <ipython-input-5-0a67a8cf4762> in calculate_WC_steadystate_comparison(phonons, PARAMS, num, threshold)
#      10         #energies, states = exciton_states(PARAMS)
#      11         H, L, PARAMS = get_H_and_L(PARAMS,silent=True, threshold=0.)
# ---> 12         H_wc, L_ns, L_s = get_H_and_L_wc(PARAMS['H_sub'], PARAMS, silent=False, tol=1e-6)
#      13         rho_nonadd.append(steadystate(H[1], [L['nonadd']]))
#      14         rho_wc.append(steadystate(H[0], [L_ns])) # shift in wc LVN
#
# ~/Work/phd-work/dimer-code/SES_setup.py in get_H_and_L_wc(H, PARAMS, silent, secular_phonon, shift, tol)
#     288     imp.reload(opt)
#     289     ti = time.time()
# --> 290     L_s = wp.weak_phonon(H, PARAMS, secular=secular_phonon, tol=tol)
#     291     L_ns = copy.deepcopy(L_s)
#     292     mu = PARAMS['mu']
#
# ~/Work/phd-work/dimer-code/weak_phonons.py in weak_phonon(H_sub, PARAMS, secular, shift, tol)
#     129                         principal=True, silent=True, alpha=PARAMS['alpha_'+str(i+1)]) # need principal value parts
#     130             L+= L_"""
# --> 131     L = L_wc_analytic(PARAMS, shift=shift, tol=tol)
#     132     return L
#     133
#
# ~/Work/phd-work/dimer-code/weak_phonons.py in L_wc_analytic(PARAMS, shift, tol)
#     245     G_0 = G(0.)
#     246     G_p = G(eta)
# --> 247     G_m = G(-eta)
#     248
#     249     Z_2 = (0.5/eta)*(G_0*((eta-epsilon)*bright_proj + (eta+epsilon)*dark_proj) - 2*V*(ct_p*G_p + ct_m*G_m))
#
# ~/Work/phd-work/dimer-code/weak_phonons.py in <lambda>(x)
#     241     G = (lambda x: (DecayRate(x, beta_f(PARAMS['T_2']), _J_underdamped,
#     242                         PARAMS['Gamma_2'], PARAMS['w0_2'], imag_part=True,
# --> 243                         alpha=PARAMS['alpha_2'], tol=tol)))
#     244     site_2 = (0.5/eta)*((eta-epsilon)*bright_proj + (eta+epsilon)*dark_proj - 2*V*cross_term)
#     245     G_0 = G(0.)
#
# ~/Work/phd-work/dimer-code/weak_phonons.py in DecayRate(omega, beta, J, Gamma, w0, imag_part, alpha, tol)
#      76         if imag_part:
#      77             G += (1j/2.)*integral_converge(F_m, 0,-abs(omega), tol=tol)
# ---> 78             G -= (1j/2.)*integral_converge(F_p, 0,abs(omega), tol=tol)
#      79         #print integrate.quad(F_m, 0, n, weight='cauchy', wvar=-abs(omega)), integrate.quad(F_p, 0, n, weight='cauchy', wvar=abs(omega))
#      80     return G
#
# TypeError: unsupported operand type(s) for *: 'complex' and 'NoneType'

# %%
plot_dynamics(data_dict_RM2, figname="PLOTS/RM-test1.pdf")
# Out:
# /Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/numpy/core/numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# PLOTS/RM-test1.pdf

# %%
# Figure 1.8
# DS protection regime
N_phonons = 90
N=5 # Change to 5
T_ph = 300.
w_2 = 1.4*ev_to_inv_cm
bias = 15*1e-3*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 15*1e-3*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 1.
T_EM = 5800.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3

eta = gap(bias, V)
w0 = 5*eta # 
wc = eta/2
Gamma = (w0**2)/wc
plot_UD_SD(Gamma, 10, w0, eps=5*eta)

phonons = np.linspace(1e-5, 15e-3, N_phonons)*ev_to_inv_cm

PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w0,
                      silent=True, exc_diff=0)

data_dict_1 = calculate_WC_steadystate_comparison(phonons, PARAMS, 1, threshold=0.)
# Out:
# Full optical Liouvillian took 0.01403498649597168 seconds.
# It took 0.01710200309753418 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 26.946083068847656 seconds
# Full optical Liouvillian took 0.013713836669921875 seconds.
# It took 0.01873922348022461 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in
seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 165.20654392242432 seconds
# Full optical Liouvillian took 0.010684967041015625 seconds.
# It took 0.013350963592529297 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 166.6773099899292 seconds
# Full optical Liouvillian took 0.009878873825073242 seconds.
# It took 0.013779163360595703 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 166.74382519721985 seconds
# Calculation took 15239.61400604248 seconds
# Filename: DATA/WC_validity_ss/3ls_1

# %%
plot_dynamics(data_dict_1, figname="PLOTS/steadystates-overdamped-aug.pdf")
# Out:
# /Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/numpy/core/numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# PLOTS/steadystates-overdamped-aug.pdf

# %%
# Figure 1.8 b

T_ph = 300.
w_2 = 1.4*ev_to_inv_cm
bias = 15*1e-3*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 25*1e-3*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 1.
T_EM = 5800.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3

eta = gap(bias, V)
w0 = 5*eta # 
wc = eta
Gamma = (w0**2)/wc
plot_UD_SD(Gamma, 10, w0, eps=5*eta)

phonons = np.linspace(1e-5, 15e-3, N_phonons)*ev_to_inv_cm

PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w0,
                      silent=True, exc_diff=0)

data_dict_1b = calculate_WC_steadystate_comparison(phonons, PARAMS, 2, threshold=0.)

plot_dynamics(data_dict_1b, figname="PLOTS/steadystates-overdamped-2-aug.pdf")
# Out:
# Full optical Liouvillian took 0.008879899978637695 seconds.
# It took 0.013065099716186523 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 15.332871913909912 seconds
# Full optical Liouvillian took 0.009160995483398438 seconds.
# It took 0.019194841384887695 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 50.64271521568298 seconds
# 2.548039591836735
# Full optical Liouvillian took 0.012460947036743164 seconds.
# It took 0.018737316131591797 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 73.78934407234192 seconds
# Full optical Liouvillian took 0.013761043548583984 seconds.
# It took 0.018239974975585938 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 84.15638995170593 seconds
# Full optical Liouvillian took 0.012434959411621094 seconds.
# It took 0.02619004249572754 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 90.0090708732605 seconds
# Full optical Liouvillian took 0.00950765609741211 seconds.
# It took 0.013443946838378906 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 91.26001310348511 seconds
# Full optical Liouvillian took 0.009680986404418945 seconds.
# It took 0.01297616958618164 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 85.15352201461792 seconds
# Full optical Liouvillian took 0.019247055053710938 seconds.
# It took 0.024371862411499023 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 101.72697973251343 seconds
# Full optical Liouvillian took 0.01404881477355957 seconds.
# It took 0.018489837646484375 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 126.26382303237915 seconds
# Full optical Liouvillian took 0.017145872116088867 seconds.
# It took 0.017262935638427734 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 130.43975496292114 seconds
# Full optical Liouvillian took 0.014038801193237305 seconds.
# It took 0.01817488670349121 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 133.68412017822266 seconds
# 24.754500918367345
# Full optical Liouvillian took 0.012794256210327148 seconds.
# It took 0.026824951171875 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 128.2478530406952 seconds
# Full optical Liouvillian took 0.013992786407470703 seconds.
# It took 0.019782066345214844 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 137.84077501296997 seconds
# Full optical Liouvillian took 0.011928796768188477 seconds.
# It took 0.016428232192993164 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 128.70388770103455 seconds
# Full optical Liouvillian took 0.013051033020019531 seconds.
# It took 0.02815079689025879 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 130.71313190460205 seconds
# Full optical Liouvillian took 0.012395858764648438 seconds.
# It took 0.015529155731201172 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 145.03360891342163 seconds
# Full optical Liouvillian took 0.0132598876953125 seconds.
# It took 0.01986098289489746 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 151.27943778038025 seconds
# Full optical Liouvillian took 0.009347915649414062 seconds.
# It took 0.012716054916381836 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 135.44389510154724 seconds
# Full optical Liouvillian took 0.009235143661499023 seconds.
# It took 0.012722969055175781 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in
seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 130.75587677955627 seconds
# Full optical Liouvillian took 0.011754989624023438 seconds.
# It took 0.015974998474121094 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 131.14626908302307 seconds
# Full optical Liouvillian took 0.011723041534423828 seconds.
# It took 0.01609492301940918 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 132.09295010566711 seconds
# 120.9825
# Calculation took 5661.6410031318665 seconds
# Filename: DATA/WC_validity_ss/3ls_3
# /Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/numpy/core/numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# PLOTS/steadystates-overdamped-3-aug.pdf

# %%
# Figure 1.9. Zero bias, could be useful to show that DS protection stops as does eigenstate coherence.

T_ph = 300.
w_2 = 1.4*ev_to_inv_cm
N_phonons = 40
bias = 0*1e-3*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 15*1e-3*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 1.
T_EM = 5800.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3

eta = gap(bias, V)
w0 = 5*eta # 
wc = eta/2
Gamma = (w0**2)/wc
plot_UD_SD(Gamma, 10, w0, eps=5*eta)

phonons = np.linspace(1e-5, 15e-3, N_phonons)*ev_to_inv_cm

PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w0,
                      silent=True, exc_diff=0)

data_dict_2 = calculate_WC_steadystate_comparison(phonons, PARAMS, 4, threshold=0.)
# Out:
# Full optical Liouvillian took 0.009344816207885742 seconds.
# It took 0.01305079460144043 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 14.547940015792847 seconds
# Full optical Liouvillian took 0.009335994720458984 seconds.
# It took 0.012848854064941406 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 45.94931983947754 seconds
# 3.180702307692308
# Full optical Liouvillian took 0.00995182991027832 seconds.
# It took 0.013195037841796875 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 58.11358094215393 seconds
# Full optical Liouvillian took 0.009219169616699219 seconds.
# It took 0.01563096046447754 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 65.38247585296631 seconds
# Full optical Liouvillian took 0.009873151779174805 seconds.
# It took 0.013277053833007812 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 71.84124994277954 seconds
# Full optical Liouvillian took 0.009274005889892578 seconds.
# It took 0.012689828872680664 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 77.30541324615479 seconds
# Full optical Liouvillian took 0.009626150131225586 seconds.
# It took 0.016750812530517578 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 82.4696741104126 seconds
# Full optical Liouvillian took 0.00921320915222168 seconds.
# It took 0.01265096664428711 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 84.03694105148315 seconds
# Full optical Liouvillian took 0.009357213973999023 seconds.
# It took 0.013569831848144531 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 90.40792608261108 seconds
# Full optical Liouvillian took 0.00981903076171875 seconds.
# It took 0.01730489730834961 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 92.82929706573486 seconds
# Full optical Liouvillian took 0.009332895278930664 seconds.
# It took 0.012763261795043945 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 95.67318820953369 seconds
# 31.08112807692308
# Full optical Liouvillian took 0.009265899658203125 seconds.
# It took 0.012754201889038086 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 99.96084928512573 seconds
# Full optical Liouvillian took 0.009773015975952148 seconds.
# It took 0.013721942901611328 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 102.29270458221436 seconds
# Full optical Liouvillian took 0.009929180145263672 seconds.
# It took 0.015495061874389648 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 103.10584688186646 seconds
# Full optical Liouvillian took 0.009308099746704102 seconds.
# It took 0.012723207473754883 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 107.38142895698547 seconds
# Full optical Liouvillian took 0.009304046630859375 seconds.
# It took 0.013651847839355469 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 111.19803404808044 seconds
# Full optical Liouvillian took 0.009749174118041992 seconds.
# It took 0.018500089645385742 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 112.40273308753967 seconds
# Full optical Liouvillian took 0.011282205581665039 seconds.
# It took 0.01402592658996582 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 113.51939010620117 seconds
# Full optical Liouvillian took 0.009329795837402344 seconds.
# It took 0.013048887252807617 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 115.5555899143219 seconds
# Full optical Liouvillian took 0.009457826614379883 seconds.
# It took 0.01651477813720703 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 119.07439422607422 seconds
# Full optical Liouvillian took 0.009300947189331055 seconds.
# It took 0.012734174728393555 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 121.5047390460968 seconds
# 62.08160115384615
# Full optical Liouvillian took 0.00922703742980957 seconds.
# It took 0.012827157974243164 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 124.93330693244934 seconds
# Full optical Liouvillian took 0.009686946868896484 seconds.
# It took 0.01822495460510254 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 124.63396286964417 seconds
# Full optical Liouvillian took 0.009937763214111328 seconds.
# It took 0.013795137405395508 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 125.56162214279175 seconds
# Full optical Liouvillian took 0.009298086166381836 seconds.
# It took 0.012813091278076172 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 127.18515992164612 seconds
# Full optical Liouvillian took 0.010232210159301758 seconds.
# It took 0.01777482032775879 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 129.60766077041626 seconds
# Full optical Liouvillian took 0.009751081466674805 seconds.
# It took 0.016067981719970703 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 129.16163682937622 seconds
# Full optical Liouvillian took 0.009289979934692383 seconds.
# It took 0.01428365707397461 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 132.97769117355347 seconds
# Full optical Liouvillian took 0.009860992431640625 seconds.
# It took 0.013215065002441406 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 132.63077974319458 seconds
# Full optical Liouvillian took 0.009289026260375977 seconds.
# It took 0.015607595443725586 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 135.51018285751343 seconds
# Full optical Liouvillian took 0.009465694427490234 seconds.
# It took 0.013553857803344727 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 137.54566287994385 seconds
# 93.08207423076924
# Full optical Liouvillian took 0.009289026260375977 seconds.
# It took 0.013475179672241211 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 136.3740758895874 seconds
# Full optical Liouvillian took 0.009285926818847656 seconds.
# It took 0.01599597930908203 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 140.37283992767334 seconds
# Full optical Liouvillian took 0.009615898132324219 seconds.
# It took 0.013590097427368164 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 141.06162691116333 seconds
# Full optical Liouvillian took 0.009270906448364258 seconds.
# It took 0.013415336608886719 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 140.8521740436554 seconds
# Full optical Liouvillian took 0.009333133697509766 seconds.
# It took 0.012841939926147461 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 145.34794187545776 seconds
# Full optical Liouvillian took 0.00988006591796875 seconds.
# It took 0.014019012451171875 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 145.02590680122375 seconds
# Full optical Liouvillian took 0.009382009506225586 seconds.
# It took 0.014249801635742188 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 144.85861921310425 seconds
# Full optical Liouvillian took 0.009306907653808594 seconds.
# It took 0.01345515251159668 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 148.736328125 seconds
# Full optical Liouvillian took 0.009821891784667969 seconds.
# It took 0.018323898315429688 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 148.98067808151245 seconds
# Calculation took 4885.575854063034 seconds
# Filename: DATA/WC_validity_ss/3ls_4

# %%
plot_dynamics(data_dict_2, figname="PLOTS/steadystates-OD-zerobias-aug.pdf")
# Out:
# /Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/numpy/core/numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# PLOTS/steadystates-OD-zerobias-aug.pdf

# %%
# Figure 1.10
N_phonons = 70
T_ph = 300.
w_2 = 1.4*ev_to_inv_cm
bias = 15*1e-3*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 15*1e-3*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 1.
T_EM = 5800.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3

eta = gap(bias, V)
w0 = 5*eta # 
#wc = eta
Gamma = V
plot_UD_SD(Gamma, 10, w0, eps=5*eta)

phonons = np.linspace(1e-5, 15e-3, N_phonons)*ev_to_inv_cm

PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w0,
                      silent=True, exc_diff=0)

data_dict_3 = calculate_WC_steadystate_comparison(phonons, PARAMS, 1, threshold=0.)

plot_dynamics(data_dict_3, figname="PLOTS/steadystates-UD-high-aug.pdf")
# Out:
# Full optical Liouvillian took 0.009184837341308594 seconds.
# It took 0.013308048248291016 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in
seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 36.28588604927063 seconds
# Full optical Liouvillian took 0.009621143341064453 seconds.
# It took 0.016186237335205078 seconds to build the phenomenological Liouvillian
# WC non-secular and secular dissipators calculated in 36.517066955566406 seconds
# Calculation took 1146.7280361652374 seconds
# Filename: DATA/WC_validity_ss/3ls_1
# /Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/numpy/core/numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# PLOTS/steadystates-UD-high-aug.pdf

# %% [markdown]
# # 3LS-4LS comparison: 14/08/2019

# %%
def calculate_steadystates(phonons, PARAMS, threshold=0.):
    ti =time.time()
    rho_nonadd = []
    op_list = []
    for j, alpha in enumerate(phonons):
        PARAMS.update({'alpha_1':alpha, 'alpha_2': alpha})
        H, L, PARAMS = get_H_and_L(PARAMS,silent=True, threshold=0.)
        rho_nonadd.append(steadystate(H[1], [L['nonadd']]))
        op_list.append(make_expectation_operators(PARAMS))
        if j in [1,10,20,30,40,49]:
            print(alpha)
    data_dict = {}
    PARAM_names = ['rho_nonadd', 'op_list', 'phonons', 'PARAMS']
    scope = locals() # Lets eval below use local variables, not global
    data_dict.update(dict((name, eval(name, scope)) for name in PARAM_names))
    print("Calculation took {} seconds".format(time.time()-ti))
    return data_dict

# %%
# Figure 1.3, 1.4: run this with N=5
N=5
N_phonon = 35
T_ph = 300.
w_2 = 1.4*ev_to_inv_cm
bias = 0*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 15e-3*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 1.
T_EM = 5800.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3

eta = gap(bias, V)
w0 = 5*eta # 
wc = eta/2
Gamma = (w0**2)/wc
plot_UD_SD(Gamma, 10, w0, eps=5*eta)

PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                          V = V, alpha=alpha,
                          T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                          num_cpus=4, N=N, Gamma=Gamma, w_0=w0,
                          silent=True, exc_diff=0)

phonons = np.logspace(np.log10(1e-1), np.log10(20), 30)*ev_to_inv_cm

data_3LS_validity_1 = calculate_steadystates(phonons, PARAMS, threshold=0.)
save_obj(data_3LS_validity_1, 'DATA/SES_validity_ss/3LS_1')
# Out:
# 968.2269291773622
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2961, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-54-4c2aaff3ce46>", line 26, in <module>
#     data_3LS_validity_1 = calculate_steadystates(phonons, PARAMS, threshold=0.)
#   File "<ipython-input-15-386468a12719>", line 8, in calculate_steadystates
#     rho_nonadd.append(steadystate(H[1], [L['nonadd']]))
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/qutip/steadystate.py", line 290, in steadystate
#     return _steadystate_direct_sparse(A, ss_args)
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/qutip/steadystate.py", line 437, in _steadystate_direct_sparse
#     options=dict(ILU_MILU=ss_args['ILU_MILU']))
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/scipy/sparse/linalg/dsolve/linsolve.py", line 309, in splu
#     ilu=False, options=_options)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 1863, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/inspect.py", line 1495, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/inspect.py", line 1453, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 421, in execute_request
#     self._abort_queues()
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 636, in _abort_queues
#     self._abort_queue(stream)
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 661, in _abort_queue
#     poller.poll(50)
#   File "/Users/henrymaguire/.pyenv/versions/3.7.0/lib/python3.7/site-packages/zmq/sugar/poll.py", line 99, in poll
#     return zmq_poll(self.sockets, timeout=timeout)
#   File "zmq/backend/cython/_poll.pyx", line 123, in zmq.backend.cython._poll.zmq_poll
#   File "zmq/backend/cython/checkrc.pxd", line 12, in zmq.backend.cython.checkrc._check_rc
# KeyboardInterrupt

# %%
# Figure 1.3, 1.4: run this with N=5
N=5
N_phonon = 35
T_ph = 300.
w_2 = 1.4*ev_to_inv_cm
bias = 15e-3*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 15e-3*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 1.
T_EM = 5800.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3

eta = gap(bias, V)
w0 = 5*eta # 
wc = eta/2
Gamma = (w0**2)/wc
plot_UD_SD(Gamma, 10, w0, eps=5*eta)

PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                          V = V, alpha=alpha,
                          T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                          num_cpus=4, N=N, Gamma=Gamma, w_0=w0,
                          silent=True, exc_diff=0)

#phonons = np.linspace(1e-5, 15e-3, N_phonon)*ev_to_inv_cm
phonons = np.logspace(np.log10(1e-1), np.log10(20), 20)*ev_to_inv_cm/1000.

data_3LS_validity_1 = calculate_steadystates(phonons, PARAMS, threshold=0.)
save_obj(data_3LS_validity_1, 'DATA/SES_validity_ss/3LS_2')
# Out:
# 1.0659531993246736
# 13.112929138185077
# Calculation took 223.996572971344 seconds

# %%
np.logspace(np.log10(1e-1), np.log10(20), 20)*ev_to_inv_cm/1000
# Out:
# array([  0.80655   ,   1.0659532 ,   1.40878584,   1.86188058,
#          2.46069996,   3.25211208,   4.29805874,   5.68040353,
#          7.50733906,   9.92185492,  13.11292914,  17.33031897,
#         22.9041088 ,  30.27054498,  40.00617974,  52.87299645,
#         69.87804813,  92.35227695, 122.05468362, 161.31      ])

# %% [markdown]
# # Paper plots 27/02/2019

# %%
def calculate_WC_add_steadystate_comparison(PARAMS, num, threshold=0.):
    phonons = np.linspace(1e-5, 15e-3, 45)*ev_to_inv_cm
    ti =time.time()
    rho_add = []
    rho_add_shift = []
    rho_nonadd = []
    rho_wc = []
    rho_wc_shift = []
    rho_wcs = []
    op_list = []
    for j, alpha in enumerate(phonons):
        #PARAMS = get_converged_N(PARAMS, err_threshold=5., min_N=3,max_N=11, silent=True, exc_diff_N=False)
        
        PARAMS.update({'alpha_1':alpha, 'alpha_2': alpha})
        #energies, states = exciton_states(PARAMS)
        H, L, PARAMS = get_H_and_L(PARAMS,silent=True, threshold=0.)
        H_wc, L_ns, L_s = get_H_and_L_wc(PARAMS['H_sub'], PARAMS)
        #_, L_wc_shift, L_s_ = get_H_and_L_wc(H[0], PARAMS)
        #rho_add_shift.append(steadystate(H[1], [L['add-shift']]))
        #rho_add.append(steadystate(H[1], [L['add']]))
        rho_nonadd.append(steadystate(H[1], [L['nonadd']]))
        #rho_wc_shift.append(steadystate(H[0], [L_wc_shift])) # shift in wc LVN
        rho_wc.append(steadystate(H[0], [L_ns])) # shift in wc LVN
        #rho_wcs.append(steadystate(H[0], [L_s]))
        op_list.append(make_expectation_operators(PARAMS))
        if j in [1,10,20,30,40,49]:
            print(alpha)
        #print ss.diag()
    data_dict = {}
    filename = 'DATA/Gamma_w0_dep/3ls_{}'.format(num)
    PARAM_names = ['rho_nonadd', #'rho_add', 
                   'rho_wc', 'op_list', 'phonons', 'PARAMS']
    scope = locals() # Lets eval below use local variables, not global
    data_dict.update(dict((name, eval(name, scope)) for name in PARAM_names))
    print("Calculation took {} seconds".format(time.time()-ti))
    try:
        save_obj(data_dict, filename)
        print( "Filename: "+filename)
    except Exception as e:
        print("Could not save file because: {}".format(e))
    return data_dict

# %%
T_ph = 300.
w_2 = 1.4*ev_to_inv_cm
bias = 0. #0.01*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 10e-3*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 0.
T_EM = 6000.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =6
#wc = 50.
w_0 = 80e-3*ev_to_inv_cm
Gamma = 30e-3*ev_to_inv_cm

# %%
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=0)

data_dict_1_w2 = calculate_WC_add_steadystate_comparison(PARAMS, '1', threshold=1e-10)

# %% [markdown]
# # Population ratio data collection for plots 27/02/2019

# %%
#Omegas = np.array([ 30e-3, 60e-3, 120e-3])*ev_to_inv_cm
#Omegas = np.array([ 30*1e-3, 60*1e-3, 120*1e-3])*ev_to_inv_cm
#Omegas = np.array([20e-3, 30e-3, 40e-3])*ev_to_inv_cm
#Omegas = np.array([ 15e-3, 20e-3, 60e-3, 120e-3])*ev_to_inv_cm
#Omegas = np.array([100,200,300])

def plot_population_ratio(data_dict, label='0'):
    PARAMS = data_dict['PARAMS']
    ops = make_expectation_operators(PARAMS)
    pd = np.array([i.tr() for i in data_dict['rho_nonadd']*ops['dark']])
    pb = np.array([i.tr() for i in data_dict['rho_nonadd']*ops['bright']])
    pg = np.array([i.tr() for i in data_dict['rho_nonadd']*ops['OO']])
    #plt.plot(pd, label='DS')
    #plt.plot(pg, label='GS')
    #plt.legend()
    #plt.figure()
    plt.plot(((pd)/pg).real, label=label)
    plt.legend()

# %%
dd_list = []
#Omegas = np.array([ 30*1e-3, 60*1e-3, 120*1e-3])*ev_to_inv_cm
Omegas = np.array([ 40*1e-3, 80*1e-3, 120*1e-3])*ev_to_inv_cm
for w0 in Omegas:
    N=6
    T_ph = 100.
    w_2 = 1.4*ev_to_inv_cm
    bias = 0 #10e-3*ev_to_inv_cm #0.0000001*ev_to_inv_cm
    V = 10e-3*ev_to_inv_cm #0.00001*ev_to_inv_cm
    alpha = 1.
    T_EM = 6000.
    alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
    Gamma = 100
    PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w0,
                      silent=True, exc_diff=0)
    data_dict_ = calculate_WC_add_steadystate_comparison(PARAMS, str(int(w0)), threshold=0.)
    dd_list.append(data_dict_)
    plot_population_ratio(data_dict_, label=str(int(w0))+"_WV")

save_obj(dd_list, "DATA/population_ratio_comparison_2_b")
# Out:
# 5.0
# 45.5
# Calculation took 208.0560338497162 seconds
# Filename: DATA/Gamma_w0_dep/3ls_161
# 5.0
# 45.5
# Calculation took 229.50867700576782 seconds
# Filename: DATA/Gamma_w0_dep/3ls_241
# 5.0
# 45.5
# Calculation took 249.18489122390747 seconds
# Filename: DATA/Gamma_w0_dep/3ls_322

# %%
for w0 in Omegas:
    N=4
    T_ph = 77.
    w_2 = 1.4*ev_to_inv_cm
    bias = 0#10e-3*ev_to_inv_cm #0.0000001*ev_to_inv_cm
    V = 10e-3*ev_to_inv_cm #0.00001*ev_to_inv_cm
    alpha = 1.
    T_EM = 6000.
    alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
    Gamma = 200
    PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w0,
                      silent=True, exc_diff=0)
    data_dict_ = calculate_WC_add_steadystate_comparison(PARAMS, str(int(w0)), threshold=0.)
    plot_population_ratio(data_dict_, label=str(int(w0)))
# Out:
# 2.206896551724138
# 17.56896551724138
# 34.63793103448276
# Calculation took 351.2204270362854 seconds
# Filename: DATA/Gamma_w0_dep/3ls_241
# 2.206896551724138
# 17.56896551724138
# 34.63793103448276
# Calculation took 522.9552710056305 seconds
# Filename: DATA/Gamma_w0_dep/3ls_483
# 2.206896551724138
# 17.56896551724138
# 34.63793103448276
# Calculation took 760.1495380401611 seconds
# Filename: DATA/Gamma_w0_dep/3ls_967

# %%
N =8
#wc = 50.
w_0 = 30e-3*ev_to_inv_cm
Gamma = 30e-3*ev_to_inv_cm
#N=4
T_ph = 300.
w_2 = 1.4*ev_to_inv_cm
bias = 10e-3*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 10e-3*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 1.
T_EM = 6000.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=0)

data_dict_1_w1 = calculate_WC_add_steadystate_comparison(PARAMS, '1a-300', threshold=0.)
# Out:
# 1.625
# 11.75
# 23.0
# 34.25
# 45.5
# Calculation took 6637.964284896851 seconds
# Filename: DATA/Gamma_w0_dep/3ls_1a-300

# %%
N =7
#wc = 50.
w_0 = 60e-3*ev_to_inv_cm
Gamma = 30e-3*ev_to_inv_cm
#N=4
T_ph = 77.
w_2 = 1.4*ev_to_inv_cm
bias = 0*1e-3*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 10e-3*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 1.
T_EM = 6000.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3

# %%
N =8
#wc = 50.
w_0 = 60e-3*ev_to_inv_cm
Gamma = 30e-3*ev_to_inv_cm
#N=4
T_ph = 300.
w_2 = 1.4*ev_to_inv_cm
bias = 10e-3*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 10e-3*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 1.
T_EM = 6000.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3

#Gamma = 200

PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=0)

data_dict_1_w2 = calculate_WC_add_steadystate_comparison(PARAMS, '1b', threshold=0.)
# Out:
# 1.3389830508474576
# 8.889830508474576
# 17.279661016949152
# 25.66949152542373
# 34.059322033898304
# 41.610169491525426
# Calculation took 3659.2719819545746 seconds
# Filename: DATA/WC_validity_ss/3ls_1b

# %%
N =7
#wc = 50.
w_0 = 120e-3*ev_to_inv_cm
Gamma = 30e-3*ev_to_inv_cm

PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=0)

data_dict_1_w2 = calculate_WC_add_steadystate_comparison(PARAMS, '1c', threshold=0.)
# Out:
# 1.3389830508474576
# 8.889830508474576
# 17.279661016949152
# 25.66949152542373
# 34.059322033898304
# 41.610169491525426
# Calculation took 4394.735204935074 seconds
# Filename: DATA/WC_validity_ss/3ls_1c

# %%
240e-3*ev_to_inv_cm
# Out:
# 1935.72

# %%
N =6
#wc = 50.
w_0 = 240e-3*ev_to_inv_cm
Gamma = 30e-3*ev_to_inv_cm

PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=0)

data_dict_1_w2 = calculate_WC_add_steadystate_comparison(PARAMS, '1c', threshold=0.)
# Out:
# 1.625
# 11.75
# 23.0
# 34.25
# 45.5
# Calculation took 2475.9989070892334 seconds
# Filename: DATA/Gamma_w0_dep/3ls_1c

# %%
# plotting function to see excited state population as a function of alpha, each w0 on the plot

# %%
1000*5000/ev_to_inv_cm
# Out:
# 619.9243692269544

# %%
N =7
#wc = 50.
w_0 = 200.
Gamma = 1*w_0

PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                              V = V, alpha=alpha,
                              T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                              num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=0)

data_dict_1 = calculate_WC_add_steadystate_comparison(PARAMS, '1', threshold=0.)

# %%
data_dict_1 =load_obj("DATA/WC_validity_ss/3ls_1")

# %%
plot_dynamics(data_dict_1, figname='PLOTS/PAPER/Redfield-comparison-UD.pdf')
# Out:
# /Users/admin/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# PLOTS/PAPER/Redfield-comparison-UD.pdf

# %% [markdown]
# # larger $\omega_0$

# %%
w_0 = 500.
Gamma = 200.
N=6
alpha=10.
T_ph = 300.
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=0)

data_dict_2 = calculate_WC_add_steadystate_comparison(PARAMS, 2, threshold=0.)
# Out:
# 1.3389830508474576
# 8.889830508474576
# 17.279661016949152
# 25.66949152542373
# 34.059322033898304
# 41.610169491525426
# Calculation took 2944.7763431072235 seconds
# Filename: DATA/WC_validity_ss/3ls_2

# %%
def B_for_min_decay(PARAMS):
    Delta = PARAMS['V']*2
    eta = sqrt(Delta**2 + PARAMS['bias']**2)
    fp = sqrt(eta+PARAMS['bias'])
    fm = sqrt(eta-PARAMS['bias'])
    return (Delta/(2*PARAMS['bias']))*((4*PARAMS['bias']**2)/(Delta**2*PARAMS['mu']))*((fp+fm)/(fp-fm))
print(B_for_min_decay(PARAMS))
# Out:
# 4.2663256059105015

# %%
data_dict_2 =load_obj("DATA/WC_validity_ss/3ls_2")

# %%
plot_dynamics(data_dict_2)
# Out:
# /Users/admin/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # Low $T_{ph}$

# %%
w_0 = 200.
Gamma = 2*w_0 #200.

T_ph = 77.
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                              V = V, alpha=alpha,
                              T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                              num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=0)
data_dict_3 = calculate_WC_add_steadystate_comparison(PARAMS, 3, threshold=0.)

# %%
data_dict_3 =load_obj("DATA/WC_validity_ss/3ls_3")

# %%
plot_dynamics(data_dict_3)

# %% [markdown]
# # very high $\omega_0$ (underdamped), but not larger than site energy

# %%
w_0 = 5000.
Gamma = 200.
N=4
T_ph = 300.
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                              V = V, alpha=alpha,
                              T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                              num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=0)
data_dict_4 = calculate_WC_add_steadystate_comparison(PARAMS, 4, threshold=0.)
# Out:
# 1.3389830508474576
# 8.889830508474576
# 17.279661016949152
# 25.66949152542373
# 34.059322033898304
# 41.610169491525426
# Calculation took 8700.722556829453 seconds
# Filename: DATA/WC_validity_ss/3ls_4

# %%
data_dict_4 =load_obj("DATA/WC_validity_ss/3ls_4")

# %%
plot_dynamics(data_dict_4)
# Out:
# /Users/admin/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
print (beta_f(300), beta_f(77), beta_f(100), beta_f(150))

# %% [markdown]
# # Overdamped
#
# This case shows perfect dark state protection behaviour in Redfield case

# %%
w_2 = 1. * ev_to_inv_cm
bias = 0. # 10e-3 * ev_to_inv_cm
V = 10e-3 * ev_to_inv_cm
alpha = 10e-3 * ev_to_inv_cm
T_EM = 6000.
T_ph = 300.
Gamma_EM = 7e-7*ev_to_inv_cm # 1ns
#alpha_EM = 1e-2*inv_ps_to_inv_cm
eta = gap(bias, V)
wc = eta
w0 = 6*eta # 18e-3*ev_to_inv_cm
Gamma = (w0**2)/wc
print(eta, w0, Gamma, Occupation(w0, T_ph))
N=4
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=T_EM, T_ph=T_ph, alpha_EM=Gamma_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w0,
                      silent=True, exc_diff=0)
data_dict_5 = calculate_WC_add_steadystate_comparison(PARAMS, 'OD2-300', threshold=1e-8)
# Out:
# (161.31, 967.86, 5807.160000000001, 0.009732063035413449)
# 1.625
# 11.75
# 23.0
# 34.25
# 45.5
# Calculation took 7632.50700402 seconds
# Filename: DATA/Gamma_w0_dep/3ls_OD2-300

# %%
plot_dynamics(data_dict_5, "PLOTS/PAPER/SS-WC-overdamped-300.pdf")
# Out:
# PLOTS/PAPER/SS-WC-overdamped-300.pdf

# %%
(gap(15*1e-3*ev_to_inv_cm, 15*1e-3*ev_to_inv_cm), 0.695*300)
# Out:
# (270.5250940878683, 208.49999999999997)

# %%
plot_dynamics(data_dict_5, "PLOTS/PAPER/steadystates-overdamped-300.pdf")
# Out:
# /Users/admin/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# PLOTS/PAPER/steadystates-overdamped-300.pdf

# %%
N=5
T_ph = 300.
w_2 = 1.4*ev_to_inv_cm
bias = 15*1e-3*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 15e-3*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 1.
T_EM = 6000.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
w0 = 2000. # 
Gamma = (w0**2)/100
eta = gap(bias, V)
plot_UD_SD(Gamma, 10, w0, eps=2*eta)


PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w0,
                      silent=True, exc_diff=0)

data_dict_OD2 = calculate_WC_add_steadystate_comparison(PARAMS, 'OD-300-2', threshold=1e-8)
plot_dynamics(data_dict_OD2, "PLOTS/PAPER/steadystates-overdamped-300.pdf")
# Out:
# 1.625
# 11.75
# 23.0
# 34.25
# 45.5
# Calculation took 6323.620673894882 seconds
# Filename: DATA/Gamma_w0_dep/3ls_OD-300-2
# /Users/admin/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# PLOTS/PAPER/steadystates-overdamped-300.pdf

# %%
data_dict_7 =load_obj("DATA/Gamma_w0_dep/3ls_UD-300")
#save_obj(data_dict_5, )
plot_dynamics(data_dict_7, "PLOTS/PAPER/steadystates-overdamped-300.pdf")
# Out:
# /Users/admin/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# PLOTS/PAPER/steadystates-overdamped-300.pdf

# %%
#N=4
T_ph = 300.
w_2 = 1.4*ev_to_inv_cm
bias = 10e-3*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 10e-3*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 1.
T_EM = 6000.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
w0 = 2000. # 
Gamma = (w0**2)/100
eta = gap(bias, V)
plot_UD_SD(Gamma, 10, w0, eps=2*eta)

N=5

PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=T_EM, T_ph=T_ph, alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w0,
                      silent=True, exc_diff=0)
data_dict_5 = calculate_WC_add_steadystate_comparison(PARAMS, 5, threshold=1e-8)

# %%
data_dict_7 =load_obj("DATA/Gamma_w0_dep/3ls_5")
#save_obj(data_dict_5, )
plot_dynamics(data_dict_7, "PLOTS/PAPER/steadystates-overdamped-150.pdf")
# Out:
# /Users/admin/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# PLOTS/PAPER/steadystates-overdamped-150.pdf

# %%
data_dict_5 =load_obj("DATA/population_ratio_comparison_overdamped")
#save_obj(data_dict_5, )
plot_dynamics(data_dict_5, "PLOTS/PAPER/steadystates-overdamped.pdf")
# Out:
# /Users/admin/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# PLOTS/PAPER/steadystates-overdamped.pdf

# %%
1000*200/ev_to_inv_cm
# Out:
# 24.796974769078172

# %%
#data_dict_1 =load_obj("DATA/WC_validity_ss/3ls_1a")
#data_dict_2 =load_obj("DATA/WC_validity_ss/3ls_1b")
data_dict_3 =load_obj("DATA/WC_validity_ss/3ls_1c")
#plot_dynamics(data_dict_1)
#plot_dynamics(data_dict_2)
plot_dynamics(data_dict_3, figname='PLOTS/PAPER/Redfield-comparison-UD-hf.pdf')
# Out:
# /Users/admin/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# PLOTS/PAPER/Redfield-comparison-UD-hf.pdf

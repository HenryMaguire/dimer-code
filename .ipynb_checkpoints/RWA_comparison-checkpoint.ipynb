# %%
# %matplotlib inline 
import matplotlib
import matplotlib.pyplot as plt

import time
import heatmap_setup as hm
import numpy as np

from SES_setup import *
from utils import *
from style import *
# Out:
# SES_setup loaded globally

# %%
#import weak_phonons as wp

T_ph = 300.
w_2 = 1000. #1.4*ev_to_inv_cm
bias = 50. #0.01*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 50. #0.01*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 10.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =6
#wc = 50.
w_0 = 500.
Gamma = 2*w_0

#phonons = np.logspace(-1,np.log10(20),8)

PARAMS = PARAMS_setup(bias=bias, w_2=w_2, V = V, alpha=alpha,
                      T_EM=2000., T_ph =T_ph, alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=0)
#print PARAMS['H_sub'].eigenstates()
H, L, L_RWA, PARAMS = get_H_and_L_RWA(PARAMS,silent=False, threshold=0.)


evals, evecs = exciton_states(PARAMS, shift=False)
dark, bright = evecs[0]*evecs[0].dag(), evecs[1]*evecs[1].dag()
eig_x = (evecs[0]*evecs[1].dag() + evecs[1]*evecs[0].dag())*0.5
ops = make_expectation_operators(PARAMS)
site_x = (site_coherence+site_coherence.dag())
# Out:
# ****************************************************************
# The operators took 6.19046187401 and have dimension 78.
# Building the RC Liouvillian took 7.115 seconds.
# It is 6084by6084. The full basis would be 11664by11664
# It took  4.10033798218  seconds to build the Non-secular RWA Liouvillian
# It took  4.92790317535  seconds to build the Non-secular RWA Liouvillian
# Chopping reduced the sparsity from 8.922% to 8.922%

# %%
print (steadystate(H[1], [-L_RWA])*ops['dark']).tr()
print (steadystate(H[1], [-L])*ops['dark']).tr()
# Out:
# (0.343670026562+0j)
# (-0.866430488051-1.05879118407e-22j)

# %%
timelist = np.linspace(0, 3., 1900)

init_sys = XO_proj
#init_sys = ((XO + OX)*(XO + OX).dag())/2.
#print init_sys
print (init_sys*eig_x).tr()

v0 = tensor(init_sys,qt.enr_thermal_dm([N, N], N, Occupation(w_0, T_ph)))

dat1 = qt.mesolve(Hs[1], v0, timelist, c_ops=[-Ls], 
                  e_ops=[ops['XO'], ops['OX'], ops['sigma_x'], ops['eig_x']], 
                  progress_bar=True)
dat11 = qt.mesolve(Hs[1], v0, timelist, c_ops=[-Ladd], 
                  e_ops=[ops['XO'], ops['OX'], ops['sigma_x'], ops['eig_x']], 
                  progress_bar=True)

dat2 = qt.mesolve(PARAMS['H_sub'], init_sys, timelist, c_ops=[L_s], 
                  e_ops=[XO_proj, OX_proj, site_x, eig_x, site_x])
dat22 = qt.mesolve(PARAMS['H_sub'], init_sys, timelist, c_ops=[L_ns], 
                  e_ops=[XO_proj, OX_proj, site_x, eig_x, site_x])
# Out:
# (0.4472135955+0j)
# 10.0%. Run time:  20.93s. Est. time left: 00:00:03:08
# 20.0%. Run time:  46.60s. Est. time left: 00:00:03:06
# 30.0%. Run time:  69.08s. Est. time left: 00:00:02:41
# 40.0%. Run time:  83.15s. Est. time left: 00:00:02:04
# 50.0%. Run time: 110.23s. Est. time left: 00:00:01:50
# 60.0%. Run time: 140.27s. Est. time left: 00:00:01:33
# 70.0%. Run time: 162.48s. Est. time left: 00:00:01:09
# 80.0%. Run time: 181.75s. Est. time left: 00:00:00:45
# 90.0%. Run time: 195.68s. Est. time left: 00:00:00:21
# Total run time: 211.85s
# 10.0%. Run time:  56.55s. Est. time left: 00:00:08:28
# 20.0%. Run time:  86.06s. Est. time left: 00:00:05:44
# 30.0%. Run time: 105.68s. Est. time left: 00:00:04:06
# 40.0%. Run time: 122.87s. Est. time left: 00:00:03:04
# 50.0%. Run time: 146.37s. Est. time left: 00:00:02:26
# 60.0%. Run time: 173.53s. Est. time left: 00:00:01:55
# 70.0%. Run time: 194.07s. Est. time left: 00:00:01:23
# 80.0%. Run time: 207.37s. Est. time left: 00:00:00:51
# 90.0%. Run time: 228.14s. Est. time left: 00:00:00:25
# Total run time: 247.73s

# %%
plt.figure(figsize=(10,6))
plt.plot(timelist, dat1.expect[0], label='RC')
plt.plot(timelist, dat11.expect[0], label='RC_a')
#plt.plot(timelist, dat1.expect[1])
plt.plot(timelist, dat2.expect[0], label='WC_s', ls='dotted')
plt.plot(timelist, dat22.expect[0], label='WC_ns', ls='dotted')
#plt.plot(timelist, dat2.expect[1], ls='dotted')
plt.figure(figsize=(10,6))
plt.plot(timelist, dat1.expect[2], label='RC')
plt.plot(timelist, dat11.expect[2], label='RC_a')
plt.plot(timelist, dat2.expect[2], label='WC_s', ls='dotted')
plt.plot(timelist, dat22.expect[2], label='WC_ns', ls='dotted')
#print (steadystate(Hs[1], [-Ls])*ops['XO']).tr()
#print (steadystate(Hs[1],[ Ls])*ops['XO']).tr()

plt.figure(figsize=(10,6))
plt.plot(timelist, dat1.expect[3], label='RC')
plt.plot(timelist, dat11.expect[3], label='RC_a')
plt.plot(timelist, dat2.expect[3], label='WC_s', ls='dotted')
plt.plot(timelist, dat22.expect[3], label='WC_ns', ls='dotted')
plt.legend()

# %% [markdown]
# # Steadystates as a function of coupling strength

# %%
phonons = np.linspace(0.0, 50, 50)

rho_s = []
rho_wc = []

for alpha in phonons:
    PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                          V = V, alpha=alpha,
                          T_EM=6000., T_ph =T_ph, alpha_EM=alpha_EM, shift=True,
                          num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                          silent=True, exc_diff=0)
    #energies, states = exciton_states(PARAMS)
    H, L = get_H_and_L_wc(PARAMS['H_sub'], PARAMS)
    Hs, Ls, Ladd, PARAMS = get_H_and_L(PARAMS, silent=True, threshold=0.)
    #eig_x = states[0]*states[1].dag()+states[1]*states[0].dag()
    #dark = states[0]*states[0].dag()
    #print PARAMS.keys()
    #L = wp.L_weak_phonon_SES(PARAMS)
    rho_s.append(steadystate(Hs[1], [-Ls]))
    rho_wc.append(steadystate(PARAMS['H_sub'], [L]))
    #print ss.diag()
print 'Calculation complete'
# Out:
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# WC using non-secular optical master equation
# Calculation complete

# %%
f, ((ax1, ax2),(ax3, ax4))  = plt.subplots(2, 2, sharex=True, figsize=(12,6))

ax1.plot(phonons, [(r*ops['OO']).tr() for r in rho_s], label='CC')
ax1.plot(phonons, [(r*OO_proj).tr() for r in rho_wc], label='Redfield')
#plt.xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax1.set_ylabel(r"GS")
ax1.set_xlim(phonons[0], phonons[-1])
ax1.legend()

ax2.plot(phonons, [(r*ops['dark']).tr() for r in rho_s], label='CC')
ax2.plot(phonons, [(r*dark).tr() for r in rho_wc], label='Redfield')
#ax2.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax2.set_ylabel(r"DS")
ax2.legend()


ax3.plot(phonons, [(r*ops['bright']).tr() for r in rho_s], label='CC')
ax3.plot(phonons, [(r*bright).tr() for r in rho_wc], label='Redfield')
ax3.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax3.set_ylabel(r"BS")
ax3.legend()


ax4.plot(phonons, [(r*ops['eig_x']).tr() for r in rho_s], label='CC')
ax4.plot(phonons, [(r*eig_x).tr() for r in rho_wc], label='Redfield')
ax4.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax4.set_ylabel(r"$\tilde{\sigma}_x$")
ax4.legend()
plt.show()
#plt.savefig("PLOTS/Redfield-CC.pdf")

# %%
w_0 = 250.
Gamma = 2*w_0
phonons = np.linspace(0.0, 50, 50)

rho_s = []
rho_wc = []
rho_sadd = []

for alpha in phonons:
    PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                          V = V, alpha=alpha,
                          T_EM=6000., T_ph =T_ph, alpha_EM=alpha_EM, shift=True,
                          num_cpus=4, N=5, Gamma=Gamma, w_0=w_0,
                          silent=True, exc_diff=0)
    #energies, states = exciton_states(PARAMS)
    H, L_ns, L_s  = get_H_and_L_wc(PARAMS['H_sub'], PARAMS)
    Hs, Ls, Ladd, PARAMS = get_H_and_L(PARAMS, silent=True, threshold=0.)
    rho_s.append(steadystate(Hs[1], [-Ls]))
    rho_sadd.append(steadystate(Hs[1], [-Ladd]))
    rho_wc.append(steadystate(PARAMS['H_sub'], [L_ns]))
    
    #print ss.diag()
print 'Calculation complete'
# Out:
# It took 0.0113410949707 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0226008892059 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0241279602051 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0184738636017 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0223679542542 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.022243976593 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0219571590424 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0246789455414 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.025563955307 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0470490455627 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0158779621124 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0101380348206 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0470521450043 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0113370418549 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.010176897049 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0118250846863 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0100090503693 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.014317035675 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0105290412903 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0107798576355 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0102250576019 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0105440616608 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0104839801788 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0112040042877 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0103690624237 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0105879306793 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.010479927063 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0107200145721 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0107209682465 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.011018037796 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0264840126038 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0109949111938 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.011570930481 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0149800777435 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0112328529358 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0110192298889 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0107009410858 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0120148658752 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0111570358276 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0115180015564 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0115149021149 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0111439228058 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0115520954132 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0154409408569 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0112009048462 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0116469860077 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0117280483246 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0118820667267 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0328459739685 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0121250152588 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# Calculation complete

# %%
phonons = phonons[1:-1]
rho_s = rho_s[1:-1]
rho_wc = rho_wc[1:-1]

# %%
f, ((ax1, ax2),(ax3, ax4))  = plt.subplots(2, 2, sharex=True, figsize=(12,6))

ax1.plot(phonons, [(r*ops['OO']).tr() for r in rho_s], label='CC')
ax1.plot(phonons, [(r*OO_proj).tr() for r in rho_wc], label='Redfield')
#plt.xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax1.set_ylabel(r"GS")
ax1.set_xlim(phonons[0], phonons[-1])
ax1.legend()

ax2.plot(phonons, [(r*ops['dark']).tr() for r in rho_s], label='CC')
ax2.plot(phonons, [(r*dark).tr() for r in rho_wc], label='Redfield')
#ax2.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax2.set_ylabel(r"DS")
ax2.legend()


ax3.plot(phonons, [(r*ops['bright']).tr() for r in rho_s], label='CC')
ax3.plot(phonons, [(r*bright).tr() for r in rho_wc], label='Redfield')
ax3.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax3.set_ylabel(r"BS")
ax3.legend()


ax4.plot(phonons, [(r*ops['eig_x']).tr() for r in rho_s], label='CC')
ax4.plot(phonons, [(r*eig_x).tr() for r in rho_wc], label='Redfield')
ax4.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax4.set_ylabel(r"$\tilde{\sigma}_x$")
ax4.legend()
plt.show()

# %%
w_0 = 125.
Gamma = 2*w_0
phonons = np.linspace(0., 50, 50)

rho_s = []
rho_wc = []
rho_sadd = []

for alpha in phonons:
    PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                          V = V, alpha=alpha,
                          T_EM=6000., T_ph =T_ph, alpha_EM=alpha_EM, shift=True,
                          num_cpus=4, N=5, Gamma=Gamma, w_0=w_0,
                          silent=True, exc_diff=0)
    #energies, states = exciton_states(PARAMS)
    H, L_ns, L_s  = get_H_and_L_wc(PARAMS['H_sub'], PARAMS)
    Hs, Ls, Ladd, PARAMS = get_H_and_L(PARAMS, silent=True, threshold=0.)
    rho_s.append(steadystate(Hs[1], [-Ls]))
    rho_sadd.append(steadystate(Hs[1], [-Ladd]))
    rho_wc.append(steadystate(PARAMS['H_sub'], [L_ns]))
    
    #print ss.diag()
print 'Calculation complete'
# Out:
# It took 0.0130219459534 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0350728034973 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0259671211243 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0190758705139 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00964999198914 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0427241325378 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00985193252563 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0100572109222 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0112709999084 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.012836933136 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0174739360809 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00996994972229 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00998687744141 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0237290859222 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0162210464478 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0344541072845 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0259320735931 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0265789031982 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0213568210602 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0169608592987 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0149481296539 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0152270793915 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0218839645386 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00976586341858 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0156939029694 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0217669010162 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0190260410309 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0182809829712 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.040678024292 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.021436214447 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.026337146759 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0238690376282 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0320630073547 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0211009979248 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.017303943634 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0235459804535 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0116760730743 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.012542963028 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0121519565582 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0242598056793 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0121910572052 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.012090921402 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0282838344574 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0253369808197 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0234339237213 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0162470340729 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0125370025635 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0126368999481 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0127778053284 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0166010856628 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# Calculation complete

# %%
#phonons = phonons[1:-1]
#rho_s = rho_s[1:-1]
rho_sadd = rho_sadd[1:-1]
#rho_wc = rho_wc[1:-1]

# %%
f, ((ax1, ax2),(ax3, ax4))  = plt.subplots(2, 2, sharex=True, figsize=(12,6))

ax1.plot(phonons, [(r*ops['OO']).tr() for r in rho_sadd], label='CC s')
ax1.plot(phonons, [(r*ops['OO']).tr() for r in rho_s], label='CC')
ax1.plot(phonons, [(r*OO_proj).tr() for r in rho_wc], label='Redfield')
#plt.xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax1.set_ylabel(r"GS")
ax1.set_xlim(phonons[0], phonons[-1])
ax1.legend()

ax2.plot(phonons, [(r*ops['dark']).tr() for r in rho_s], label='CC')
ax2.plot(phonons, [(r*ops['dark']).tr() for r in rho_s], label='CC')
ax2.plot(phonons, [(r*dark).tr() for r in rho_wc], label='Redfield')
#ax2.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax2.set_ylabel(r"DS")
ax2.legend()


ax3.plot(phonons, [(r*ops['bright']).tr() for r in rho_s], label='CC')
ax3.plot(phonons, [(r*bright).tr() for r in rho_wc], label='Redfield')
ax3.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax3.set_ylabel(r"BS")
ax3.legend()


ax4.plot(phonons, [(r*ops['eig_x']).tr() for r in rho_s], label='CC')
ax4.plot(phonons, [(r*eig_x).tr() for r in rho_wc], label='Redfield')
ax4.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax4.set_ylabel(r"$\tilde{\sigma}_x$")
ax4.legend()
plt.show()

# %%
w_0 = 125.
Gamma = 2*w_0
phonons = np.linspace(0., 50, 50)

rho_s = []
rho_wc = []
rho_sadd = []

for alpha in phonons:
    PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                          V = V, alpha=alpha,
                          T_EM=6000., T_ph =T_ph, alpha_EM=alpha_EM, shift=True,
                          num_cpus=4, N=6, Gamma=Gamma, w_0=w_0,
                          silent=True, exc_diff=0)
    #energies, states = exciton_states(PARAMS)
    H, L_ns, L_s  = get_H_and_L_wc(PARAMS['H_sub'], PARAMS)
    Hs, Ls, Ladd, PARAMS = get_H_and_L(PARAMS, silent=True, threshold=0.)
    rho_s.append(steadystate(Hs[1], [-Ls]))
    rho_sadd.append(steadystate(Hs[1], [-Ladd]))
    rho_wc.append(steadystate(PARAMS['H_sub'], [L_ns]))
    
    #print ss.diag()
print 'Calculation complete'
# Out:
# It took 0.013603925705 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00960493087769 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0100479125977 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0098819732666 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0100710391998 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00977993011475 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0100820064545 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0100860595703 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0097291469574 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00992202758789 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0101339817047 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00955510139465 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0102391242981 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.023313999176 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0302090644836 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0182371139526 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00993609428406 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00959801673889 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0100150108337 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0100889205933 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0152130126953 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0212769508362 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0157351493835 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0103399753571 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.023097038269 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0243709087372 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00994491577148 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00993704795837 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0121281147003 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0105259418488 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00978803634644 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0095911026001 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0189361572266 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.022176027298 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0101020336151 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00998711585999 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00975394248962 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0104629993439 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0111439228058 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0176410675049 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00956392288208 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0100328922272 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0505340099335 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0195109844208 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0100240707397 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00971698760986 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00942587852478 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0216960906982 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0270581245422 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.010302066803 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# Calculation complete

# %%
ops = make_expectation_operators(PARAMS)

# %%
f, ((ax1, ax2),(ax3, ax4))  = plt.subplots(2, 2, sharex=True, figsize=(12,6))

ax1.plot(phonons, [(r*ops['OO']).tr() for r in rho_sadd], label='CC s')
ax1.plot(phonons, [(r*ops['OO']).tr() for r in rho_s], label='CC')
ax1.plot(phonons, [(r*OO_proj).tr() for r in rho_wc], label='Redfield')
#plt.xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax1.set_ylabel(r"GS")
ax1.set_xlim(phonons[0], phonons[-1])
ax1.legend()

ax2.plot(phonons, [(r*ops['dark']).tr() for r in rho_sadd], label='CC s')
ax2.plot(phonons, [(r*ops['dark']).tr() for r in rho_s], label='CC')
ax2.plot(phonons, [(r*dark).tr() for r in rho_wc], label='Redfield')
#ax2.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax2.set_ylabel(r"DS")
ax2.legend()

ax3.plot(phonons, [(r*ops['bright']).tr() for r in rho_sadd], label='CC s')
ax3.plot(phonons, [(r*ops['bright']).tr() for r in rho_s], label='CC')
ax3.plot(phonons, [(r*bright).tr() for r in rho_wc], label='Redfield')
ax3.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax3.set_ylabel(r"BS")
ax3.legend()


ax4.plot(phonons, [(r*ops['eig_x']).tr() for r in rho_sadd], label='CC s')
ax4.plot(phonons, [(r*ops['eig_x']).tr() for r in rho_s], label='CC')
ax4.plot(phonons, [(r*eig_x).tr() for r in rho_wc], label='Redfield')
ax4.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax4.set_ylabel(r"$\tilde{\sigma}_x$")
ax4.legend()
plt.show()

# %%
w_0 = 75.
Gamma = 2*w_0
phonons = np.linspace(1, 50, 49)

rho_s = []
rho_wc = []
rho_sadd = []

for alpha in phonons:
    PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                          V = V, alpha=alpha,
                          T_EM=6000., T_ph =T_ph, alpha_EM=alpha_EM, shift=True,
                          num_cpus=4, N=7, Gamma=Gamma, w_0=w_0,
                          silent=True, exc_diff=0)
    #energies, states = exciton_states(PARAMS)
    H, L_ns, L_s  = get_H_and_L_wc(PARAMS['H_sub'], PARAMS)
    Hs, Ls, Ladd, PARAMS = get_H_and_L(PARAMS, silent=True, threshold=0.)
    rho_s.append(steadystate(Hs[1], [-Ls]))
    rho_sadd.append(steadystate(Hs[1], [-Ladd]))
    rho_wc.append(steadystate(PARAMS['H_sub'], [L_ns]))
    
    #print ss.diag()
print 'Calculation complete'
# Out:
# It took 0.0140907764435 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0204060077667 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0101909637451 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00996804237366 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00993299484253 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00960803031921 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00965714454651 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00998497009277 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00996804237366 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0104548931122 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0103690624237 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0226020812988 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00975203514099 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00998711585999 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0101981163025 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00981497764587 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0101912021637 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0119850635529 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0283069610596 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0120780467987 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00942587852478 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0115389823914 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00981402397156 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0193037986755 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0115008354187 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0231430530548 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0121700763702 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0105400085449 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.03107213974 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0140058994293 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0238308906555 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00982403755188 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0102469921112 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0135979652405 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00978493690491 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00966811180115 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0133299827576 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0186121463776 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0124008655548 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.020889043808 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0115489959717 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0156788825989 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0164420604706 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0119729042053 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0233011245728 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0136170387268 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0213708877563 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0180208683014 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0128839015961 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# Calculation complete

# %%
ops = make_expectation_operators(PARAMS)

f, ((ax1, ax2),(ax3, ax4))  = plt.subplots(2, 2, sharex=True, figsize=(12,6))

ax1.plot(phonons, [(r*ops['OO']).tr() for r in rho_sadd], label='add')
ax1.plot(phonons, [(r*ops['OO']).tr() for r in rho_s], label='non-add')
ax1.plot(phonons, [(r*OO_proj).tr() for r in rho_wc], label='Redfield')
#plt.xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax1.set_ylabel(r"GS")
ax1.set_xlim(phonons[0], phonons[-1])
ax1.legend()

ax2.plot(phonons, [(r*ops['dark']).tr() for r in rho_sadd], label='add')
ax2.plot(phonons, [(r*ops['dark']).tr() for r in rho_s], label='non-add')
ax2.plot(phonons, [(r*dark).tr() for r in rho_wc], label='Redfield')
#ax2.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax2.set_ylabel(r"DS")
ax2.legend()

ax3.plot(phonons, [(r*ops['bright']).tr() for r in rho_sadd], label='add')
ax3.plot(phonons, [(r*ops['bright']).tr() for r in rho_s], label='non-add')
ax3.plot(phonons, [(r*bright).tr() for r in rho_wc], label='Redfield')
ax3.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax3.set_ylabel(r"BS")
ax3.legend()


ax4.plot(phonons, [(r*ops['eig_x']).tr() for r in rho_sadd], label='add')
ax4.plot(phonons, [(r*ops['eig_x']).tr() for r in rho_s], label='non-add')
ax4.plot(phonons, [(r*eig_x).tr() for r in rho_wc], label='Redfield')
ax4.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax4.set_ylabel(r"$\tilde{\sigma}_x$")
ax4.legend()
plt.show()

# %% [markdown]
# Qualitative behaviour change for very low RC frequency in the non-additive theory. Again, the exciton coherence is unaffected by additivity. Would need to check convergence here, since the BS has a tendency of breaking.

# %%
w_0 = 125.
Gamma = 2*w_0
phonons = np.linspace(0.5, 50, 30)

rho_s = []
rho_wc = []
rho_sadd = []

for alpha in phonons:
    PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                          V = V, alpha=alpha,
                          T_EM=6000., T_ph =77., alpha_EM=alpha_EM, shift=True,
                          num_cpus=4, N=6, Gamma=Gamma, w_0=w_0,
                          silent=True, exc_diff=0)
    #energies, states = exciton_states(PARAMS)
    H, L_ns, L_s  = get_H_and_L_wc(PARAMS['H_sub'], PARAMS)
    Hs, Ls, Ladd, PARAMS = get_H_and_L(PARAMS, silent=True, threshold=0.)
    rho_s.append(steadystate(Hs[1], [-Ls]))
    rho_sadd.append(steadystate(Hs[1], [-Ladd]))
    rho_wc.append(steadystate(PARAMS['H_sub'], [L_ns]))
    
    #print ss.diag()
print 'Calculation complete'
# Out:
# It took 0.0185971260071 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0232439041138 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0195069313049 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0139260292053 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00982308387756 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00997710227966 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0224101543427 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0101191997528 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0100500583649 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0158898830414 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00989699363708 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0124659538269 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00969815254211 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.00968408584595 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0148780345917 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0146019458771 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0173609256744 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0134761333466 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0191237926483 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0107669830322 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0141479969025 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0248770713806 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0192408561707 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0101919174194 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0101230144501 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0100929737091 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0137441158295 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0213119983673 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.0237979888916 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# It took 0.010969877243 seconds to build the phenomenological Liouvillian
# Non-secular and secular dissipators calculated
# Calculation complete

# %%
ops = make_expectation_operators(PARAMS)

f, ((ax1, ax2),(ax3, ax4))  = plt.subplots(2, 2, sharex=True, figsize=(12,6))

ax1.plot(phonons, [(r*ops['OO']).tr() for r in rho_sadd], label='add')
ax1.plot(phonons, [(r*ops['OO']).tr() for r in rho_s], label='non-add')
ax1.plot(phonons, [(r*OO_proj).tr() for r in rho_wc], label='Redfield')
#plt.xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax1.set_ylabel(r"GS")
ax1.set_xlim(phonons[0], phonons[-1])
ax1.legend()

ax2.plot(phonons, [(r*ops['dark']).tr() for r in rho_sadd], label='add')
ax2.plot(phonons, [(r*ops['dark']).tr() for r in rho_s], label='non-add')
ax2.plot(phonons, [(r*dark).tr() for r in rho_wc], label='Redfield')
#ax2.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax2.set_ylabel(r"DS")
ax2.legend()

ax3.plot(phonons, [(r*ops['bright']).tr() for r in rho_sadd], label='add')
ax3.plot(phonons, [(r*ops['bright']).tr() for r in rho_s], label='non-add')
ax3.plot(phonons, [(r*bright).tr() for r in rho_wc], label='Redfield')
ax3.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax3.set_ylabel(r"BS")
ax3.legend()


ax4.plot(phonons, [(r*ops['eig_x']).tr() for r in rho_sadd], label='add')
ax4.plot(phonons, [(r*ops['eig_x']).tr() for r in rho_s], label='non-add')
ax4.plot(phonons, [(r*eig_x).tr() for r in rho_wc], label='Redfield')
ax4.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax4.set_ylabel(r"$\tilde{\sigma}_x$")
ax4.legend()
plt.show()

# %% [markdown]
# Absolutely no difference on this scale when $T_{ph}=77K$

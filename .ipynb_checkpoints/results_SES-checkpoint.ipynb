# %%
# Incase we have to clear all variables
# %reset -f

# %%
# %matplotlib inline 
import matplotlib
import matplotlib.pyplot as plt


import time
import heatmap_setup as hm
import numpy as np


from SES_setup import *
from utils import *
from style import *
colourWheel =['#329932',
            '#ff6961',
            'b',
            '#6a3d9a',
            '#fb9a99',
            '#e31a1c',
            '#fdbf6f',
            '#ff7f00',
            '#cab2d6',
            '#6a3d9a',
            '#ffff99',
            '#b15928',
            '#67001f',
            '#b2182b',
            '#d6604d',
            '#f4a582',
            '#fddbc7',
            '#f7f7f7',
            '#d1e5f0',
            '#92c5de',
            '#4393c3',
            '#2166ac',
            '#053061'][::-1]
plt.rcParams['axes.labelsize'] = 25
plt.rcParams['legend.fontsize'] = 'large'
# Out:
# SES_setup loaded globally

# %%
def steadystate_observable(ss_array, PARAMS, observable):
    ss_obs_array = np.zeros(shape=ss_array.shape)
    for y, ss_row in enumerate(ss_array):
        for x, ss_dm in enumerate(ss_row):
            dim, size = ss_dm.dims[0][1::], int(ss_dm.shape[0]/PARAMS['sys_dim'])
            
            nstates, state2idx, idx2state = qt.enr_state_dictionaries(dim, dim[0]+0)
            exc_diff = 0 # function finds the correct exc_diff given some dm
            while nstates != size:
                nstates, state2idx, idx2state = qt.enr_state_dictionaries(dim, dim[0]+exc_diff)
            
            #print exc_diff, dim[0]+exc_diff
            PARAMS.update({'N_1':dim[0], 'N_2':dim[1], 'exc':dim[0]+exc_diff})
            obs_op = make_expectation_operators(PARAMS)[observable]
            #print obs_op.shape, ss_dm.shape
            ss_obs_array[y][x] = (obs_op*ss_dm).tr().real #info_test[y][x]['solution_time']
    return ss_obs_array

# With saved data, we can calculte things differently

def heatmap_loader(num, dir_name="heatmap"):
    # Only loads data of heatmap into memory, does not plot
    directory = 'DATA/'+dir_name+'_'+str(num)
    ss_array = load_obj(directory+'/ss_array')
    PARAMS = load_obj(directory+'/PARAMS')
    info_array = load_obj(directory+'/info_array') # reverse ordering -> lower_N-higher_N
    return ss_array, PARAMS, info_array


def heatmap_plotter(num=-1, plot_SD=True, dir_name="heatmap", 
                     print_params=False, observable='sigma_x', ylim=False):
    
    # If ss_info_params list is provided, then makes heatmap from memory not disk
    
    if num>=0:
        ss_array, PARAMS, info_array = heatmap_loader(num, dir_name=dir_name)
        ss_array_add, PARAMS, info_array_add = heatmap_loader(num, dir_name=dir_name+'_add')
        data = {'non-add.': [ss_array,'solid'], 'add.': [ss_array_add, 'dashed']}
    info = info_array[0][0]
    try:
        # To catch an old bug where these were in "info" not in PARAMS
        keys = ['x_values', 'y_values', 'y_axis_parameters', 'x_axis_parameters']
        PARAMS.update(dict((key, info[key]) for key in keys))
    except Exception as err:
        print "plotting in new style"
    #print info
    
    if plot_SD:
        plot_UD_SD(PARAMS["Gamma_1"], PARAMS["alpha_1"], PARAMS["w0_1"], eps=8000.)
    eta = np.sqrt(PARAMS['bias']**2 + 4*PARAMS['V']**2)
    f, axes = plt.subplots(1,1, figsize=(13,6))
    for key in data.keys():
        if observable=='DS/GS':
            ss_arrayGS = steadystate_observable(data[key][0], PARAMS, 'OO')
            ss_arrayDS = steadystate_observable(data[key][0], PARAMS, 'dark')
            ss_arrayBS = steadystate_observable(data[key][0], PARAMS, 'bright')
            ss_array = (ss_arrayDS+ss_arrayBS)/ss_arrayGS
        else:
            ss_array = steadystate_observable(data[key][0], PARAMS, observable)
        
        ylab = ' = '.join(["$"+l+"$" for l in PARAMS['y_axis_parameters']])
        for i, y_val in enumerate(PARAMS['y_values']):
            x_values = PARAMS['x_values']

            lbl = ylab+"="+"{:0.1f}".format(y_val)
            if key == 'add.':
                lbl = None
            axes.plot(x_values, ss_array[i], label=lbl, 
                      linestyle=data[key][1], color=colourWheel[i*8])
            
        if print_params:
            print_PARAMS(PARAMS)
        labs = ("$\\"+l+"$" for l in PARAMS['x_axis_parameters'])
        xlab = ' , '.join(labs)
        
        plt.xlabel(xlab+" (cm$^{-1}$)")
        #plt.xlabel(', '.join(PARAMS['x_axis_parameters']))
        try:
            plt.ylabel(r"Steadystate "+make_expectation_labels()[observable])
        except:
            plt.ylabel(r"Steadystate "+observable)
    #plt.ylabel(', '.join(info['y_axis_parameters']))
    plt.legend()
    #plt.grid()
    plt.xlim(x_values[0], x_values[-1])
    if ylim:
        plt.ylim(ylim[0], ylim[-1])
    plot_filename = 'PLOTS/'+dir_name+'_'+observable+'_'+str(num)+'.pdf'
    plt.savefig(plot_filename,bbox_inches='tight')
    plt.show()
    print "saved at {}".format(plot_filename)

# Example of loading data to memory
"""ss_info_params = [ss_array, info_array, PARAMS]

heatmap_plotter(ss_info_params=ss_info_params, plot_SD=False,
                print_params=False, observable='sigma_x')
heatmap_plotter(num=5, plot_SD=False, dir_name="heatmap_excvN",
                print_params=False, observable='sigma_x')"""
# Out:
# 'ss_info_params = [ss_array, info_array, PARAMS]\n\nheatmap_plotter(ss_info_params=ss_info_params, plot_SD=False,\n                print_params=False, observable=\'sigma_x\')\nheatmap_plotter(num=5, plot_SD=False, dir_name="heatmap_excvN",\n                print_params=False, observable=\'sigma_x\')'

# %% [markdown]
# # Environments with different parity $\alpha_1 = -\alpha_2$

# %%
reload(hm)
w_2 = 1.4*ev_to_inv_cm
bias = 0.01*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 0.01*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 100./pi
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =7
wc = 100.
w_0 = 200.
site_basis = True
Gamma = (w_0**2)/wc
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=False, exc_diff=N, parity_flip=True)

x_values = np.logspace(-2, np.log10(100), 10, endpoint=True)
print x_values
y_values = [77, 300] #np.linspace(77,300, 2)
dirname = 'heatmap_TphvAlpha_phased'

ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname+'_add', save_data=True,
                            persistent=False, method='direct', threshold=1e-9, 
                            conv_percent_tol=0.025, conv_obs='OO', additive=True)

ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname, save_data=True,
                            persistent=False, method='direct', threshold=1e-9, 
                            conv_percent_tol=0.025, conv_obs='OO', additive=False)
# Out:
# /Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/matplotlib/figure.py:2299: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# Gap is 180.350062725. Phonon thermal energy is 208.5. Phonon SD peak is 115.01150115. N=7.
# [1.00000000e-02 2.78255940e-02 7.74263683e-02 2.15443469e-01
#  5.99484250e-01 1.66810054e+00 4.64158883e+00 1.29154967e+01
#  3.59381366e+01 1.00000000e+02]
# Steady state for 2 took 0.002 seconds with direct, OO changed by 33.3691%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 4.5049%
# Steady state for 4 took 0.308 seconds with direct, OO changed by 0.2050%
# calculation converged - 0.0, 77.0 (1/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 15.2945%
# Steady state for 3 took 0.020 seconds with direct, OO changed by 0.7889%
# Steady state for 4 took 0.297 seconds with direct, OO changed by 0.0383%
# calculation converged - 0.0, 77.0 (2/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 956.7519%
# Steady state for 3 took 0.020 seconds with direct, OO changed by 0.2355%
# Steady state for 4 took 0.297 seconds with direct, OO changed by 0.0116%
# calculation converged - 0.1, 77.0 (3/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 40.7738%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0883%
# Steady state for 4 took 0.311 seconds with direct, OO changed by 0.0043%
# calculation converged - 0.2, 77.0 (4/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 9.1352%
# Steady state for 3 took 0.020 seconds with direct, OO changed by 0.0573%
# Steady state for 4 took 0.370 seconds with direct, OO changed by 0.0026%
# calculation converged - 0.6, 77.0 (5/20)
# Steady state for 2 took 0.003 seconds with direct, OO changed by 25.0454%
# Steady state for 3 took 0.025 seconds with direct, OO changed by 0.1061%
# Steady state for 4 took 0.339 seconds with direct, OO changed by 0.0054%
# calculation converged - 1.7, 77.0 (6/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 32.8298%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.3604%
# Steady state for 4 took 0.296 seconds with direct, OO changed by 0.0249%
# calculation converged - 4.6, 77.0 (7/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 14.6813%
# Steady state for 3 took 0.021 seconds with direct, OO changed by 1.3767%
# Steady state for 4 took 0.312 seconds with direct, OO changed by 0.1522%
# Steady state for 5 took 2.883 seconds with direct, OO changed by 0.0128%
# calculation converged - 12.9, 77.0 (8/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 180.5154%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 4.1756%
# Steady state for 4 took 0.302 seconds with direct, OO changed by 0.8211%
# Steady state for 5 took 2.641 seconds with direct, OO changed by 0.1268%
# Steady state for 6 took 17.690 seconds with direct, OO changed by 0.0157%
# calculation converged - 35.9, 77.0 (9/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 230.1190%
# Steady state for 3 took 0.018 seconds with direct, OO changed by 7.7162%
# Steady state for 4 took 0.295 seconds with direct, OO changed by 2.3753%
# Steady state for 5 took 2.653 seconds with direct, OO changed by 0.7227%
# Steady state for 6 took 17.625 seconds with direct, OO changed by 0.1915%
# Steady state for 7 took 89.995 seconds with direct, OO changed by 0.0425%
# Steady state for 8 took 353.989 seconds with direct, OO changed by 0.0080%
# calculation converged - 100.0, 77.0 (10/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 31.9571%
# Steady state for 3 took 0.021 seconds with direct, OO changed by 1.3768%
# Steady state for 4 took 0.290 seconds with direct, OO changed by 0.1837%
# calculation converged - 0.0, 300.0 (11/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 17.2762%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.3830%
# Steady state for 4 took 0.284 seconds with direct, OO changed by 0.0591%
# calculation converged - 0.0, 300.0 (12/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 183.4172%
# Steady state for 3 took 0.018 seconds with direct, OO changed by 0.1273%
# Steady state for 4 took 0.293 seconds with direct, OO changed by 0.0207%
# calculation converged - 0.1, 300.0 (13/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 681.1619%
# Steady state for 3 took 0.023 seconds with direct, OO changed by 0.0458%
# Steady state for 4 took 0.288 seconds with direct, OO changed by 0.0080%
# calculation converged - 0.2, 300.0 (14/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 15.8650%
# Steady state for 3 took 0.018 seconds with direct, OO changed by 0.0194%
# calculation converged - 0.6, 300.0 (15/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 14.3950%
# Steady state for 3 took 0.020 seconds with direct, OO changed by 0.0152%
# calculation converged - 1.7, 300.0 (16/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 95.8592%
# Steady state for 3 took 0.020 seconds with direct, OO changed by 0.0277%
# Steady state for 4 took 0.290 seconds with direct, OO changed by 0.0154%
# calculation converged - 4.6, 300.0 (17/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 41.2754%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0693%
# Steady state for 4 took 0.293 seconds with direct, OO changed by 0.0409%
# Steady state for 5 took 2.660 seconds with direct, OO changed by 0.0236%
# calculation converged - 12.9, 300.0 (18/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 42.5046%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 0.1748%
# Steady state for 4 took 0.294 seconds with direct, OO changed by 0.1060%
# Steady state for 5 took 2.668 seconds with direct, OO changed by 0.0635%
# Steady state for 6 took 17.547 seconds with direct, OO changed by 0.0367%
# Steady state for 7 took 90.804 seconds with direct, OO changed by 0.0205%
# calculation converged - 35.9, 300.0 (19/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 65.7489%
# Steady state for 3 took 0.020 seconds with direct, OO changed by 0.3947%
# Steady state for 4 took 0.304 seconds with direct, OO changed by 0.2475%
# Steady state for 5 took 2.643 seconds with direct, OO changed by 0.1571%
# Steady state for 6 took 17.591 seconds with direct, OO changed by 0.0983%
# Steady state for 7 took 90.738 seconds with direct, OO changed by 0.0601%
# Steady state for 8 took 361.318 seconds with direct, OO changed by 0.0359%
# Steady state for 9 took 1366.376 seconds with direct, OO changed by 0.0208%
# calculation converged - 100.0, 300.0 (20/20)
# Files saved at DATA/heatmap_TphvAlpha_phased_add_2
# Steady state for 2 took 0.002 seconds with direct, OO changed by 22.5672%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 4.5313%
# Steady state for 4 took 0.359 seconds with direct, OO changed by 0.2060%
# calculation converged - 0.0, 77.0 (1/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 58.9519%
# Steady state for 3 took 0.021 seconds with direct, OO changed by 0.7871%
# Steady state for 4 took 0.308 seconds with direct, OO changed by 0.0382%
# calculation converged - 0.0, 77.0 (2/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 39.7906%
# Steady state for 3 took 0.021 seconds with direct, OO changed by 0.2344%
# Steady state for 4 took 0.281 seconds with direct, OO changed by 0.0115%
# calculation converged - 0.1, 77.0 (3/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 38.4543%
# Steady state for 3 took 0.020 seconds with direct, OO changed by 0.0876%
# Steady state for 4 took 0.349 seconds with direct, OO changed by 0.0042%
# calculation converged - 0.2, 77.0 (4/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 19.5965%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 0.0560%
# Steady state for 4 took 0.394 seconds with direct, OO changed by 0.0026%
# calculation converged - 0.6, 77.0 (5/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 31.7109%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 0.1022%
# Steady state for 4 took 0.416 seconds with direct, OO changed by 0.0052%
# calculation converged - 1.7, 77.0 (6/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 19.6507%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 0.3462%
# Steady state for 4 took 0.403 seconds with direct, OO changed by 0.0239%
# calculation converged - 4.6, 77.0 (7/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 297.0409%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 1.3219%
# Steady state for 4 took 0.412 seconds with direct, OO changed by 0.1456%
# Steady state for 5 took 3.497 seconds with direct, OO changed by 0.0122%
# calculation converged - 12.9, 77.0 (8/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 337.4720%
# Steady state for 3 took 0.024 seconds with direct, OO changed by 4.0030%
# Steady state for 4 took 0.409 seconds with direct, OO changed by 0.7836%
# Steady state for 5 took 3.458 seconds with direct, OO changed by 0.1202%
# Steady state for 6 took 21.621 seconds with direct, OO changed by 0.0148%
# calculation converged - 35.9, 77.0 (9/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 4.8492%
# Steady state for 3 took 0.027 seconds with direct, OO changed by 7.2915%
# Steady state for 4 took 0.395 seconds with direct, OO changed by 2.2318%
# Steady state for 5 took 4.073 seconds with direct, OO changed by 0.6717%
# Steady state for 6 took 27.393 seconds with direct, OO changed by 0.1758%
# Steady state for 7 took 104.335 seconds with direct, OO changed by 0.0385%
# Steady state for 8 took 508.640 seconds with direct, OO changed by 0.0072%
# calculation converged - 100.0, 77.0 (10/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 88.3653%
# Steady state for 3 took 0.025 seconds with direct, OO changed by 1.3669%
# Steady state for 4 took 0.350 seconds with direct, OO changed by 0.1821%
# calculation converged - 0.0, 300.0 (11/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 2801.4049%
# Steady state for 3 took 0.021 seconds with direct, OO changed by 0.3795%
# Steady state for 4 took 0.305 seconds with direct, OO changed by 0.0585%
# calculation converged - 0.0, 300.0 (12/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 479.5142%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 0.1260%
# Steady state for 4 took 0.293 seconds with direct, OO changed by 0.0204%
# calculation converged - 0.1, 300.0 (13/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 417.5623%
# Steady state for 3 took 0.020 seconds with direct, OO changed by 0.0450%
# Steady state for 4 took 0.336 seconds with direct, OO changed by 0.0077%
# calculation converged - 0.2, 300.0 (14/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 119.0421%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 0.0185%
# calculation converged - 0.6, 300.0 (15/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 211.3938%
# Steady state for 3 took 0.026 seconds with direct, OO changed by 0.0130%
# calculation converged - 1.7, 300.0 (16/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 60.9161%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 0.0218%
# calculation converged - 4.6, 300.0 (17/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 107.8836%
# Steady state for 3 took 0.025 seconds with direct, OO changed by 0.0533%
# Steady state for 4 took 0.399 seconds with direct, OO changed by 0.0313%
# Steady state for 5 took 3.484 seconds with direct, OO changed by 0.0180%
# calculation converged - 12.9, 300.0 (18/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 1807.6798%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 0.1323%
# Steady state for 4 took 0.414 seconds with direct, OO changed by 0.0797%
# Steady state for 5 took 3.490 seconds with direct, OO changed by 0.0474%
# Steady state for 6 took 21.572 seconds with direct, OO changed by 0.0273%
# Steady state for 7 took 137.470 seconds with direct, OO changed by 0.0151%
# calculation converged - 35.9, 300.0 (19/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 1038.5883%
# Steady state for 3 took 0.025 seconds with direct, OO changed by 0.2880%
# Steady state for 4 took 0.400 seconds with direct, OO changed by 0.1779%
# Steady state for 5 took 4.102 seconds with direct, OO changed by 0.1112%
# Steady state for 6 took 27.262 seconds with direct, OO changed by 0.0684%
# Steady state for 7 took 103.605 seconds with direct, OO changed by 0.0412%
# Steady state for 8 took 513.096 seconds with direct, OO changed by 0.0242%
# calculation converged - 100.0, 300.0 (20/20)
# Files saved at DATA/heatmap_TphvAlpha_phased_2

# %%
num=2
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='XO', ylim=[0,0.2])
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='OX', ylim=[0.1,0.5])
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='dark', ylim=[0,0.6])
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='bright', ylim=[-0.01,0.1])
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='eig_x')
# Out:
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_phased_XO_2.pdf
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_phased_OX_2.pdf
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_phased_dark_2.pdf
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_phased_bright_2.pdf
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_phased_eig_x_2.pdf

# %% [markdown]
# Okay, we want to know:
# - What is the nature of the coherence we are seeing?
#     - How does site coherence and population inversion relate to exciton coherence?

# %% [markdown]
# ### Uncoupled monomers
#
# These get updated dynamically by the various functions. `SES_setup.PARAMS_setup` just imposes the relevant symmetry behind the scenes so the API is clean and so that we can reuse code for dimer case - e.g. $\alpha_1 = \alpha_2$, no doubly excited state.

# %%
w_2 = 1.4*ev_to_inv_cm
bias = 0.02*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 0.0*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 100./pi
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =7
wc = 100.
w_0 = 200.
site_basis = True
Gamma = (w_0**2)/wc
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=False, exc_diff=N)

x_values = np.logspace(-2, np.log10(100), 10, endpoint=True)
print x_values
y_values = [77, 300] #np.linspace(77,300, 2)
dirname = 'heatmap_TphvAlpha_uncoupled'

ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname+'_add', save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.01, conv_obs='OO', additive=True)

ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname, save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                            conv_percent_tol=0.01, conv_obs='OO', additive=False)
# Out:
# /Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/matplotlib/figure.py:2299: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# Gap is 161.31. Phonon thermal energy is 208.5. Phonon SD peak is 115.01150115. N=7.
# [1.00000000e-02 2.78255940e-02 7.74263683e-02 2.15443469e-01
#  5.99484250e-01 1.66810054e+00 4.64158883e+00 1.29154967e+01
#  3.59381366e+01 1.00000000e+02]
# True
# Steady state for 5 took 1.698 seconds with direct, OO changed by 162.1666%
# calculation converged - 0.0, 77.0 (1/20)
# True
# Steady state for 5 took 1.252 seconds with direct, OO changed by 2.8055%
# calculation converged - 0.0, 77.0 (2/20)
# True
# Steady state for 5 took 1.993 seconds with direct, OO changed by 212.9889%
# calculation converged - 0.1, 77.0 (3/20)
# True
# Steady state for 5 took 1.441 seconds with direct, OO changed by 112.8096%
# calculation converged - 0.2, 77.0 (4/20)
# True
# Steady state for 5 took 1.716 seconds with direct, OO changed by 568.2504%
# calculation converged - 0.6, 77.0 (5/20)
# Steady state for 5 took 1.510 seconds with direct, OO changed by 2.1653%
# Steady state for 6 took 10.544 seconds with direct, OO changed by 0.0000%
# calculation converged - 1.7, 77.0 (6/20)
# Steady state for 5 took 1.887 seconds with direct, OO changed by 468.3992%
# Steady state for 6 took 10.269 seconds with direct, OO changed by 0.0000%
# calculation converged - 4.6, 77.0 (7/20)
# Steady state for 5 took 1.457 seconds with direct, OO changed by 37.7614%
# Steady state for 6 took 10.878 seconds with direct, OO changed by 0.0000%
# calculation converged - 12.9, 77.0 (8/20)
# Steady state for 5 took 1.436 seconds with direct, OO changed by 118.3799%
# Steady state for 6 took 10.397 seconds with direct, OO changed by 0.0000%
# calculation converged - 35.9, 77.0 (9/20)
# Steady state for 5 took 1.478 seconds with direct, OO changed by 8.0948%
# Steady state for 6 took 10.702 seconds with direct, OO changed by 0.0000%
# calculation converged - 100.0, 77.0 (10/20)
# True
# Steady state for 5 took 1.534 seconds with direct, OO changed by 15.0282%
# calculation converged - 0.0, 300.0 (11/20)
# True
# Steady state for 5 took 1.868 seconds with direct, OO changed by 2.5395%
# calculation converged - 0.0, 300.0 (12/20)
# True
# Steady state for 5 took 1.551 seconds with direct, OO changed by 960.1354%
# calculation converged - 0.1, 300.0 (13/20)
# True
# Steady state for 5 took 1.583 seconds with direct, OO changed by 1867.2194%
# calculation converged - 0.2, 300.0 (14/20)
# True
# Steady state for 5 took 1.875 seconds with direct, OO changed by 85.6697%
# calculation converged - 0.6, 300.0 (15/20)
# Steady state for 5 took 1.430 seconds with direct, OO changed by 42.3728%
# Steady state for 6 took 9.986 seconds with direct, OO changed by 0.0000%
# calculation converged - 1.7, 300.0 (16/20)
# Steady state for 5 took 1.897 seconds with direct, OO changed by 10.9833%
# Steady state for 6 took 11.455 seconds with direct, OO changed by 0.0000%
# calculation converged - 4.6, 300.0 (17/20)
# Steady state for 5 took 1.448 seconds with direct, OO changed by 8.4903%
# Steady state for 6 took 10.425 seconds with direct, OO changed by 0.0000%
# calculation converged - 12.9, 300.0 (18/20)
# Steady state for 5 took 1.460 seconds with direct, OO changed by 57.1158%
# Steady state for 6 took 11.330 seconds with direct, OO changed by 0.0000%
# calculation converged - 35.9, 300.0 (19/20)
# Steady state for 5 took 1.603 seconds with direct, OO changed by 336.7039%
# Steady state for 6 took 10.601 seconds with direct, OO changed by 0.0000%
# calculation converged - 100.0, 300.0 (20/20)
# Files saved at DATA/heatmap_TphvAlpha_uncoupled_add_6
# True
# Steady state for 2 took 0.002 seconds with direct, OO changed by 4.5132%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0000%
# calculation converged - 0.0, 77.0 (1/20)
# True
# Steady state for 2 took 0.001 seconds with direct, OO changed by 56.7390%
# Steady state for 3 took 0.027 seconds with direct, OO changed by 0.0000%
# calculation converged - 0.0, 77.0 (2/20)
# True
# Steady state for 2 took 0.002 seconds with direct, OO changed by 3285.2239%
# Steady state for 3 took 0.023 seconds with direct, OO changed by 0.0000%
# calculation converged - 0.1, 77.0 (3/20)
# True
# Steady state for 2 took 0.001 seconds with direct, OO changed by 12.3516%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0000%
# calculation converged - 0.2, 77.0 (4/20)
# True
# Steady state for 2 took 0.001 seconds with direct, OO changed by 2817.7869%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0001%
# calculation converged - 0.6, 77.0 (5/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 77.3804%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0003%
# calculation converged - 1.7, 77.0 (6/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 333.9947%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0011%
# calculation converged - 4.6, 77.0 (7/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 213.6293%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0052%
# calculation converged - 12.9, 77.0 (8/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 11.9191%
# Steady state for 3 took 0.018 seconds with direct, OO changed by 0.0225%
# Steady state for 4 took 0.223 seconds with direct, OO changed by 0.0059%
# calculation converged - 35.9, 77.0 (9/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 42.8984%
# Steady state for 3 took 0.021 seconds with direct, OO changed by 0.0703%
# Steady state for 4 took 0.217 seconds with direct, OO changed by 0.0369%
# Steady state for 5 took 2.457 seconds with direct, OO changed by 0.0157%
# Steady state for 6 took 17.816 seconds with direct, OO changed by 0.0052%
# calculation converged - 100.0, 77.0 (10/20)
# True
# Steady state for 2 took 0.001 seconds with direct, OO changed by 33.9594%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0000%
# calculation converged - 0.0, 300.0 (11/20)
# True
# Steady state for 2 took 0.002 seconds with direct, OO changed by 1623.4034%
# Steady state for 3 took 0.020 seconds with direct, OO changed by 0.0000%
# calculation converged - 0.0, 300.0 (12/20)
# True
# Steady state for 2 took 0.002 seconds with direct, OO changed by 134.7856%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0001%
# calculation converged - 0.1, 300.0 (13/20)
# True
# Steady state for 2 took 0.001 seconds with direct, OO changed by 11.1246%
# Steady state for 3 took 0.021 seconds with direct, OO changed by 0.0001%
# calculation converged - 0.2, 300.0 (14/20)
# True
# Steady state for 2 took 0.001 seconds with direct, OO changed by 113.0814%
# Steady state for 3 took 0.021 seconds with direct, OO changed by 0.0004%
# calculation converged - 0.6, 300.0 (15/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 93.0491%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0011%
# calculation converged - 1.7, 300.0 (16/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 34.1321%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0030%
# calculation converged - 4.6, 300.0 (17/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 284.8250%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0082%
# calculation converged - 12.9, 300.0 (18/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 6.6296%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0221%
# Steady state for 4 took 0.214 seconds with direct, OO changed by 0.0140%
# Steady state for 5 took 2.614 seconds with direct, OO changed by 0.0086%
# calculation converged - 35.9, 300.0 (19/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 91.8508%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0564%
# Steady state for 4 took 0.208 seconds with direct, OO changed by 0.0385%
# Steady state for 5 took 2.422 seconds with direct, OO changed by 0.0261%
# Steady state for 6 took 17.986 seconds with direct, OO changed by 0.0172%
# Steady state for 7 took 90.403 seconds with direct, OO changed by 0.0110%
# Steady state for 8 took 370.182 seconds with direct, OO changed by 0.0068%
# calculation converged - 100.0, 300.0 (20/20)
# Files saved at DATA/heatmap_TphvAlpha_uncoupled_6

# %%
num=6
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='XO')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='OX')
# Out:
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_uncoupled_XO_6.pdf
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_uncoupled_OX_6.pdf

# %%
H, L = get_H_and_L(PARAMS)

# %%
eta = np.sqrt(PARAMS['bias']**2 + 4*PARAMS['V']**2)
print (2*PARAMS['V']/eta)
print (PARAMS['bias']/eta)
print (1/np.sqrt(2))

# %%
np.linspace(200, 600, 5, endpoint=False)

# %%
np.log(0.0001)
np.logspace(-5, 2, 10, endpoint=False)

# %% [markdown]
# ## Heterodimer
# Shouldn't increasing the phonon coupling strength lead to suppression of ground state population?

# %%
reload(hm)
w_2 = 1.4*ev_to_inv_cm
bias=0.01*ev_to_inv_cm
V=0.01*ev_to_inv_cm
alpha = 200./pi
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =4
wc = 100.
w_0 = 200.
site_basis = True
Gamma = (w_0**2)/wc
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=2*N)

x_values = np.logspace(-2, np.log10(100), 10, endpoint=True)
print x_values
y_values = [77, 300] #np.linspace(77,300, 2)

"""

ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name='heatmap_TphvAlpha', save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.1, conv_obs='OO')
"""
dirname = 'heatmap_TphvAlpha_hetero'
# Out:
# [1.00000000e-02 2.78255940e-02 7.74263683e-02 2.15443469e-01
#  5.99484250e-01 1.66810054e+00 4.64158883e+00 1.29154967e+01
#  3.59381366e+01 1.00000000e+02]

# %%
ss_array, PARAMS, info_array = heatmap_loader(16, dir_name="heatmap_TphvAlpha")
print zip(PARAMS['x_values'], steadystate_observable(ss_array, PARAMS, 'OO')[0])

# %%
reload(hm)
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname, save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                            conv_percent_tol=0.025, conv_obs='OO', additive=False)
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname+'_add', save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.025, conv_obs='OO', additive=True)
# Out:
# Steady state for 2 took 0.001 seconds with direct, OO changed by 12.0745%
# Steady state for 3 took 0.023 seconds with direct, OO changed by 4.5313%
# Steady state for 4 took 0.387 seconds with direct, OO changed by 0.2060%
# calculation converged - 0.0, 77.0 (1/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 7.8968%
# Steady state for 3 took 0.028 seconds with direct, OO changed by 0.7871%
# Steady state for 4 took 0.317 seconds with direct, OO changed by 0.0382%
# calculation converged - 0.0, 77.0 (2/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 126.7754%
# Steady state for 3 took 0.025 seconds with direct, OO changed by 0.2344%
# Steady state for 4 took 0.299 seconds with direct, OO changed by 0.0115%
# calculation converged - 0.1, 77.0 (3/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 88.7573%
# Steady state for 3 took 0.020 seconds with direct, OO changed by 0.0876%
# Steady state for 4 took 0.352 seconds with direct, OO changed by 0.0042%
# calculation converged - 0.2, 77.0 (4/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 41.7205%
# Steady state for 3 took 0.028 seconds with direct, OO changed by 0.0560%
# Steady state for 4 took 0.391 seconds with direct, OO changed by 0.0026%
# calculation converged - 0.6, 77.0 (5/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 390.8435%
# Steady state for 3 took 0.023 seconds with direct, OO changed by 0.1022%
# Steady state for 4 took 0.423 seconds with direct, OO changed by 0.0052%
# calculation converged - 1.7, 77.0 (6/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 28.6740%
# Steady state for 3 took 0.024 seconds with direct, OO changed by 0.3462%
# Steady state for 4 took 0.426 seconds with direct, OO changed by 0.0239%
# calculation converged - 4.6, 77.0 (7/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 26.4423%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 1.3219%
# Steady state for 4 took 0.426 seconds with direct, OO changed by 0.1456%
# Steady state for 5 took 3.555 seconds with direct, OO changed by 0.0122%
# calculation converged - 12.9, 77.0 (8/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 191.6675%
# Steady state for 3 took 0.023 seconds with direct, OO changed by 4.0030%
# Steady state for 4 took 0.431 seconds with direct, OO changed by 0.7836%
# Steady state for 5 took 3.733 seconds with direct, OO changed by 0.1202%
# Steady state for 6 took 23.432 seconds with direct, OO changed by 0.0148%
# calculation converged - 35.9, 77.0 (9/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 115.6137%
# Steady state for 3 took 0.030 seconds with direct, OO changed by 7.2915%
# Steady state for 4 took 0.410 seconds with direct, OO changed by 2.2318%
# Steady state for 5 took 4.302 seconds with direct, OO changed by 0.6717%
# Steady state for 6 took 27.840 seconds with direct, OO changed by 0.1758%
# Steady state for 7 took 113.373 seconds with direct, OO changed by 0.0385%
# Steady state for 8 took 552.551 seconds with direct, OO changed by 0.0072%
# calculation converged - 100.0, 77.0 (10/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 4.2875%
# Steady state for 3 took 0.027 seconds with direct, OO changed by 1.3669%
# Steady state for 4 took 0.378 seconds with direct, OO changed by 0.1821%
# calculation converged - 0.0, 300.0 (11/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 19.6413%
# Steady state for 3 took 0.024 seconds with direct, OO changed by 0.3795%
# Steady state for 4 took 0.332 seconds with direct, OO changed by 0.0585%
# calculation converged - 0.0, 300.0 (12/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 90.2526%
# Steady state for 3 took 0.024 seconds with direct, OO changed by 0.1260%
# Steady state for 4 took 0.331 seconds with direct, OO changed by 0.0204%
# calculation converged - 0.1, 300.0 (13/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 138.8686%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 0.0450%
# Steady state for 4 took 0.357 seconds with direct, OO changed by 0.0077%
# calculation converged - 0.2, 300.0 (14/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 26.1777%
# Steady state for 3 took 0.024 seconds with direct, OO changed by 0.0185%
# calculation converged - 0.6, 300.0 (15/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 57.0372%
# Steady state for 3 took 0.030 seconds with direct, OO changed by 0.0130%
# calculation converged - 1.7, 300.0 (16/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 100.1630%
# Steady state for 3 took 0.028 seconds with direct, OO changed by 0.0218%
# calculation converged - 4.6, 300.0 (17/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 5.7984%
# Steady state for 3 took 0.025 seconds with direct, OO changed by 0.0533%
# Steady state for 4 took 0.413 seconds with direct, OO changed by 0.0313%
# Steady state for 5 took 3.723 seconds with direct, OO changed by 0.0180%
# calculation converged - 12.9, 300.0 (18/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 114.5191%
# Steady state for 3 took 0.026 seconds with direct, OO changed by 0.1323%
# Steady state for 4 took 0.415 seconds with direct, OO changed by 0.0797%
# Steady state for 5 took 3.722 seconds with direct, OO changed by 0.0474%
# Steady state for 6 took 24.487 seconds with direct, OO changed by 0.0273%
# Steady state for 7 took 139.269 seconds with direct, OO changed by 0.0151%
# calculation converged - 35.9, 300.0 (19/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 26.0729%
# Steady state for 3 took 0.025 seconds with direct, OO changed by 0.2880%
# Steady state for 4 took 0.405 seconds with direct, OO changed by 0.1779%
# Steady state for 5 took 4.177 seconds with direct, OO changed by 0.1112%
# Steady state for 6 took 27.582 seconds with direct, OO changed by 0.0684%
# Steady state for 7 took 110.505 seconds with direct, OO changed by 0.0412%
# Steady state for 8 took 536.981 seconds with direct, OO changed by 0.0242%
# calculation converged - 100.0, 300.0 (20/20)
# Files saved at DATA/heatmap_TphvAlpha_hetero_4
# Steady state for 2 took 0.002 seconds with direct, OO changed by 1.9942%
# Steady state for 3 took 0.018 seconds with direct, OO changed by 4.5049%
# Steady state for 4 took 0.299 seconds with direct, OO changed by 0.2050%
# calculation converged - 0.0, 77.0 (1/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 44.4723%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.7889%
# Steady state for 4 took 0.291 seconds with direct, OO changed by 0.0383%
# calculation converged - 0.0, 77.0 (2/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 339.0454%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.2355%
# Steady state for 4 took 0.287 seconds with direct, OO changed by 0.0116%
# calculation converged - 0.1, 77.0 (3/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 28.8296%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0883%
# Steady state for 4 took 0.281 seconds with direct, OO changed by 0.0043%
# calculation converged - 0.2, 77.0 (4/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 23.4756%
# Steady state for 3 took 0.018 seconds with direct, OO changed by 0.0573%
# Steady state for 4 took 0.306 seconds with direct, OO changed by 0.0026%
# calculation converged - 0.6, 77.0 (5/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 38.8557%
# Steady state for 3 took 0.018 seconds with direct, OO changed by 0.1061%
# Steady state for 4 took 0.286 seconds with direct, OO changed by 0.0054%
# calculation converged - 1.7, 77.0 (6/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 51.6883%
# Steady state for 3 took 0.018 seconds with direct, OO changed by 0.3604%
# Steady state for 4 took 0.287 seconds with direct, OO changed by 0.0249%
# calculation converged - 4.6, 77.0 (7/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 10.0314%
# Steady state for 3 took 0.018 seconds with direct, OO changed by 1.3767%
# Steady state for 4 took 0.286 seconds with direct, OO changed by 0.1522%
# Steady state for 5 took 2.667 seconds with direct, OO changed by 0.0128%
# calculation converged - 12.9, 77.0 (8/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 16.9755%
# Steady state for 3 took 0.018 seconds with direct, OO changed by 4.1756%
# Steady state for 4 took 0.299 seconds with direct, OO changed by 0.8211%
# Steady state for 5 took 2.689 seconds with direct, OO changed by 0.1268%
# Steady state for 6 took 17.776 seconds with direct, OO changed by 0.0157%
# calculation converged - 35.9, 77.0 (9/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 89.3163%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 7.7162%
# Steady state for 4 took 0.283 seconds with direct, OO changed by 2.3753%
# Steady state for 5 took 2.689 seconds with direct, OO changed by 0.7227%
# Steady state for 6 took 17.898 seconds with direct, OO changed by 0.1915%
# Steady state for 7 took 90.730 seconds with direct, OO changed by 0.0425%
# Steady state for 8 took 357.359 seconds with direct, OO changed by 0.0080%
# calculation converged - 100.0, 77.0 (10/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 280.8895%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 1.3768%
# Steady state for 4 took 0.295 seconds with direct, OO changed by 0.1837%
# calculation converged - 0.0, 300.0 (11/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 34.4107%
# Steady state for 3 took 0.018 seconds with direct, OO changed by 0.3830%
# Steady state for 4 took 0.299 seconds with direct, OO changed by 0.0591%
# calculation converged - 0.0, 300.0 (12/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 373.8665%
# Steady state for 3 took 0.018 seconds with direct, OO changed by 0.1273%
# Steady state for 4 took 0.287 seconds with direct, OO changed by 0.0207%
# calculation converged - 0.1, 300.0 (13/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 4.0967%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 0.0458%
# Steady state for 4 took 0.286 seconds with direct, OO changed by 0.0080%
# calculation converged - 0.2, 300.0 (14/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 18.7813%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0194%
# calculation converged - 0.6, 300.0 (15/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 15.8429%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0152%
# calculation converged - 1.7, 300.0 (16/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 15.1362%
# Steady state for 3 took 0.017 seconds with direct, OO changed by 0.0277%
# Steady state for 4 took 0.297 seconds with direct, OO changed by 0.0154%
# calculation converged - 4.6, 300.0 (17/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 4.4364%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0693%
# Steady state for 4 took 0.276 seconds with direct, OO changed by 0.0409%
# Steady state for 5 took 2.664 seconds with direct, OO changed by 0.0236%
# calculation converged - 12.9, 300.0 (18/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 286.9081%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.1748%
# Steady state for 4 took 0.288 seconds with direct, OO changed by 0.1060%
# Steady state for 5 took 2.629 seconds with direct, OO changed by 0.0635%
# Steady state for 6 took 17.915 seconds with direct, OO changed by 0.0367%
# Steady state for 7 took 90.428 seconds with direct, OO changed by 0.0205%
# calculation converged - 35.9, 300.0 (19/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 3.7423%
# Steady state for 3 took 0.018 seconds with direct, OO changed by 0.3947%
# Steady state for 4 took 0.280 seconds with direct, OO changed by 0.2475%
# Steady state for 5 took 2.634 seconds with direct, OO changed by 0.1571%
# Steady state for 6 took 17.938 seconds with direct, OO changed by 0.0983%
# Steady state for 7 took 90.475 seconds with direct, OO changed by 0.0601%
# Steady state for 8 took 358.588 seconds with direct, OO changed by 0.0359%
# Steady state for 9 took 1314.182 seconds with direct, OO changed by 0.0208%
# calculation converged - 100.0, 300.0 (20/20)
# Files saved at DATA/heatmap_TphvAlpha_hetero_add_4

# %% [markdown]
# I don't really get this at all. It means that the model (as it is) does not work for very small couplings and the plots do not interpolate between $\alpha=0$ and $\alpha>0$, even though there is no purely dark state (causing a non-unique steadystate). What this all suggests to me is that I should use the weak-coupling theory to see what the small frequency behaviour is, since these couplings are like millionths of a percent of the site energies.
#
# What does all this mean then?
#
# - Minimal coupling theory for monomer doesn't cause population inversion.
# - Dimer model doesn't have this population inversion then. Excited state populations decrease as a function of $\alpha$, apart from some weird behaviour at very small couplings.
# - This must mean that, for population inversion to occur the ohmicity of the optical spectral density must be at least somewhere between 1 and 3.

# %%
num = 4
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='bright')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='dark')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='sigma_z')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='sigma_x')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='eig_x')
# Out:
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_hetero_bright_4.pdf
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_hetero_dark_4.pdf
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_hetero_sigma_z_4.pdf
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_hetero_sigma_x_4.pdf
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_hetero_eig_x_4.pdf

# %%
num = 20
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='DS/GS')

heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='OO')

heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='XO')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='OX')

heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='eig_x')
"""heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_x_equiv')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_y')"""

# %% [markdown]
# # Homodimer

# %%
reload(hm)
w_2 = 1.40*ev_to_inv_cm
bias= 0 #0.01*ev_to_inv_cm
V=0.01*ev_to_inv_cm
alpha = 200./pi
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =4
wc = 100.
w_0 = 200.
site_basis = True
Gamma = (w_0**2)/wc
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=2*N)

x_values = np.logspace(-5, np.log10(100), 10, endpoint=True)
#x_values[0] = 0
y_values = [77, 300] #np.linspace(77,300, 2)

"""
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name='heatmap_TphvAlpha', save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.001, conv_obs='OO')"""
# Out:
# "\nss_array, info_array = hm.heat_map_calculator(PARAMS,\n                            x_axis_parameters=['alpha_1', 'alpha_2'],\n                            y_axis_parameters=['T_1', 'T_2'],\n                            x_values=x_values,\n                            y_values=y_values,\n                            dir_name='heatmap_TphvAlpha', save_data=True,\n                            persistent=False, method='direct', threshold=1e-12, \n                                              conv_percent_tol=0.001, conv_obs='OO')"

# %%
print (x_values)
# Out:
# [1.00000000e-05 5.01187234e-05 2.51188643e-04 1.25892541e-03
#  6.30957344e-03 3.16227766e-02 1.58489319e-01 7.94328235e-01
#  3.98107171e+00 1.99526231e+01]

# %%
dirname = 'heatmap_TphvAlpha_homo'
reload(hm)
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname, save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.04, conv_obs='OO', additive=False)
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname+'_add', save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.04, conv_obs='OO', additive=True)
# Out:
# Steady state for 2 took 0.001 seconds with direct, OO changed by 48.1209%
# Steady state for 3 took 0.025 seconds with direct, OO changed by 0.0010%
# calculation converged - 0.0, 77.0 (1/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 1405.4787%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 0.0010%
# calculation converged - 0.0, 77.0 (2/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 44.6846%
# Steady state for 3 took 0.021 seconds with direct, OO changed by 0.0010%
# calculation converged - 0.0, 77.0 (3/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 17.4323%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 0.0012%
# calculation converged - 0.0, 77.0 (4/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 35.7864%
# Steady state for 3 took 0.021 seconds with direct, OO changed by 0.0022%
# calculation converged - 0.0, 77.0 (5/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 226.5614%
# Steady state for 3 took 0.021 seconds with direct, OO changed by 0.0085%
# calculation converged - 0.1, 77.0 (6/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 46.9380%
# Steady state for 3 took 0.023 seconds with direct, OO changed by 0.0491%
# Steady state for 4 took 0.420 seconds with direct, OO changed by 0.0020%
# calculation converged - 0.5, 77.0 (7/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 37.9085%
# Steady state for 3 took 0.023 seconds with direct, OO changed by 0.3849%
# Steady state for 4 took 0.410 seconds with direct, OO changed by 0.0223%
# calculation converged - 2.8, 77.0 (8/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 369.0148%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 3.4414%
# Steady state for 4 took 0.397 seconds with direct, OO changed by 0.4246%
# Steady state for 5 took 3.534 seconds with direct, OO changed by 0.0404%
# Steady state for 6 took 20.078 seconds with direct, OO changed by 0.0032%
# calculation converged - 16.7, 77.0 (9/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 18.6324%
# Steady state for 3 took 0.023 seconds with direct, OO changed by 11.0741%
# Steady state for 4 took 0.405 seconds with direct, OO changed by 3.1343%
# Steady state for 5 took 4.091 seconds with direct, OO changed by 0.9202%
# Steady state for 6 took 27.454 seconds with direct, OO changed by 0.2387%
# Steady state for 7 took 106.425 seconds with direct, OO changed by 0.0521%
# Steady state for 8 took 463.230 seconds with direct, OO changed by 0.0097%
# calculation converged - 100.0, 77.0 (10/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 1433.6436%
# Steady state for 3 took 0.021 seconds with direct, OO changed by 0.0005%
# calculation converged - 0.0, 300.0 (11/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 23.2074%
# Steady state for 3 took 0.021 seconds with direct, OO changed by 0.0005%
# calculation converged - 0.0, 300.0 (12/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 57.4198%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 0.0005%
# calculation converged - 0.0, 300.0 (13/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 460.5173%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 0.0005%
# calculation converged - 0.0, 300.0 (14/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 186.1386%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 0.0006%
# calculation converged - 0.0, 300.0 (15/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 7.7399%
# Steady state for 3 took 0.023 seconds with direct, OO changed by 0.0009%
# calculation converged - 0.1, 300.0 (16/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 28.1933%
# Steady state for 3 took 0.023 seconds with direct, OO changed by 0.0026%
# calculation converged - 0.5, 300.0 (17/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 1308.4478%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 0.0127%
# calculation converged - 2.8, 300.0 (18/20)
# Steady state for 2 took 0.001 seconds with direct, OO changed by 8.3981%
# Steady state for 3 took 0.024 seconds with direct, OO changed by 0.0689%
# Steady state for 4 took 0.413 seconds with direct, OO changed by 0.0410%
# Steady state for 5 took 3.445 seconds with direct, OO changed by 0.0238%
# calculation converged - 16.7, 300.0 (19/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 10.4238%
# Steady state for 3 took 0.023 seconds with direct, OO changed by 0.2969%
# Steady state for 4 took 0.392 seconds with direct, OO changed by 0.1835%
# Steady state for 5 took 4.075 seconds with direct, OO changed by 0.1146%
# Steady state for 6 took 27.757 seconds with direct, OO changed by 0.0706%
# Steady state for 7 took 105.491 seconds with direct, OO changed by 0.0425%
# Steady state for 8 took 462.433 seconds with direct, OO changed by 0.0249%
# calculation converged - 100.0, 300.0 (20/20)
# Files saved at DATA/heatmap_TphvAlpha_homo_2
# Steady state for 4 took 0.283 seconds with direct, OO changed by 52.3383%
# calculation converged - 0.0, 77.0 (1/20)
# Steady state for 4 took 0.269 seconds with direct, OO changed by 52.9587%
# calculation converged - 0.0, 77.0 (2/20)
# Steady state for 4 took 0.290 seconds with direct, OO changed by 37.2960%
# calculation converged - 0.0, 77.0 (3/20)
# Steady state for 4 took 0.279 seconds with direct, OO changed by 23.6096%
# calculation converged - 0.0, 77.0 (4/20)
# Steady state for 4 took 0.270 seconds with direct, OO changed by 56.8861%
# calculation converged - 0.0, 77.0 (5/20)
# Steady state for 4 took 0.298 seconds with direct, OO changed by 47.4871%
# calculation converged - 0.1, 77.0 (6/20)
# Steady state for 4 took 0.277 seconds with direct, OO changed by 25.2501%
# calculation converged - 0.5, 77.0 (7/20)
# Steady state for 4 took 0.296 seconds with direct, OO changed by 37.2464%
# Steady state for 5 took 2.714 seconds with direct, OO changed by 0.0011%
# calculation converged - 2.8, 77.0 (8/20)
# Steady state for 4 took 0.281 seconds with direct, OO changed by 16.9771%
# Steady state for 5 took 2.724 seconds with direct, OO changed by 0.0420%
# Steady state for 6 took 18.325 seconds with direct, OO changed by 0.0033%
# calculation converged - 16.7, 77.0 (9/20)
# Steady state for 4 took 0.279 seconds with direct, OO changed by 60.7306%
# Steady state for 5 took 2.700 seconds with direct, OO changed by 0.9780%
# Steady state for 6 took 18.772 seconds with direct, OO changed by 0.2565%
# Steady state for 7 took 95.275 seconds with direct, OO changed by 0.0566%
# Steady state for 8 took 385.608 seconds with direct, OO changed by 0.0106%
# calculation converged - 100.0, 77.0 (10/20)
# Steady state for 4 took 0.281 seconds with direct, OO changed by 13.4162%
# calculation converged - 0.0, 300.0 (11/20)
# Steady state for 4 took 0.301 seconds with direct, OO changed by 0.6666%
# calculation converged - 0.0, 300.0 (12/20)
# Steady state for 4 took 0.296 seconds with direct, OO changed by 12.6033%
# calculation converged - 0.0, 300.0 (13/20)
# Steady state for 4 took 0.277 seconds with direct, OO changed by 81.5311%
# calculation converged - 0.0, 300.0 (14/20)
# Steady state for 4 took 0.294 seconds with direct, OO changed by 0.3307%
# calculation converged - 0.0, 300.0 (15/20)
# Steady state for 4 took 0.286 seconds with direct, OO changed by 5236.4058%
# calculation converged - 0.1, 300.0 (16/20)
# Steady state for 4 took 0.290 seconds with direct, OO changed by 3812.2301%
# calculation converged - 0.5, 300.0 (17/20)
# Steady state for 4 took 0.276 seconds with direct, OO changed by 68.9365%
# Steady state for 5 took 2.798 seconds with direct, OO changed by 0.0053%
# calculation converged - 2.8, 300.0 (18/20)
# Steady state for 4 took 0.288 seconds with direct, OO changed by 285.5611%
# Steady state for 5 took 2.750 seconds with direct, OO changed by 0.0312%
# calculation converged - 16.7, 300.0 (19/20)
# Steady state for 4 took 0.289 seconds with direct, OO changed by 1254.4529%
# Steady state for 5 took 2.784 seconds with direct, OO changed by 0.1612%
# Steady state for 6 took 18.623 seconds with direct, OO changed by 0.1008%
# Steady state for 7 took 95.224 seconds with direct, OO changed by 0.0617%
# Steady state for 8 took 384.087 seconds with direct, OO changed by 0.0368%
# calculation converged - 100.0, 300.0 (20/20)
# Files saved at DATA/heatmap_TphvAlpha_homo_add_2

# %%
def steadystate_observable(ss_array, PARAMS, observable):
    ss_obs_array = np.zeros(shape=ss_array.shape)
    for y, ss_row in enumerate(ss_array):
        for x, ss_dm in enumerate(ss_row):
            dim, size = ss_dm.dims[0][1::], int(ss_dm.shape[0]/PARAMS['sys_dim'])
            
            nstates, state2idx, idx2state = qt.enr_state_dictionaries(dim, dim[0]+0)
            exc_diff = 0 # function finds the correct exc_diff given some dm
            while nstates != size:
                nstates, state2idx, idx2state = qt.enr_state_dictionaries(dim, dim[0]+exc_diff)
            
            #print exc_diff, dim[0]+exc_diff
            PARAMS.update({'N_1':dim[0], 'N_2':dim[1], 'exc':dim[0]+exc_diff})
            obs_op = make_expectation_operators(PARAMS)[observable]
            #print obs_op.shape, ss_dm.shape
            ss_obs_array[y][x] = (obs_op*ss_dm).tr().real #info_test[y][x]['solution_time']
    return ss_obs_array

# With saved data, we can calculte things differently

def heatmap_loader(num, dir_name="heatmap"):
    # Only loads data of heatmap into memory, does not plot
    directory = 'DATA/'+dir_name+'_'+str(num)
    ss_array = load_obj(directory+'/ss_array')
    PARAMS = load_obj(directory+'/PARAMS')
    info_array = load_obj(directory+'/info_array') # reverse ordering -> lower_N-higher_N
    return ss_array, PARAMS, info_array

num = 2
heatmap_plotter(num=num, dir_name=dirname, 
                     print_params=False, observable='dark')
heatmap_plotter(num=num, dir_name=dirname, 
                     print_params=False, observable='bright')
heatmap_plotter(num=num, dir_name=dirname, 
                     print_params=False, observable='sigma_x')
# Out:
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_homo_dark_2.pdf
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_homo_bright_2.pdf
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_homo_sigma_x_2.pdf

# %%
num = 19

heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=True, observable='DS/GS')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='bright')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='dark')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='OO')

heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='XO')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='OX')

heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_x')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_x_equiv')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_y')

heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='sigma_z')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='sigma_x')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='sigma_y')

# %%
num = 1
dir_name = 'heatmap_TphvAlpha_a19'
hm = heatmap_loader(19, dir_name='heatmap_TphvAlpha')
hm2 = heatmap_loader(1, dir_name='heatmap_TphvAlpha_a19')
print hm[0]
"""heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=True, observable='DS/GS')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='bright')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='dark')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='OO')

heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='XO')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='OX')

heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='eig_x')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='eig_x_equiv')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='eig_y')

heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='sigma_z')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='sigma_x')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='sigma_y')"""

# %% [markdown]
# # Asymmetrical phonon environments

# %%
reload(hm)
w_2 = 1.40*ev_to_inv_cm
bias= 0 #0.01*ev_to_inv_cm
V=0.01*ev_to_inv_cm
alpha = 5.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =4
wc = 100.
w_0 = 200.
site_basis = True
Gamma = (w_0**2)/wc
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=2*N)

x_values = np.logspace(-2, np.log10(100), 20, endpoint=True)
#x_values[0] = 0
y_values = [77, 300] #np.linspace(77,300, 2)
dirname = "heatmap_TphvAlpha_assymmetrical"

ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname, save_data=True,
                            persistent=False, method='direct', threshold=1e-7, 
                                              conv_percent_tol=0.025, conv_obs='OO')
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname, save_data=True,
                            persistent=False, method='direct', threshold=1e-7, 
                                              conv_percent_tol=0.025, conv_obs='OO', additive=True)
# Out:
# Steady state for 2 took 0.002 seconds with direct, OO changed by 41.7399%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 0.4486%
# Steady state for 4 took 0.349 seconds with direct, OO changed by 0.0322%
# calculation converged - 0.0, 77.0 (1/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 3.7877%
# Steady state for 3 took 0.021 seconds with direct, OO changed by 0.4491%
# Process PoolWorker-864:
# Process PoolWorker-861:
# Process PoolWorker-862:
# Process PoolWorker-863:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#     self.run()
#     self.run()
#     self.run()
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/multiprocessing/pool.py", line 113, in worker
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/multiprocessing/pool.py", line 113, in worker
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/multiprocessing/pool.py", line 113, in worker
#     result = (True, func(*args, **kwds))
#     result = (True, func(*args, **kwds))
#     task = get()
#     result = (True, func(*args, **kwds))
#   File "phonons.py", line 78, in operator_func
#   File "phonons.py", line 68, in operator_func
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/multiprocessing/queues.py", line 376, in get
#   File "phonons.py", line 68, in operator_func
#     Xi_2 += 0.5*np.pi*e_jk*gamma_2 * A_jk_2 * outer_eigen
#     Chi_1 += 0.5*np.pi*e_jk*gamma_1 * coth(e_jk * beta_1 / 2)*A_jk_1*outer_eigen
#     Chi_1 += 0.5*np.pi*e_jk*gamma_1 * coth(e_jk * beta_1 / 2)*A_jk_1*outer_eigen
#     return recv()
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/qutip/qobj.py", line 436, in __add__
#   File "utils.py", line 269, in coth
#   File "utils.py", line 269, in coth
# KeyboardInterrupt
#     out.data = self.data + other.data
#     return float(sympy.coth(x))
#     return float(sympy.coth(x))
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/cache.py", line 93, in wrapper
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/cache.py", line 93, in wrapper
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/scipy/sparse/base.py", line 414, in __add__
#     retval = cfunc(*args, **kwargs)
#     return self._add_sparse(other)
#     retval = cfunc(*args, **kwargs)
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/scipy/sparse/compressed.py", line 342, in _add_sparse
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/compatibility.py", line 850, in wrapper
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/compatibility.py", line 850, in wrapper
#     result = user_function(*args, **kwds)
#     return self._binopt(other, '_plus_')
#     result = user_function(*args, **kwds)
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/function.py", line 446, in __new__
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/function.py", line 441, in __new__
# KeyboardInterrupt
#     result = super(Function, cls).__new__(cls, *args, **options)
#     result = result.evalf(mlib.libmpf.prec_to_dps(pr))
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/evalf.py", line 1395, in evalf
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/cache.py", line 93, in wrapper
#     retval = cfunc(*args, **kwargs)
#     from sympy import Float, Number
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/compatibility.py", line 850, in wrapper
# KeyboardInterrupt
#     result = user_function(*args, **kwds)
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/function.py", line 250, in __new__
#     evaluated = cls.eval(*args)
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/functions/elementary/hyperbolic.py", line 589, in eval
#     return -cls(-arg)
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/cache.py", line 93, in wrapper
#     retval = cfunc(*args, **kwargs)
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/compatibility.py", line 850, in wrapper
#     result = user_function(*args, **kwds)
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/function.py", line 446, in __new__
#     result = result.evalf(mlib.libmpf.prec_to_dps(pr))
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/evalf.py", line 1419, in evalf
#     result = evalf(self, prec + 4, options)
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/evalf.py", line 1314, in evalf
#     re, im = xe.as_real_imag()
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/expr.py", line 1770, in as_real_imag
#     return (re(self), im(self))
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/cache.py", line 93, in wrapper
#     retval = cfunc(*args, **kwargs)
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/compatibility.py", line 850, in wrapper
#     result = user_function(*args, **kwds)
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/function.py", line 425, in __new__
#     if n not in cls.nargs:
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/sets/sets.py", line 554, in __contains__
#     symb = sympify(self.contains(other))
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/sets/sets.py", line 285, in contains
#     other = sympify(other, strict=True)
#   File "/Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/sympy/core/sympify.py", line 290, in sympify
#     return converter[cls](a)
# KeyboardInterrupt

# %%
# Out:
# Steady state for 4 took 0.314 seconds with direct, OO changed by 46.9712%
# calculation converged - 0.0, 77.0 (1/20)
# Steady state for 4 took 0.318 seconds with direct, OO changed by 382.2063%
# calculation converged - 0.0, 77.0 (2/20)
# Steady state for 4 took 0.306 seconds with direct, OO changed by 6.2742%
# calculation converged - 0.1, 77.0 (3/20)
# Steady state for 4 took 0.305 seconds with direct, OO changed by 56.3518%
# calculation converged - 0.2, 77.0 (4/20)
# Steady state for 4 took 0.300 seconds with direct, OO changed by 802.1107%
# calculation converged - 0.6, 77.0 (5/20)
# Steady state for 4 took 0.306 seconds with direct, OO changed by 27.1317%
# Steady state for 5 took 2.732 seconds with direct, OO changed by 0.0020%
# calculation converged - 1.7, 77.0 (6/20)
# Steady state for 4 took 0.296 seconds with direct, OO changed by 53.8136%
# Steady state for 5 took 2.928 seconds with direct, OO changed by 0.0031%
# calculation converged - 4.6, 77.0 (7/20)
# Steady state for 4 took 0.325 seconds with direct, OO changed by 0.7156%
# Steady state for 5 took 2.796 seconds with direct, OO changed by 0.0157%
# calculation converged - 12.9, 77.0 (8/20)
# Steady state for 4 took 0.306 seconds with direct, OO changed by 39.3607%
# Steady state for 5 took 2.761 seconds with direct, OO changed by 0.1621%
# Steady state for 6 took 18.557 seconds with direct, OO changed by 0.0199%
# calculation converged - 35.9, 77.0 (9/20)
# Steady state for 4 took 0.304 seconds with direct, OO changed by 215.0018%
# Steady state for 5 took 2.754 seconds with direct, OO changed by 1.1081%
# Steady state for 6 took 18.370 seconds with direct, OO changed by 0.3021%
# Steady state for 7 took 93.959 seconds with direct, OO changed by 0.0669%
# Steady state for 8 took 374.819 seconds with direct, OO changed by 0.0125%
# calculation converged - 100.0, 77.0 (10/20)
# Steady state for 4 took 0.294 seconds with direct, OO changed by 116.9263%
# calculation converged - 0.0, 300.0 (11/20)
# Steady state for 4 took 0.301 seconds with direct, OO changed by 218.3924%
# calculation converged - 0.0, 300.0 (12/20)
# Steady state for 4 took 0.300 seconds with direct, OO changed by 245.2384%
# calculation converged - 0.1, 300.0 (13/20)
# Steady state for 4 took 0.289 seconds with direct, OO changed by 0.4402%
# calculation converged - 0.2, 300.0 (14/20)
# Steady state for 4 took 0.302 seconds with direct, OO changed by 467.1198%
# calculation converged - 0.6, 300.0 (15/20)
# Steady state for 4 took 0.303 seconds with direct, OO changed by 20.6118%
# Steady state for 5 took 2.748 seconds with direct, OO changed by 0.0064%
# calculation converged - 1.7, 300.0 (16/20)
# Steady state for 4 took 0.289 seconds with direct, OO changed by 180.4568%
# Steady state for 5 took 2.659 seconds with direct, OO changed by 0.0092%
# calculation converged - 4.6, 300.0 (17/20)
# Steady state for 4 took 0.289 seconds with direct, OO changed by 138.0612%
# Steady state for 5 took 2.696 seconds with direct, OO changed by 0.0169%
# calculation converged - 12.9, 300.0 (18/20)
# Steady state for 4 took 0.287 seconds with direct, OO changed by 75.7812%
# Steady state for 5 took 2.738 seconds with direct, OO changed by 0.0381%
# calculation converged - 35.9, 300.0 (19/20)
# Steady state for 4 took 0.295 seconds with direct, OO changed by 11.5492%
# Steady state for 5 took 2.738 seconds with direct, OO changed by 0.0878%
# Steady state for 6 took 17.974 seconds with direct, OO changed by 0.0593%
# Steady state for 7 took 94.887 seconds with direct, OO changed by 0.0379%
# calculation converged - 100.0, 300.0 (20/20)
# Files saved at DATA/heatmap_TphvAlpha_23

# %%
num = 1
dirname = "heatmap_TphvAlpha_assymmetrical"
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=True, observable='DS/GS')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='bright')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='dark')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='OO')

heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='XO')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='OX')

heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='eig_x')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='eig_x_equiv')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='eig_y')

heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='sigma_z')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='sigma_x')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='sigma_y')

# %% [markdown]
# # Redfield comparison

# %%
import weak_phonons as wp
reload(wp)

w_2 = 1.4*ev_to_inv_cm
bias = 0.01*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 0.01*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 10
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =5
wc = 100.
w_0 = 200.
site_basis = True
Gamma = (w_0**2)/wc
rho_s = []
rho_wc = []
phonons = np.logspace(-1,np.log10(20),8)

for alpha in phonons:
    PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                          V = V, alpha=alpha,
                          T_EM=6000., T_ph =180., alpha_EM=alpha_EM, shift=True,
                          num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                          silent=True, exc_diff=0)
    energies, states = exciton_states(PARAMS)
    eig_x = states[0]*states[1].dag()+states[1]*states[0].dag()
    dark = states[0]*states[0].dag()
    #print PARAMS.keys()
    #L = wp.L_weak_phonon_SES(PARAMS)
    H, L = wp.get_wc_H_and_L(PARAMS, silent=True, threshold=0.)
    
    Hs, Ls, Ladd = get_H_and_L(PARAMS, silent=True, threshold=0.)
    rho_s.append(steadystate(Hs[1], [Ls]))
    rho_wc.append(steadystate(H, [L]))
    #print ss.diag()
print "Calculation complete"
# Out:
# Weak coupling Liouvillian took 3.54 seconds
# Weak coupling Liouvillian took 4.24 seconds
# Weak coupling Liouvillian took 5.67 seconds
# Weak coupling Liouvillian took 7.14 seconds
# Weak coupling Liouvillian took 10.33 seconds
# Weak coupling Liouvillian took 12.65 seconds
# Weak coupling Liouvillian took 15.01 seconds
# Weak coupling Liouvillian took 18.09 seconds
# Calculation complete

# %%
bright = states[1]*states[1].dag()
ops = make_expectation_operators(PARAMS)

f, ((ax1, ax2),(ax3, ax4))  = plt.subplots(2, 2, sharex=True, figsize=(12,6))

ax1.plot(phonons, [(r*ops['OO']).tr() for r in rho_s], label='CC')
ax1.plot(phonons, [(r*OO_proj).tr() for r in rho_wc], label='Redfield')
#plt.xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax1.set_ylabel(r"GS")
ax1.set_xlim(phonons[0], phonons[-1])
ax1.legend()

ax2.plot(phonons, [(r*ops['dark']).tr() for r in rho_s], label='CC')
ax2.plot(phonons, [(r*dark).tr() for r in rho_wc], label='Redfield')
#ax2.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax2.set_ylabel(r"DS")
ax2.legend()


ax3.plot(phonons, [(r*ops['bright']).tr() for r in rho_s], label='CC')
ax3.plot(phonons, [(r*bright).tr() for r in rho_wc], label='Redfield')
ax3.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax3.set_ylabel(r"BS")
ax3.legend()


ax4.plot(phonons, [(r*ops['eig_x']).tr() for r in rho_s], label='CC')
ax4.plot(phonons, [(r*eig_x).tr() for r in rho_wc], label='Redfield')
ax4.set_xlabel(r"$\alpha_1$, $\alpha_2$ $(cm^{-1})$")
ax4.set_ylabel(r"$\tilde{\sigma}_x$")
ax4.legend()

plt.savefig("PLOTS/Redfield-CC.pdf")

# %%
import weak_phonons as wp
reload(wp)

w_2 = 1.4*ev_to_inv_cm
bias = 0.01*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 0.011*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 10
alpha_bias = 0.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =5
wc = 100.
w_0 = sqrt(bias**2 +4*(V**2))
site_basis = True
Gamma = (w_0**2)/wc
gs_s = []
gs_wc = []
phonons = np.linspace(1e-3,20,20)
for alpha in phonons:
    PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                          V = V, alpha=alpha,
                          T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                          num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                          silent=True, exc_diff=N)
    #print PARAMS.keys()
    #L = wp.L_weak_phonon_SES(PARAMS)

    H, L = wp.get_wc_H_and_L(PARAMS, silent=True, threshold=0.)

    Hs, Ls = get_H_and_L(PARAMS, silent=True, threshold=0.)
    sss = steadystate(Hs[1], [Ls])
    if alpha == 0.:
        print sss.ptrace(0)
    gs_s.append(sss.ptrace(0).diag()[0])
    ss = steadystate(H, [L])
    #print ss.diag()
    gs_wc.append(ss.diag()[0])
plt.plot(phonons, gs_s, label='sc')
plt.plot(phonons, gs_wc, label='wc')
plt.legend()
plt.show()

# %% [markdown]
# # Plotting T vs $\alpha$

# %%
heatmap_plotter(num=2, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_x')
"""heatmap_plotter(num=2, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_x_equiv')
heatmap_plotter(num=2, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_y')"""
heatmap_plotter(num=2, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='OO')
heatmap_plotter(num=2, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='XO')
heatmap_plotter(num=2, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='OX')
heatmap_plotter(num=2, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='sigma_z')
heatmap_plotter(num=2, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='sigma_x')

# %%
def populations_plotter(ss_info_params=False, num=-1, plot_SD=True, dir_name="heatmap", 
                     print_params=False, observable='sigma_x'):
    if num>=0:
        ss_array, PARAMS, info_array = heatmap_loader(num, dir_name=dir_name)
        
    if ss_info_params:
        if num>=0:
            print "Not loading saved data, using data from arguments instead"
        ss_array,info_array, PARAMS = ss_info_params[0], ss_info_params[1], ss_info_params[2]
    info = info_array[0][0]
    #print info
    
    try:
        # To catch an old bug where these were in "info" not in PARAMS
        keys = ['x_values', 'y_values', 'y_axis_parameters', 'x_axis_parameters']
        PARAMS.update(dict((key, info[key]) for key in keys))
    except Exception as err:
        print "plotting in new style"
    if plot_SD:
        plot_UD_SD(PARAMS["Gamma_1"], PARAMS["alpha_1"], PARAMS["w0_1"], eps=8000.)
    #print PARAMS
    ss_array = steadystate_observable(ss_array, PARAMS, observable)
    
    f, axes = plt.subplots(1,1, figsize=(13,6))
    for i, y_val in enumerate(PARAMS['y_values']):
        x_values = PARAMS['x_values']

        axes.plot(x_values, ss_array[i], 
                  label=str(PARAMS['y_axis_parameters'])+"="+str(y_val))
    if print_params:
        print_PARAMS(PARAMS)
    
    plt.xlabel(r', ($cm^{-1}$)'.join(r"\\"+PARAMS['x_axis_parameters']))
    plt.ylabel("Steadystate "+observable)
    #plt.ylabel(', '.join(info['y_axis_parameters']))
    plt.legend()
    plt.grid()
    plot_filename = 'PLOTS/'+dir_name+'_'+str(num)+'.pdf'
    plt.savefig(plot_filename)
    print "saved at {}".format(plot_filename)
    plt.show()

# %%
ss_info_params = [ss_array, info_array, PARAMS]

heatmap_plotter(ss_info_params=ss_info_params, plot_SD=False,
                print_params=False, observable='sigma_x')

# %% [markdown]
# # Comparing SS solution methods (direct, inverse power, eigen)

# %%
from qutip import build_preconditioner

def method_plotter(N_vals, data_dict, info_dict, ax1, ax2, linestyle="solid"):
    lw=1.
    if linestyle == 'dashed':
        lw=1.8
    for i, key in enumerate(data_dict.keys()):
        ax1.plot(N_vals, data_dict[key], label=key, color=colourWheel[i], ls=linestyle, linewidth=lw)
        #print info_dict[key]
        ax2.plot(N_vals, info_dict[key], label=key, color=colourWheel[i], ls=linestyle, linewidth=lw)
    ax1.legend()
    ax2.legend()
    ax1.set_ylabel("Coherence")
    ax2.set_ylabel("Solution time")


def method_comparison(N_i, N_f, plot=False, site_basis=True):
    methods = ['direct']
    data_dict = dict()
    info_dict = dict()
    N_vals = range(N_i, N_f)
    for exc_diff in [0,3,4]:
        for N in N_vals:
            PARAMS.update({'N_1':N, 'N_2':N, 'exc':int(2*N-exc_diff)})
            H, L = get_H_and_L(PARAMS,silent=False, threshold=1e-7, site_basis=site_basis)
            exps = make_expectation_operators(PARAMS, site_basis=site_basis)
            for method in methods:
                try:
                    M=None

                    if "iterative" in method:
                        ti = time.time()
                        M = build_preconditioner(H[1], [L], use_rcm=True, ILU_MILU='smilu_2')
                        print("Building preconditioner took {} seconds".format(time.time()-ti))
                    ss, full_info = calculate_steadystate(H, L, method=method, persistent=True)
                    info = full_info['solution_time']

                    coh = (exps['sigma_x']*ss).tr().real
                    try:
                        data_dict[exc_diff].append(coh)
                        info_dict[exc_diff].append(info)
                    except KeyError:
                        data_dict[exc_diff] = [coh]
                        info_dict[exc_diff] = [info]
                except Exception as err:
                    print( "{} failed due to : {}".format(method, err))
                    try:
                        data_dict[exc_diff].append(None)
                        info_dict[exc_diff].append(None)
                    except KeyError:
                        data_dict[exc_diff] = [None]
                        info_dict[exc_diff] = [None]
    #if plot:
    #    method_plotter(N_vals, data_dict, info_dict)
    return N_vals, data_dict, info_dict

N_vals, data_dict_sb, info_dict_sb = method_comparison(3,7)
#N_vals, data_dict_eb, info_dict_eb = method_comparison(3,7, site_basis=False)

f, (ax1, ax2) = plt.subplots(2,1, figsize=(10,7))
method_plotter(N_vals, data_dict_sb, info_dict_sb, ax1, ax2)
#method_plotter(N_vals, data_dict_eb, info_dict_eb, ax1, ax2, linestyle="dashed")

# %% [markdown]
# # Plotting methods

# %%
heatmap_plotter(2, plot_SD=False, dir_name='heatmap_excvN', 
                     print_params=False, observable='')

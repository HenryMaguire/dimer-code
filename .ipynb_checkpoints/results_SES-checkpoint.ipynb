# %%
# Incase we have to clear all variables
# %reset -f

# %%
# %matplotlib inline 
import matplotlib
import matplotlib.pyplot as plt


import time
import heatmap_setup as hm
import numpy as np


from SES_setup import *
from utils import *
from style import *
colourWheel =['#329932',
            '#ff6961',
            'b',
            '#6a3d9a',
            '#fb9a99',
            '#e31a1c',
            '#fdbf6f',
            '#ff7f00',
            '#cab2d6',
            '#6a3d9a',
            '#ffff99',
            '#b15928',
            '#67001f',
            '#b2182b',
            '#d6604d',
            '#f4a582',
            '#fddbc7',
            '#f7f7f7',
            '#d1e5f0',
            '#92c5de',
            '#4393c3',
            '#2166ac',
            '#053061'][::-1]
plt.rcParams['axes.labelsize'] = 25
plt.rcParams['legend.fontsize'] = 'large'
# Out:
# SES_setup loaded globally

# %%
def steadystate_observable(ss_array, PARAMS, observable):
    ss_obs_array = np.zeros(shape=ss_array.shape)
    for y, ss_row in enumerate(ss_array):
        for x, ss_dm in enumerate(ss_row):
            dim, size = ss_dm.dims[0][1::], int(ss_dm.shape[0]/PARAMS['sys_dim'])
            
            nstates, state2idx, idx2state = qt.enr_state_dictionaries(dim, dim[0]+0)
            exc_diff = 0 # function finds the correct exc_diff given some dm
            while nstates != size:
                nstates, state2idx, idx2state = qt.enr_state_dictionaries(dim, dim[0]+exc_diff)
            
            #print exc_diff, dim[0]+exc_diff
            PARAMS.update({'N_1':dim[0], 'N_2':dim[1], 'exc':dim[0]+exc_diff})
            obs_op = make_expectation_operators(PARAMS)[observable]
            #print obs_op.shape, ss_dm.shape
            ss_obs_array[y][x] = (obs_op*ss_dm).tr().real #info_test[y][x]['solution_time']
    return ss_obs_array

# With saved data, we can calculte things differently

def heatmap_loader(num, dir_name="heatmap"):
    # Only loads data of heatmap into memory, does not plot
    directory = 'DATA/'+dir_name+'_'+str(num)
    ss_array = load_obj(directory+'/ss_array')
    PARAMS = load_obj(directory+'/PARAMS')
    info_array = load_obj(directory+'/info_array') # reverse ordering -> lower_N-higher_N
    return ss_array, PARAMS, info_array


def heatmap_plotter(num=-1, plot_SD=True, dir_name="heatmap", 
                     print_params=False, observable='sigma_x'):
    
    # If ss_info_params list is provided, then makes heatmap from memory not disk
    
    if num>=0:
        ss_array, PARAMS, info_array = heatmap_loader(num, dir_name=dir_name)
        ss_array_add, PARAMS, info_array_add = heatmap_loader(num, dir_name=dir_name+'_add')
        data = {'non-add.': [ss_array,'solid'], 'add.': [ss_array_add, 'dashed']}
    info = info_array[0][0]
    try:
        # To catch an old bug where these were in "info" not in PARAMS
        keys = ['x_values', 'y_values', 'y_axis_parameters', 'x_axis_parameters']
        PARAMS.update(dict((key, info[key]) for key in keys))
    except Exception as err:
        print "plotting in new style"
    #print info
    
    if plot_SD:
        plot_UD_SD(PARAMS["Gamma_1"], PARAMS["alpha_1"], PARAMS["w0_1"], eps=8000.)
    eta = np.sqrt(PARAMS['bias']**2 + 4*PARAMS['V']**2)
    f, axes = plt.subplots(1,1, figsize=(13,6))
    for key in data.keys():
        if observable=='DS/GS':
            ss_arrayGS = steadystate_observable(data[key][0], PARAMS, 'OO')
            ss_arrayDS = steadystate_observable(data[key][0], PARAMS, 'dark')
            ss_arrayBS = steadystate_observable(data[key][0], PARAMS, 'bright')
            ss_array = (ss_arrayDS+ss_arrayBS)/ss_arrayGS
        else:
            ss_array = steadystate_observable(data[key][0], PARAMS, observable)
        
        ylab = ' = '.join(["$"+l+"$" for l in PARAMS['y_axis_parameters']])
        for i, y_val in enumerate(PARAMS['y_values']):
            x_values = PARAMS['x_values']

            lbl = ylab+"="+"{:0.1f}".format(y_val)
            if key == 'add.':
                lbl = None
            axes.plot(x_values, ss_array[i], label=lbl, 
                      linestyle=data[key][1], color=colourWheel[i*8])
            
        if print_params:
            print_PARAMS(PARAMS)
        labs = ("$\\"+l+"$" for l in PARAMS['x_axis_parameters'])
        xlab = ' , '.join(labs)
        
        plt.xlabel(xlab+" (cm$^{-1}$)")
        #plt.xlabel(', '.join(PARAMS['x_axis_parameters']))
        try:
            plt.ylabel(r"Steadystate "+make_expectation_labels()[observable])
        except:
            plt.ylabel(r"Steadystate "+observable)
    #plt.ylabel(', '.join(info['y_axis_parameters']))
    plt.legend()
    #plt.grid()
    plt.xlim(x_values[0], x_values[-1])
    plot_filename = 'PLOTS/'+dir_name+'_'+observable+'_'+str(num)+'.pdf'
    plt.savefig(plot_filename,bbox_inches='tight')
    plt.show()
    print "saved at {}".format(plot_filename)

# Example of loading data to memory
"""ss_info_params = [ss_array, info_array, PARAMS]

heatmap_plotter(ss_info_params=ss_info_params, plot_SD=False,
                print_params=False, observable='sigma_x')
heatmap_plotter(num=5, plot_SD=False, dir_name="heatmap_excvN",
                print_params=False, observable='sigma_x')"""
# Out:
# 'ss_info_params = [ss_array, info_array, PARAMS]\n\nheatmap_plotter(ss_info_params=ss_info_params, plot_SD=False,\n                print_params=False, observable=\'sigma_x\')\nheatmap_plotter(num=5, plot_SD=False, dir_name="heatmap_excvN",\n                print_params=False, observable=\'sigma_x\')'

# %% [markdown]
# Okay, we want to know:
# - What is the nature of the coherence we are seeing?
#     - How does site coherence and population inversion relate to exciton coherence?

# %% [markdown]
# ### Base Hamiltonian and Bath parameters
#
# These get updated dynamically by the various functions. `SES_setup.PARAMS_setup` just imposes the relevant symmetry behind the scenes so the API is clean and so that we can reuse code for dimer case - e.g. $\alpha_1 = \alpha_2$, no doubly excited state.

# %%
w_2 = 1.4*ev_to_inv_cm
bias = 0.02*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 0.0*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 100./pi
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =7
wc = 100.
w_0 = 200.
site_basis = True
Gamma = (w_0**2)/wc
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=False, exc_diff=2*N)

# %%
H, L = get_H_and_L(PARAMS)

# %%
eta = np.sqrt(PARAMS['bias']**2 + 4*PARAMS['V']**2)
print (2*PARAMS['V']/eta)
print (PARAMS['bias']/eta)
print (1/np.sqrt(2))

# %%
np.linspace(200, 600, 5, endpoint=False)

# %%
np.log(0.0001)
np.logspace(-5, 2, 10, endpoint=False)
# Out:
# array([1.00000000e-05, 5.01187234e-05, 2.51188643e-04, 1.25892541e-03,
#        6.30957344e-03, 3.16227766e-02, 1.58489319e-01, 7.94328235e-01,
#        3.98107171e+00, 1.99526231e+01])

# %% [markdown]
# ## Heterodimer
# Shouldn't increasing the phonon coupling strength lead to suppression of ground state population?

# %%
reload(hm)
w_2 = 1.4*ev_to_inv_cm
bias=0.01*ev_to_inv_cm
V=0.01*ev_to_inv_cm
alpha = 200./pi
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =4
wc = 100.
w_0 = 200.
site_basis = True
Gamma = (w_0**2)/wc
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=2*N)

x_values = np.logspace(-2, np.log10(100), 10, endpoint=True)
print x_values
y_values = [77, 300] #np.linspace(77,300, 2)

"""

ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name='heatmap_TphvAlpha', save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.1, conv_obs='OO')
"""
dirname = 'heatmap_TphvAlpha_hetero'
# Out:
# [  1.00000000e-02   2.78255940e-02   7.74263683e-02   2.15443469e-01
#    5.99484250e-01   1.66810054e+00   4.64158883e+00   1.29154967e+01
#    3.59381366e+01   1.00000000e+02]

# %%
ss_array, PARAMS, info_array = heatmap_loader(16, dir_name="heatmap_TphvAlpha")
print zip(PARAMS['x_values'], steadystate_observable(ss_array, PARAMS, 'OO')[0])

# %%
reload(hm)
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname, save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                            conv_percent_tol=0.01, conv_obs='OO', additive=False)
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname+'_add', save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.01, conv_obs='OO', additive=True)
# Out:
# True
# Steady state for 2 took 0.003 seconds with direct, OO changed by 43.5668%
# Steady state for 3 took 0.035 seconds with direct, OO changed by 4.5313%
# Steady state for 4 took 0.084 seconds with direct, OO changed by 0.2060%
# calculation converged - 0.0, 77.0 (1/20)
# True
# Steady state for 2 took 0.022 seconds with direct, OO changed by 83.0552%
# Steady state for 3 took 0.030 seconds with direct, OO changed by 0.7871%
# Steady state for 4 took 0.105 seconds with direct, OO changed by 0.0382%
# calculation converged - 0.0, 77.0 (2/20)
# True
# Steady state for 2 took 0.009 seconds with direct, OO changed by 136.3902%
# Steady state for 3 took 0.016 seconds with direct, OO changed by 0.2344%
# Steady state for 4 took 0.096 seconds with direct, OO changed by 0.0115%
# calculation converged - 0.1, 77.0 (3/20)
# True
# Steady state for 2 took 0.007 seconds with direct, OO changed by 2.0328%
# Steady state for 3 took 0.016 seconds with direct, OO changed by 0.0876%
# Steady state for 4 took 0.094 seconds with direct, OO changed by 0.0042%
# calculation converged - 0.2, 77.0 (4/20)
# True
# Steady state for 2 took 0.006 seconds with direct, OO changed by 171.4256%
# Steady state for 3 took 0.016 seconds with direct, OO changed by 0.0560%
# Steady state for 4 took 0.112 seconds with direct, OO changed by 0.0026%
# calculation converged - 0.6, 77.0 (5/20)
# Steady state for 2 took 0.003 seconds with direct, OO changed by 596.5532%
# Steady state for 3 took 0.021 seconds with direct, OO changed by 0.1022%
# Steady state for 4 took 0.106 seconds with direct, OO changed by 0.0052%
# calculation converged - 1.7, 77.0 (6/20)
# Steady state for 2 took 0.006 seconds with direct, OO changed by 223.5730%
# Steady state for 3 took 0.017 seconds with direct, OO changed by 0.3462%
# Steady state for 4 took 0.110 seconds with direct, OO changed by 0.0239%
# Steady state for 5 took 0.551 seconds with direct, OO changed by 0.0013%
# calculation converged - 4.6, 77.0 (7/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 7.5037%
# Steady state for 3 took 0.032 seconds with direct, OO changed by 1.3219%
# Steady state for 4 took 0.098 seconds with direct, OO changed by 0.1456%
# Steady state for 5 took 0.571 seconds with direct, OO changed by 0.0122%
# Steady state for 6 took 3.226 seconds with direct, OO changed by 0.0008%
# calculation converged - 12.9, 77.0 (8/20)
# Steady state for 2 took 0.007 seconds with direct, OO changed by 15.4351%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 4.0030%
# Steady state for 4 took 0.090 seconds with direct, OO changed by 0.7836%
# Steady state for 5 took 0.491 seconds with direct, OO changed by 0.1202%
# Steady state for 6 took 2.722 seconds with direct, OO changed by 0.0148%
# Steady state for 7 took 12.590 seconds with direct, OO changed by 0.0015%
# calculation converged - 35.9, 77.0 (9/20)
# Steady state for 2 took 0.003 seconds with direct, OO changed by 6460.3817%
# Steady state for 3 took 0.020 seconds with direct, OO changed by 7.2915%
# Steady state for 4 took 0.090 seconds with direct, OO changed by 2.2318%
# Steady state for 5 took 0.537 seconds with direct, OO changed by 0.6717%
# Steady state for 6 took 3.275 seconds with direct, OO changed by 0.1758%
# Steady state for 7 took 13.819 seconds with direct, OO changed by 0.0385%
# Steady state for 8 took 60.696 seconds with direct, OO changed by 0.0072%
# calculation converged - 100.0, 77.0 (10/20)
# True
# Steady state for 2 took 0.002 seconds with direct, OO changed by 14.3333%
# Steady state for 3 took 0.021 seconds with direct, OO changed by 1.3669%
# Steady state for 4 took 0.083 seconds with direct, OO changed by 0.1821%
# calculation converged - 0.0, 300.0 (11/20)
# True
# Steady state for 2 took 0.006 seconds with direct, OO changed by 56.9695%
# Steady state for 3 took 0.018 seconds with direct, OO changed by 0.3795%
# Steady state for 4 took 0.127 seconds with direct, OO changed by 0.0585%
# calculation converged - 0.0, 300.0 (12/20)
# True
# Steady state for 2 took 0.002 seconds with direct, OO changed by 4434.4961%
# Steady state for 3 took 0.015 seconds with direct, OO changed by 0.1260%
# Steady state for 4 took 0.090 seconds with direct, OO changed by 0.0204%
# calculation converged - 0.1, 300.0 (13/20)
# True
# Steady state for 2 took 0.002 seconds with direct, OO changed by 214.9318%
# Steady state for 3 took 0.017 seconds with direct, OO changed by 0.0450%
# Steady state for 4 took 0.096 seconds with direct, OO changed by 0.0077%
# calculation converged - 0.2, 300.0 (14/20)
# True
# Steady state for 2 took 0.002 seconds with direct, OO changed by 48.8421%
# Steady state for 3 took 0.021 seconds with direct, OO changed by 0.0185%
# Steady state for 4 took 0.093 seconds with direct, OO changed by 0.0041%
# calculation converged - 0.6, 300.0 (15/20)
# Steady state for 2 took 0.004 seconds with direct, OO changed by 354.8895%
# Steady state for 3 took 0.031 seconds with direct, OO changed by 0.0130%
# Steady state for 4 took 0.120 seconds with direct, OO changed by 0.0051%
# calculation converged - 1.7, 300.0 (16/20)
# Steady state for 2 took 0.011 seconds with direct, OO changed by 41.4855%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 0.0218%
# Steady state for 4 took 0.114 seconds with direct, OO changed by 0.0119%
# Steady state for 5 took 0.455 seconds with direct, OO changed by 0.0067%
# calculation converged - 4.6, 300.0 (17/20)
# Steady state for 2 took 0.006 seconds with direct, OO changed by 14.8589%
# Steady state for 3 took 0.015 seconds with direct, OO changed by 0.0533%
# Steady state for 4 took 0.117 seconds with direct, OO changed by 0.0313%
# Steady state for 5 took 0.513 seconds with direct, OO changed by 0.0180%
# Steady state for 6 took 2.661 seconds with direct, OO changed by 0.0100%
# calculation converged - 12.9, 300.0 (18/20)
# Steady state for 2 took 0.004 seconds with direct, OO changed by 3.1305%
# Steady state for 3 took 0.017 seconds with direct, OO changed by 0.1323%
# Steady state for 4 took 0.093 seconds with direct, OO changed by 0.0797%
# Steady state for 5 took 0.498 seconds with direct, OO changed by 0.0474%
# Steady state for 6 took 2.656 seconds with direct, OO changed by 0.0273%
# Steady state for 7 took 14.076 seconds with direct, OO changed by 0.0151%
# Steady state for 8 took 69.190 seconds with direct, OO changed by 0.0081%
# calculation converged - 35.9, 300.0 (19/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 4632.1466%
# Steady state for 3 took 0.018 seconds with direct, OO changed by 0.2880%
# Steady state for 4 took 0.115 seconds with direct, OO changed by 0.1779%
# Steady state for 5 took 0.499 seconds with direct, OO changed by 0.1112%
# Steady state for 6 took 2.906 seconds with direct, OO changed by 0.0684%
# Steady state for 7 took 14.645 seconds with direct, OO changed by 0.0412%
# Steady state for 8 took 51.760 seconds with direct, OO changed by 0.0242%
# Steady state for 9 took 258.958 seconds with direct, OO changed by 0.0138%
# Steady state for 5 took 0.473 seconds with direct, OO changed by 0.1240%
# Steady state for 6 took 2.626 seconds with direct, OO changed by 0.0153%
# Steady state for 7 took 8.608 seconds with direct, OO changed by 0.0016%
# calculation converged - 35.9, 77.0 (9/20)
# Steady state for 2 took 0.003 seconds with direct, OO changed by 0.3128%
# Steady state for 3 took 0.013 seconds with direct, OO changed by 7.3884%
# Steady state for 4 took 0.071 seconds with direct, OO changed by 2.2722%
# Steady state for 5 took 0.379 seconds with direct, OO changed by 0.6911%
# Steady state for 6 took 2.359 seconds with direct, OO changed by 0.1831%
# Steady state for 7 took 11.351 seconds with direct, OO changed by 0.0406%
# Steady state for 8 took 40.852 seconds with direct, OO changed by 0.0076%
# calculation converged - 100.0, 77.0 (10/20)
# True
# Steady state for 2 took 0.006 seconds with direct, OO changed by 72.1365%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 1.3669%
# Steady state for 4 took 0.070 seconds with direct, OO changed by 0.1821%
# calculation converged - 0.0, 300.0 (11/20)
# True
# Steady state for 2 took 0.009 seconds with direct, OO changed by 51.2099%
# Steady state for 3 took 0.022 seconds with direct, OO changed by 0.3796%
# Steady state for 4 took 0.074 seconds with direct, OO changed by 0.0586%
# calculation converged - 0.0, 300.0 (12/20)
# True
# Steady state for 2 took 0.004 seconds with direct, OO changed by 39.2455%
# Steady state for 3 took 0.013 seconds with direct, OO changed by 0.1261%
# Steady state for 4 took 0.069 seconds with direct, OO changed by 0.0205%
# calculation converged - 0.1, 300.0 (13/20)
# True
# Steady state for 2 took 0.005 seconds with direct, OO changed by 3666.4777%
# Steady state for 3 took 0.014 seconds with direct, OO changed by 0.0453%
# Steady state for 4 took 0.083 seconds with direct, OO changed by 0.0079%
# calculation converged - 0.2, 300.0 (14/20)
# True
# Steady state for 2 took 0.010 seconds with direct, OO changed by 14.0049%
# Steady state for 3 took 0.014 seconds with direct, OO changed by 0.0192%
# Steady state for 4 took 0.069 seconds with direct, OO changed by 0.0045%
# calculation converged - 0.6, 300.0 (15/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 1963.4427%
# Steady state for 3 took 0.017 seconds with direct, OO changed by 0.0150%
# Steady state for 4 took 0.081 seconds with direct, OO changed by 0.0063%
# calculation converged - 1.7, 300.0 (16/20)
# Steady state for 2 took 0.007 seconds with direct, OO changed by 52.2632%
# Steady state for 3 took 0.018 seconds with direct, OO changed by 0.0273%
# Steady state for 4 took 0.074 seconds with direct, OO changed by 0.0151%
# Steady state for 5 took 0.410 seconds with direct, OO changed by 0.0086%
# calculation converged - 4.6, 300.0 (17/20)
# Steady state for 2 took 0.004 seconds with direct, OO changed by 63.8727%
# Steady state for 3 took 0.014 seconds with direct, OO changed by 0.0679%
# Steady state for 4 took 0.088 seconds with direct, OO changed by 0.0401%
# Steady state for 5 took 0.498 seconds with direct, OO changed by 0.0232%
# Steady state for 6 took 2.228 seconds with direct, OO changed by 0.0128%
# Steady state for 7 took 9.405 seconds with direct, OO changed by 0.0068%
# calculation converged - 12.9, 300.0 (18/20)
# Steady state for 2 took 0.015 seconds with direct, OO changed by 182.2086%
# Steady state for 3 took 0.013 seconds with direct, OO changed by 0.1701%
# Steady state for 4 took 0.098 seconds with direct, OO changed by 0.1031%
# Steady state for 5 took 0.394 seconds with direct, OO changed by 0.0617%
# Steady state for 6 took 2.387 seconds with direct, OO changed by 0.0357%
# Steady state for 7 took 11.694 seconds with direct, OO changed by 0.0200%
# Steady state for 8 took 50.786 seconds with direct, OO changed by 0.0108%
# Steady state for 9 took 182.718 seconds with direct, OO changed by 0.0057%
# calculation converged - 35.9, 300.0 (19/20)
# Steady state for 2 took 0.003 seconds with direct, OO changed by 95.0369%
# Steady state for 3 took 0.014 seconds with direct, OO changed by 0.3762%
# Steady state for 4 took 0.073 seconds with direct, OO changed by 0.2359%
# Steady state for 5 took 0.408 seconds with direct, OO changed by 0.1497%
# Steady state for 6 took 2.389 seconds with direct, OO changed by 0.0937%
# Steady state for 7 took 8.797 seconds with direct, OO changed by 0.0573%
# Steady state for 8 took 38.335 seconds with direct, OO changed by 0.0342%
# Steady state for 9 took 175.854 seconds with direct, OO changed by 0.0199%
# Steady state for 10 took 553.398 seconds with direct, OO changed by 0.0113%
# calculation converged - 100.0, 300.0 (20/20)
# Files saved at DATA/heatmap_TphvAlpha_hetero_add_2

# %% [markdown]
# I don't really get this at all. It means that the model (as it is) does not work for very small couplings and the plots do not interpolate between $\alpha=0$ and $\alpha>0$, even though there is no purely dark state (causing a non-unique steadystate). What this all suggests to me is that I should use the weak-coupling theory to see what the small frequency behaviour is, since these couplings are like millionths of a percent of the site energies.
#
# What does all this mean then?
#
# - Minimal coupling theory for monomer doesn't cause population inversion.
# - Dimer model doesn't have this population inversion then. Excited state populations decrease as a function of $\alpha$, apart from some weird behaviour at very small couplings.
# - This must mean that, for population inversion to occur the ohmicity of the optical spectral density must be at least somewhere between 1 and 3.

# %%
num = 2
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='bright')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='dark')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='sigma_z')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='sigma_x')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='eig_x')
# Out:
# plotting in new style
# /home/henry/anaconda2/envs/qutip/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# saved at PLOTS/heatmap_TphvAlpha_hetero_bright_2.pdf
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_hetero_dark_2.pdf
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_hetero_sigma_z_2.pdf
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_hetero_sigma_x_2.pdf
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_hetero_eig_x_2.pdf

# %%
num = 20
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='DS/GS')

heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='OO')

heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='XO')
heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='OX')

heatmap_plotter(num=num, plot_SD=False, dir_name=dirname,
                print_params=False, observable='eig_x')
"""heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_x_equiv')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_y')"""
# Out:
# plotting in new style
# 0.0 1.0
# saved at PLOTS/heatmap_TphvAlpha_20.pdf
# plotting in new style
# 0.0 1.0
# saved at PLOTS/heatmap_TphvAlpha_20.pdf
# plotting in new style
# 0.0 1.0
# saved at PLOTS/heatmap_TphvAlpha_20.pdf
# plotting in new style
# 0.0 1.0
# saved at PLOTS/heatmap_TphvAlpha_20.pdf
# plotting in new style
# 0.0 1.0
# saved at PLOTS/heatmap_TphvAlpha_20.pdf
# plotting in new style
# 0.0 1.0
# saved at PLOTS/heatmap_TphvAlpha_20.pdf
# plotting in new style
# 0.0 1.0
# saved at PLOTS/heatmap_TphvAlpha_20.pdf
# plotting in new style
# 0.0 1.0
# saved at PLOTS/heatmap_TphvAlpha_20.pdf
# plotting in new style
# 0.0 1.0
# saved at PLOTS/heatmap_TphvAlpha_20.pdf

# %% [markdown]
# # Homodimer

# %%
reload(hm)
w_2 = 1.40*ev_to_inv_cm
bias= 0 #0.01*ev_to_inv_cm
V=0.01*ev_to_inv_cm
alpha = 200./pi
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =4
wc = 100.
w_0 = 200.
site_basis = True
Gamma = (w_0**2)/wc
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=2*N)

x_values = np.logspace(-5, 2.5, 10, endpoint=False)
#x_values[0] = 0
y_values = [77, 300] #np.linspace(77,300, 2)

"""
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name='heatmap_TphvAlpha', save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.001, conv_obs='OO')"""
# Out:
# "\nss_array, info_array = hm.heat_map_calculator(PARAMS,\n                            x_axis_parameters=['alpha_1', 'alpha_2'],\n                            y_axis_parameters=['T_1', 'T_2'],\n                            x_values=x_values,\n                            y_values=y_values,\n                            dir_name='heatmap_TphvAlpha', save_data=True,\n                            persistent=False, method='direct', threshold=1e-12, \n                                              conv_percent_tol=0.001, conv_obs='OO')"

# %%
print (x_values)
# Out:
# [  1.00000000e-05   5.62341325e-05   3.16227766e-04   1.77827941e-03
#    1.00000000e-02   5.62341325e-02   3.16227766e-01   1.77827941e+00
#    1.00000000e+01   5.62341325e+01]

# %%
dirname = 'heatmap_TphvAlpha_v2'
reload(hm)
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname, save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.01, conv_obs='OO', additive=False)
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1', 'alpha_2'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name=dirname+'_add', save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.01, conv_obs='OO', additive=True)
# Out:
# True
# Steady state for 2 took 0.002 seconds with direct, OO changed by 56.1211%
# Steady state for 3 took 0.017 seconds with direct, OO changed by 0.0010%
# calculation converged - 0.0, 77.0 (1/20)
# True
# Steady state for 2 took 0.005 seconds with direct, OO changed by 30.8139%
# Steady state for 3 took 0.045 seconds with direct, OO changed by 0.0010%
# calculation converged - 0.0, 77.0 (2/20)
# True
# Steady state for 2 took 0.010 seconds with direct, OO changed by 216.6069%
# Steady state for 3 took 0.045 seconds with direct, OO changed by 0.0010%
# calculation converged - 0.0, 77.0 (3/20)
# True
# Steady state for 2 took 0.053 seconds with direct, OO changed by 19.8533%
# Steady state for 3 took 0.042 seconds with direct, OO changed by 0.0011%
# calculation converged - 0.0, 77.0 (4/20)
# True
# Steady state for 2 took 0.003 seconds with direct, OO changed by 107.2424%
# Steady state for 3 took 0.034 seconds with direct, OO changed by 0.0019%
# calculation converged - 0.0, 77.0 (5/20)
# True
# Steady state for 2 took 0.004 seconds with direct, OO changed by 4.3871%
# Steady state for 3 took 0.038 seconds with direct, OO changed by 0.0064%
# calculation converged - 0.1, 77.0 (6/20)
# True
# Steady state for 2 took 0.004 seconds with direct, OO changed by 357.0702%
# Steady state for 3 took 0.016 seconds with direct, OO changed by 0.0330%
# Steady state for 4 took 0.114 seconds with direct, OO changed by 0.0013%
# calculation converged - 0.3, 77.0 (7/20)
# Steady state for 2 took 0.006 seconds with direct, OO changed by 23.7084%
# Steady state for 3 took 0.027 seconds with direct, OO changed by 0.2225%
# Steady state for 4 took 0.098 seconds with direct, OO changed by 0.0114%
# Steady state for 5 took 0.522 seconds with direct, OO changed by 0.0005%
# calculation converged - 1.8, 77.0 (8/20)
# Steady state for 2 took 0.013 seconds with direct, OO changed by 55.6087%
# Steady state for 3 took 0.020 seconds with direct, OO changed by 1.9190%
# Steady state for 4 took 0.098 seconds with direct, OO changed by 0.1829%
# Steady state for 5 took 0.504 seconds with direct, OO changed by 0.0135%
# Steady state for 6 took 2.733 seconds with direct, OO changed by 0.0008%
# calculation converged - 10.0, 77.0 (9/20)
# Steady state for 2 took 0.004 seconds with direct, OO changed by 35.3621%
# Steady state for 3 took 0.033 seconds with direct, OO changed by 9.0581%
# Steady state for 4 took 0.114 seconds with direct, OO changed by 2.0998%
# Steady state for 5 took 0.490 seconds with direct, OO changed by 0.4309%
# Steady state for 6 took 2.900 seconds with direct, OO changed by 0.0723%
# Steady state for 7 took 12.810 seconds with direct, OO changed by 0.0101%
# Steady state for 8 took 54.612 seconds with direct, OO changed by 0.0012%
# calculation converged - 56.2, 77.0 (10/20)
# True
# Steady state for 2 took 0.003 seconds with direct, OO changed by 101.1841%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0005%
# calculation converged - 0.0, 300.0 (11/20)
# True
# Steady state for 2 took 0.003 seconds with direct, OO changed by 9.6509%
# Steady state for 3 took 0.018 seconds with direct, OO changed by 0.0005%
# calculation converged - 0.0, 300.0 (12/20)
# True
# Steady state for 2 took 0.005 seconds with direct, OO changed by 113.0597%
# Steady state for 3 took 0.014 seconds with direct, OO changed by 0.0005%
# calculation converged - 0.0, 300.0 (13/20)
# True
# Steady state for 2 took 0.003 seconds with direct, OO changed by 7.9133%
# Steady state for 3 took 0.015 seconds with direct, OO changed by 0.0005%
# calculation converged - 0.0, 300.0 (14/20)
# True
# Steady state for 2 took 0.004 seconds with direct, OO changed by 60.0939%
# Steady state for 3 took 0.017 seconds with direct, OO changed by 0.0006%
# calculation converged - 0.0, 300.0 (15/20)
# True
# Steady state for 2 took 0.006 seconds with direct, OO changed by 117.9335%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0008%
# calculation converged - 0.1, 300.0 (16/20)
# True
# Steady state for 2 took 0.011 seconds with direct, OO changed by 2.8058%
# Steady state for 3 took 0.018 seconds with direct, OO changed by 0.0019%
# calculation converged - 0.3, 300.0 (17/20)
# Steady state for 2 took 0.005 seconds with direct, OO changed by 0.6991%
# Steady state for 3 took 0.017 seconds with direct, OO changed by 0.0083%
# calculation converged - 1.8, 300.0 (18/20)
# Steady state for 2 took 0.004 seconds with direct, OO changed by 253.2202%
# Steady state for 3 took 0.020 seconds with direct, OO changed by 0.0427%
# Steady state for 4 took 0.106 seconds with direct, OO changed by 0.0252%
# Steady state for 5 took 0.485 seconds with direct, OO changed by 0.0145%
# Steady state for 6 took 2.777 seconds with direct, OO changed by 0.0080%
# calculation converged - 10.0, 300.0 (19/20)
# Steady state for 2 took 0.003 seconds with direct, OO changed by 79.5803%
# Steady state for 3 took 0.015 seconds with direct, OO changed by 0.1963%
# Steady state for 4 took 0.122 seconds with direct, OO changed by 0.1197%
# Steady state for 5 took 0.564 seconds with direct, OO changed by 0.0727%
# Steady state for 6 took 2.700 seconds with direct, OO changed by 0.0430%
# Steady state for 7 took 13.206 seconds with direct, OO changed by 0.0246%
# Steady state for 8 took 54.269 seconds with direct, OO changed by 0.0137%
# Steady state for 9 took 167.301 seconds with direct, OO changed by 0.0074%
# calculation converged - 56.2, 300.0 (20/20)
# Files saved at DATA/heatmap_TphvAlpha_v2_2
# True
# Steady state for 2 took 0.002 seconds with direct, OO changed by 57.1081%
# Steady state for 3 took 0.015 seconds with direct, OO changed by 0.0010%
# calculation converged - 0.0, 77.0 (1/20)
# True
# Steady state for 2 took 0.004 seconds with direct, OO changed by 50.0790%
# Steady state for 3 took 0.015 seconds with direct, OO changed by 0.0010%
# calculation converged - 0.0, 77.0 (2/20)
# True
# Steady state for 2 took 0.003 seconds with direct, OO changed by 48.9432%
# Steady state for 3 took 0.025 seconds with direct, OO changed by 0.0010%
# calculation converged - 0.0, 77.0 (3/20)
# True
# Steady state for 2 took 0.005 seconds with direct, OO changed by 51.7344%
# Steady state for 3 took 0.016 seconds with direct, OO changed by 0.0012%
# calculation converged - 0.0, 77.0 (4/20)
# True
# Steady state for 2 took 0.011 seconds with direct, OO changed by 54.8222%
# Steady state for 3 took 0.017 seconds with direct, OO changed by 0.0020%
# calculation converged - 0.0, 77.0 (5/20)
# True
# Steady state for 2 took 0.003 seconds with direct, OO changed by 42.7892%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0066%
# calculation converged - 0.1, 77.0 (6/20)
# True
# Steady state for 2 took 0.003 seconds with direct, OO changed by 0.8403%
# Steady state for 3 took 0.012 seconds with direct, OO changed by 0.0338%
# Steady state for 4 took 0.080 seconds with direct, OO changed by 0.0014%
# calculation converged - 0.3, 77.0 (7/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 64.5899%
# Steady state for 3 took 0.014 seconds with direct, OO changed by 0.2281%
# Steady state for 4 took 0.112 seconds with direct, OO changed by 0.0117%
# Steady state for 5 took 0.447 seconds with direct, OO changed by 0.0005%
# calculation converged - 1.8, 77.0 (8/20)
# Steady state for 2 took 0.020 seconds with direct, OO changed by 137.5737%
# Steady state for 3 took 0.016 seconds with direct, OO changed by 1.9596%
# Steady state for 4 took 0.079 seconds with direct, OO changed by 0.1873%
# Steady state for 5 took 0.382 seconds with direct, OO changed by 0.0139%
# Steady state for 6 took 2.135 seconds with direct, OO changed by 0.0009%
# calculation converged - 10.0, 77.0 (9/20)
# Steady state for 2 took 0.004 seconds with direct, OO changed by 32.6145%
# Steady state for 3 took 0.013 seconds with direct, OO changed by 9.1424%
# Steady state for 4 took 0.084 seconds with direct, OO changed by 2.1263%
# Steady state for 5 took 0.384 seconds with direct, OO changed by 0.4394%
# Steady state for 6 took 1.710 seconds with direct, OO changed by 0.0743%
# Steady state for 7 took 8.737 seconds with direct, OO changed by 0.0105%
# Steady state for 8 took 42.816 seconds with direct, OO changed by 0.0013%
# calculation converged - 56.2, 77.0 (10/20)
# True
# Steady state for 2 took 0.003 seconds with direct, OO changed by 1.3038%
# Steady state for 3 took 0.013 seconds with direct, OO changed by 0.0006%
# calculation converged - 0.0, 300.0 (11/20)
# True
# Steady state for 2 took 0.008 seconds with direct, OO changed by 652.8048%
# Steady state for 3 took 0.016 seconds with direct, OO changed by 0.0006%
# calculation converged - 0.0, 300.0 (12/20)
# True
# Steady state for 2 took 0.009 seconds with direct, OO changed by 179.9913%
# Steady state for 3 took 0.016 seconds with direct, OO changed by 0.0006%
# calculation converged - 0.0, 300.0 (13/20)
# True
# Steady state for 2 took 0.013 seconds with direct, OO changed by 187.0043%
# Steady state for 3 took 0.018 seconds with direct, OO changed by 0.0006%
# calculation converged - 0.0, 300.0 (14/20)
# True
# Steady state for 2 took 0.004 seconds with direct, OO changed by 68.0704%
# Steady state for 3 took 0.020 seconds with direct, OO changed by 0.0006%
# calculation converged - 0.0, 300.0 (15/20)
# True
# Steady state for 2 took 0.002 seconds with direct, OO changed by 22.8745%
# Steady state for 3 took 0.024 seconds with direct, OO changed by 0.0009%
# calculation converged - 0.1, 300.0 (16/20)
# True
# Steady state for 2 took 0.003 seconds with direct, OO changed by 47.9325%
# Steady state for 3 took 0.013 seconds with direct, OO changed by 0.0023%
# calculation converged - 0.3, 300.0 (17/20)
# Steady state for 2 took 0.004 seconds with direct, OO changed by 178139.2954%
# Steady state for 3 took 0.015 seconds with direct, OO changed by 0.0105%
# Steady state for 4 took 0.085 seconds with direct, OO changed by 0.0059%
# calculation converged - 1.8, 300.0 (18/20)
# Steady state for 2 took 0.002 seconds with direct, OO changed by 4568.5680%
# Steady state for 3 took 0.019 seconds with direct, OO changed by 0.0544%
# Steady state for 4 took 0.090 seconds with direct, OO changed by 0.0322%
# Steady state for 5 took 0.404 seconds with direct, OO changed by 0.0185%
# Steady state for 6 took 2.546 seconds with direct, OO changed by 0.0102%
# Steady state for 7 took 10.930 seconds with direct, OO changed by 0.0054%
# calculation converged - 10.0, 300.0 (19/20)
# Steady state for 2 took 0.004 seconds with direct, OO changed by 0.0538%
# Steady state for 3 took 0.012 seconds with direct, OO changed by 0.2528%
# Steady state for 4 took 0.075 seconds with direct, OO changed by 0.1555%
# Steady state for 5 took 0.408 seconds with direct, OO changed by 0.0953%
# Steady state for 6 took 2.207 seconds with direct, OO changed by 0.0568%
# Steady state for 7 took 11.149 seconds with direct, OO changed by 0.0329%
# Steady state for 8 took 37.674 seconds with direct, OO changed by 0.0184%
# Steady state for 9 took 127.273 seconds with direct, OO changed by 0.0100%
# Steady state for 10 took 338.177 seconds with direct, OO changed by 0.0053%
# calculation converged - 56.2, 300.0 (20/20)
# Files saved at DATA/heatmap_TphvAlpha_v2_add_2

# %%
def steadystate_observable(ss_array, PARAMS, observable):
    ss_obs_array = np.zeros(shape=ss_array.shape)
    for y, ss_row in enumerate(ss_array):
        for x, ss_dm in enumerate(ss_row):
            dim, size = ss_dm.dims[0][1::], int(ss_dm.shape[0]/PARAMS['sys_dim'])
            
            nstates, state2idx, idx2state = qt.enr_state_dictionaries(dim, dim[0]+0)
            exc_diff = 0 # function finds the correct exc_diff given some dm
            while nstates != size:
                nstates, state2idx, idx2state = qt.enr_state_dictionaries(dim, dim[0]+exc_diff)
            
            #print exc_diff, dim[0]+exc_diff
            PARAMS.update({'N_1':dim[0], 'N_2':dim[1], 'exc':dim[0]+exc_diff})
            obs_op = make_expectation_operators(PARAMS)[observable]
            #print obs_op.shape, ss_dm.shape
            ss_obs_array[y][x] = (obs_op*ss_dm).tr().real #info_test[y][x]['solution_time']
    return ss_obs_array

# With saved data, we can calculte things differently

def heatmap_loader(num, dir_name="heatmap"):
    # Only loads data of heatmap into memory, does not plot
    directory = 'DATA/'+dir_name+'_'+str(num)
    ss_array = load_obj(directory+'/ss_array')
    PARAMS = load_obj(directory+'/PARAMS')
    info_array = load_obj(directory+'/info_array') # reverse ordering -> lower_N-higher_N
    return ss_array, PARAMS, info_array


heatmap_plotter(num=2, dir_name="heatmap_TphvAlpha_v2", 
                     print_params=False, observable='dark')
heatmap_plotter(num=2, dir_name="heatmap_TphvAlpha_v2", 
                     print_params=False, observable='bright')
heatmap_plotter(num=2, dir_name="heatmap_TphvAlpha_v2", 
                     print_params=False, observable='sigma_x')
# Out:
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_v2_dark_2.pdf
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_v2_bright_2.pdf
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_v2_sigma_x_2.pdf
# plotting in new style
# saved at PLOTS/heatmap_TphvAlpha_v2_sigma_y_2.pdf

# %%
num = 19

heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=True, observable='DS/GS')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='bright')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='dark')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='OO')

heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='XO')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='OX')

heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_x')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_x_equiv')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_y')

heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='sigma_z')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='sigma_x')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='sigma_y')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f2ad277f94b4> in <module>()
#       1 num = 19
#       2
# ----> 3 heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
#       4                 print_params=True, observable='DS/GS')
#       5 heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
#
# NameError: name 'heatmap_plotter' is not defined

# %%
num = 1
dir_name = 'heatmap_TphvAlpha_a19'
hm = heatmap_loader(19, dir_name='heatmap_TphvAlpha')
hm2 = heatmap_loader(1, dir_name='heatmap_TphvAlpha_a19')
print hm[0]
"""heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=True, observable='DS/GS')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='bright')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='dark')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='OO')

heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='XO')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='OX')

heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='eig_x')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='eig_x_equiv')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='eig_y')

heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='sigma_z')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='sigma_x')
heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,
                print_params=False, observable='sigma_y')"""
# Out:
# [[ Quantum object: dims = [[3, 3, 3], [3, 3, 3]], shape = (24, 24), type = oper, isherm = True
# Qobj data =
# [[  3.97317698e-01 +0.00000000e+00j  -3.97718536e-10 +1.98520414e-10j
#    -1.10997048e-13 +1.07041169e-13j  -3.97718527e-10 +1.98520410e-10j
#     9.70829318e-14 -9.68834440e-14j  -7.37822714e-17 -3.93944436e-16j
#    -1.11000242e-13 +1.07044248e-13j  -7.37499595e-17 -3.94005431e-16j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j]
#  [ -3.97718536e-10 -1.98520414e-10j   9.46372703e-03 +0.00000000e+00j
#    -1.35349755e-11 +6.52976934e-12j   1.73173957e-13 +7.79905039e-23j
#    -9.47353936e-12 +4.72513762e-12j   3.31773167e-15 -3.19454302e-15j
#    -7.84855900e-16 +6.03766965e-16j  -2.62094393e-15 +2.50931421e-15j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j]
#  [ -1.10997048e-13 -1.07041169e-13j  -1.35349755e-11 -6.52976934e-12j
#     2.25416914e-04 +0.00000000e+00j  -7.84927933e-16 -6.03786890e-16j
#     5.81242370e-15 -1.72256657e-18j  -2.26030113e-13 +1.10932485e-13j
#    -2.75718387e-17 +2.34967745e-22j  -1.10747249e-15 -3.73955184e-16j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j]
#  [ -3.97718527e-10 -1.98520410e-10j   1.73173957e-13 -7.79905039e-23j
#    -7.84927933e-16 +6.03786890e-16j   9.46372703e-03 +0.00000000e+00j
#    -9.47353941e-12 +4.72513767e-12j  -2.62086859e-15 +2.50924190e-15j
#    -1.35349754e-11 +6.52976923e-12j   3.31773146e-15 -3.19454284e-15j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j]
#  [  9.70829318e-14 +9.68834440e-14j  -9.47353936e-12 -4.72513762e-12j
#     5.81242370e-15 +1.72256657e-18j  -9.47353941e-12 -4.72513767e-12j
#     2.25416914e-04 +0.00000000e+00j  -3.18445993e-13 +1.53995834e-13j
#     5.81242347e-15 +1.72250664e-18j  -3.18445991e-13 +1.53995832e-13j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j]
#  [ -7.37822714e-17 +3.93944436e-16j   3.31773167e-15 +3.19454302e-15j
#    -2.26030113e-13 -1.10932485e-13j  -2.62086859e-15 -2.50924190e-15j
#    -3.18445993e-13 -1.53995834e-13j   5.36921499e-06 +0.00000000e+00j
#    -1.10747402e-15 +3.73955333e-16j   1.21060284e-16 -2.02920441e-24j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j]
#  [
#  [  0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j ...,   1.52960630e-05 +0.00000000e+00j
#     1.53084393e-09 +1.42664427e-12j   1.42015435e-08 +9.15731815e-12j]
#  [  0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j ...,   1.53084393e-09 -1.42664427e-12j
#     3.88043994e-05 +0.00000000e+00j   4.10743750e-06 -7.02860847e-11j]
#  [  0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j ...,   1.42015435e-08 -9.15731815e-12j
#     4.10743750e-06 +7.02860847e-11j   1.50063390e-05 +0.00000000e+00j]]
#   Quantum object: dims = [[3, 10, 10], [3, 10, 10]], shape = (192, 192), type = oper, isherm = True
# Qobj data =
# [[  3.16726078e-01 +0.00000000e+00j  -2.56884429e-07 +1.30225631e-07j
#    -2.56025158e-08 +2.60210557e-08j ...,   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j]
#  [ -2.56884429e-07 -1.30225631e-07j   1.21365205e-01 +0.00000000e+00j
#    -1.46552641e-07 +7.31793159e-08j ...,   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j]
#  [ -2.56025158e-08 -2.60210557e-08j  -1.46552641e-07 -7.31793159e-08j
#     4.65055255e-02 +0.00000000e+00j ...,   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j]
#  ...,
#  [  0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j ...,   2.28604256e-06 +0.00000000e+00j
#     2.67987963e-09 +9.12305053e-13j   1.14883929e-08 +4.16501696e-12j]
#  [  0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j ...,   2.67987963e-09 -9.12305053e-13j
#     5.21826893e-06 +0.00000000e+00j   1.20325894e-06 -2.16100721e-11j]
#  [  0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#     0.00000000e+00 +0.00000000e+00j ...,   1.14883929e-08 -4.16501696e-12j
#     1.20325894e-06 +2.16100721e-11j   2.08863236e-06 +0.00000000e+00j]]]]
# "heatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,\n                print_params=True, observable='DS/GS')\nheatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,\n                print_params=False, observable='bright')\nheatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,\n                print_params=False, observable='dark')\nheatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,\n                print_params=False, observable='OO')\n\nheatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,\n                print_params=False, observable='XO')\nheatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,\n                print_params=False, observable='OX')\n\nheatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,\n                print_params=False, observable='eig_x')\nheatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,\n                print_params=False, observable='eig_x_equiv')\nheatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,\n                print_params=False, observable='eig_y')\n\nheatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,\n                print_params=False, observable='sigma_z')\nheatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,\n                print_params=False, observable='sigma_x')\nheatmap_plotter(num=num, plot_SD=False, dir_name=dir_name,\n                print_params=False, observable='sigma_y')"

# %% [markdown]
# # Asymmetrical phonon environments

# %%
reload(hm)
w_2 = 1.40*ev_to_inv_cm
bias= 0 #0.01*ev_to_inv_cm
V=0.01*ev_to_inv_cm
alpha = 100.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =4
wc = 100.
w_0 = 200.
site_basis = True
Gamma = (w_0**2)/wc
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=True, exc_diff=2*N)

x_values = np.logspace(-5, 2, 10, endpoint=False)
#x_values[0] = 0
y_values = [77, 300] #np.linspace(77,300, 2)


ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['alpha_1'],
                            y_axis_parameters=['T_1', 'T_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name='heatmap_TphvAlpha', save_data=True,
                            persistent=False, method='direct', threshold=1e-12, 
                                              conv_percent_tol=0.001, conv_obs='OO')
# Out:
# True
# Steady state for 2 took 0.004 seconds with direct, OO changed by 26.7462%
# Steady state for 3 took 0.016 seconds with direct, OO changed by 3.8756%
# Steady state for 4 took 0.098 seconds with direct, OO changed by 3.1316%
# calculation converged - 0.0, 77.0 (1/20)
# True
# Steady state for 2 took 0.004 seconds with direct, OO changed by 624.8195%
# Steady state for 3 took 0.016 seconds with direct, OO changed by 3.8756%
# Steady state for 4 took 0.093 seconds with direct, OO changed by 3.1316%
# calculation converged - 0.0, 77.0 (2/20)
# True
# Steady state for 2 took 0.005 seconds with direct, OO changed by 30.9123%
# Steady state for 3 took 0.015 seconds with direct, OO changed by 3.8756%
# Steady state for 4 took 0.086 seconds with direct, OO changed by 3.1316%
# calculation converged - 0.0, 77.0 (3/20)
# True
# Steady state for 2 took 0.003 seconds with direct, OO changed by 2991.8859%
# Steady state for 3 took 0.015 seconds with direct, OO changed by 3.8756%
# Steady state for 4 took 0.097 seconds with direct, OO changed by 3.1316%
# calculation converged - 0.0, 77.0 (4/20)
# True
# Steady state for 2 took 0.003 seconds with direct, OO changed by 37.5878%
# Steady state for 3 took 0.089 seconds with direct, OO changed by 3.8755%
# Steady state for 4 took 0.091 seconds with direct, OO changed by 3.1314%
# calculation converged - 0.0, 77.0 (5/20)
# True
# Steady state for 2 took 0.003 seconds with direct, OO changed by 196.1555%
# Steady state for 3 took 0.017 seconds with direct, OO changed by 3.8749%
# Steady state for 4 took 0.088 seconds with direct, OO changed by 3.1304%
# calculation converged - 0.0, 77.0 (6/20)
# True
# Steady state for 2 took 0.002 seconds with direct, OO changed by 59.2686%
# Steady state for 3 took 0.017 seconds with direct, OO changed by 3.8723%
# Steady state for 4 took 0.089 seconds with direct, OO changed by 3.1255%
# calculation converged - 0.2, 77.0 (7/20)
# True
# Steady state for 2 took 0.004 seconds with direct, OO changed by 18.1652%
# Steady state for 3 took 0.021 seconds with direct, OO changed by 3.8622%
# Steady state for 4 took 0.085 seconds with direct, OO changed by 3.1011%
# calculation converged - 0.8, 77.0 (8/20)
# Steady state for 2 took 0.017 seconds with direct, OO changed by 7.4494%
# Steady state for 3 took 0.015 seconds with direct, OO changed by 3.8751%
# Steady state for 4 took 0.136 seconds with direct, OO changed by 2.9872%
# Steady state for 5 took 0.837 seconds with direct, OO changed by 1.0627%
# Steady state for 6 took 3.626 seconds with direct, OO changed by 0.2875%
# Steady state for 7 took 16.370 seconds with direct, OO changed by 0.0631%
# Steady state for 8 took 96.950 seconds with direct, OO changed by 0.0117%
# Steady state for 9 took 295.219 seconds with direct, OO changed by 0.0019%
# Steady state for 10 took 733.423 seconds with direct, OO changed by 0.0003%
# calculation converged - 4.0, 77.0 (9/20)
# Steady state for 2 took 0.080 seconds with direct, OO changed by 5.2969%
# Steady state for 3 took 0.016 seconds with direct, OO changed by 4.9024%
# Steady state for 4 took 0.091 seconds with direct, OO changed by 2.6237%
# Steady state for 5 took 0.477 seconds with direct, OO changed by 0.9013%
# Steady state for 6 took 2.812 seconds with direct, OO changed by 0.2426%
# Steady state for 7 took 13.487 seconds with direct, OO changed by 0.0532%
# Steady state for 8 took 73.763 seconds with direct, OO changed by 0.0099%
# Steady state for 9 took 272.024 seconds with direct, OO changed by 0.0016%
# Steady state for 6 took 2.685 seconds with direct, OO changed by 0.0414%
# Steady state for 7 took 16.092 seconds with direct, OO changed by 0.0263%
# Steady state for 8 took 76.887 seconds with direct, OO changed by 0.0160%
# Steady state for 9 took 251.041 seconds with direct, OO changed by 0.0094%
# Steady state for 10 took 633.856 seconds with direct, OO changed by 0.0053%
# calculation converged - 4.0, 300.0 (19/20)
# Steady state for 2 took 0.003 seconds with direct, OO changed by 60.9222%
# Steady state for 3 took 0.014 seconds with direct, OO changed by 0.1524%
# Steady state for 4 took 0.095 seconds with direct, OO changed by 0.1065%
# Steady state for 5 took 0.496 seconds with direct, OO changed by 0.0716%
# Steady state for 6 took 2.710 seconds with direct, OO changed by 0.0460%
# Steady state for 7 took 12.515 seconds with direct, OO changed by 0.0284%
# Steady state for 8 took 71.708 seconds with direct, OO changed by 0.0169%
# Steady state for 9 took 236.759 seconds with direct, OO changed by 0.0097%
# Steady state for 10 took 891.748 seconds with direct, OO changed by 0.0054%
# calculation converged - 20.0, 300.0 (20/20)
# Files saved at DATA/heatmap_TphvAlpha_21

# %%
num = 21
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=True, observable='DS/GS')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='bright')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='dark')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='OO')

heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='XO')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='OX')

heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_x')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_x_equiv')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_y')

heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='sigma_z')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='sigma_x')
heatmap_plotter(num=num, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='sigma_y')
# Out:
# plotting in new style
# 1.0 0.0
# kappa_2=177.25, kappa_1=79.17, T_EM=6000.00, bias=0.00, alpha_2=100.00, Gamma_1=400.00, Gamma_2=400.00, shift2=157.08, w0_1=200.00, w0_2=200.00, V=80.66, w_1=11291.70, w_2=11291.70, dipole_2=1.00, dipole_1=1.00, exc=10.00, alpha_EM=0.01, sys_dim=3.00, N_1=10.00, N_2=10.00, mu=1.00, shift1=31.34, w_xx=22583.40, gamma_1=0.32, gamma_2=0.32
# /home/henry/anaconda2/envs/qutip/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# saved at PLOTS/heatmap_TphvAlpha_21.pdf
# plotting in new style
# 1.0 0.0
# saved at PLOTS/heatmap_TphvAlpha_21.pdf
# plotting in new style
# 1.0 0.0
# saved at PLOTS/heatmap_TphvAlpha_21.pdf
# plotting in new style
# 1.0 0.0
# saved at PLOTS/heatmap_TphvAlpha_21.pdf
# plotting in new style
# 1.0 0.0
# saved at PLOTS/heatmap_TphvAlpha_21.pdf
# plotting in new style
# 1.0 0.0
# saved at PLOTS/heatmap_TphvAlpha_21.pdf
# plotting in new style
# 1.0 0.0
# saved at PLOTS/heatmap_TphvAlpha_21.pdf
# plotting in new style
# 1.0 0.0
# saved at PLOTS/heatmap_TphvAlpha_21.pdf
# plotting in new style
# 1.0 0.0
# saved at PLOTS/heatmap_TphvAlpha_21.pdf
# plotting in new style
# 1.0 0.0
# saved at PLOTS/heatmap_TphvAlpha_21.pdf
# plotting in new style
# 1.0 0.0
# saved at PLOTS/heatmap_TphvAlpha_21.pdf
# plotting in new style
# 1.0 0.0
# saved at PLOTS/heatmap_TphvAlpha_21.pdf

# %%
reload(hm)

w_2 = 1.4*ev_to_inv_cm
bias = 0.03*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 0.011*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 200./pi
alpha_bias = 
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =4
wc = 100.
w_0 = sqrt(bias**2 +4*(V**2))
site_basis = True
Gamma = (w_0**2)/wc
PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                      V = V, alpha=alpha,
                      T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                      num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                      silent=False, exc_diff=0)

x_values = np.linspace(100, 600, 6) # When omega_RC = 300, it's on resonance with gap
y_values = np.linspace(30,500, 5)
time.sleep(3)
ss_array, info_array = hm.heat_map_calculator(PARAMS,
                            x_axis_parameters=['w0_1', 'w0_2'],
                            y_axis_parameters=['Gamma_1', 'Gamma_2'],
                            x_values=x_values,
                            y_values=y_values,
                            dir_name='heatmap_GammavOmega', save_data=True,
                            persistent=False, method='direct', threshold=1e-7)

# %%
import weak_phonons as wp
reload(wp)

w_2 = 1.4*ev_to_inv_cm
bias = 0# 0.01*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 0.011*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 10
alpha_bias = 0.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =5
wc = 100.
w_0 = sqrt(bias**2 +4*(V**2))
site_basis = True
Gamma = (w_0**2)/wc
gs_s = []
gs_wc = []
phonons = np.linspace(1e-3,20,20)
for alpha in phonons:
    PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                          V = V, alpha=alpha,
                          T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                          num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                          silent=True, exc_diff=N)
    #print PARAMS.keys()
    #L = wp.L_weak_phonon_SES(PARAMS)

    H, L = wp.get_wc_H_and_L(PARAMS, silent=True, threshold=0.)

    Hs, Ls = get_H_and_L(PARAMS, silent=True, threshold=0.)
    sss = steadystate(Hs[1], [Ls])
    if alpha == 0.:
        print sss.ptrace(0)
    gs_s.append(sss.ptrace(0).diag()[0])
    ss = steadystate(H, [L])
    #print ss.diag()
    gs_wc.append(ss.diag()[0])
plt.plot(phonons, gs_s, label='sc')
plt.plot(phonons, gs_wc, label='wc')
plt.legend()
plt.show()
# Out:
# Weak coupling Liouvillian took 0.01 seconds
# Weak coupling Liouvillian took 3.78 seconds
# Weak coupling Liouvillian took 2.26 seconds
# Weak coupling Liouvillian took 5.77 seconds
# Weak coupling Liouvillian took 3.30 seconds
# Weak coupling Liouvillian took 3.60 seconds
# Weak coupling Liouvillian took 3.16 seconds
# Weak coupling Liouvillian took 3.29 seconds
# Weak coupling Liouvillian took 3.45 seconds
# Weak coupling Liouvillian took 3.71 seconds
# Weak coupling Liouvillian took 3.76 seconds
# Weak coupling Liouvillian took 4.03 seconds
# Weak coupling Liouvillian took 3.94 seconds
# Weak coupling Liouvillian took 5.79 seconds
# Weak coupling Liouvillian took 8.95 seconds
# Weak coupling Liouvillian took 7.19 seconds
# Weak coupling Liouvillian took 4.24 seconds
# Weak coupling Liouvillian took 4.42 seconds
# Weak coupling Liouvillian took 4.46 seconds
# Weak coupling Liouvillian took 4.52 seconds

# %%
import weak_phonons as wp
reload(wp)

w_2 = 1.4*ev_to_inv_cm
bias = 0.01*ev_to_inv_cm #0.0000001*ev_to_inv_cm
V = 0.011*ev_to_inv_cm #0.00001*ev_to_inv_cm
alpha = 10
alpha_bias = 0.
alpha_EM = 5.309e-3 # inv_ps_to_inv_cm *10^-3
N =5
wc = 100.
w_0 = sqrt(bias**2 +4*(V**2))
site_basis = True
Gamma = (w_0**2)/wc
gs_s = []
gs_wc = []
phonons = np.linspace(1e-3,20,20)
for alpha in phonons:
    PARAMS = PARAMS_setup(bias=bias, w_2=w_2, 
                          V = V, alpha=alpha,
                          T_EM=6000., T_ph =300., alpha_EM=alpha_EM, shift=True,
                          num_cpus=4, N=N, Gamma=Gamma, w_0=w_0,
                          silent=True, exc_diff=N)
    #print PARAMS.keys()
    #L = wp.L_weak_phonon_SES(PARAMS)

    H, L = wp.get_wc_H_and_L(PARAMS, silent=True, threshold=0.)

    Hs, Ls = get_H_and_L(PARAMS, silent=True, threshold=0.)
    sss = steadystate(Hs[1], [Ls])
    if alpha == 0.:
        print sss.ptrace(0)
    gs_s.append(sss.ptrace(0).diag()[0])
    ss = steadystate(H, [L])
    #print ss.diag()
    gs_wc.append(ss.diag()[0])
plt.plot(phonons, gs_s, label='sc')
plt.plot(phonons, gs_wc, label='wc')
plt.legend()
plt.show()
# Out:
# Weak coupling Liouvillian took 0.01 seconds
# Weak coupling Liouvillian took 1.45 seconds
# Weak coupling Liouvillian took 2.38 seconds
# Weak coupling Liouvillian took 2.87 seconds
# Weak coupling Liouvillian took 3.06 seconds
# Weak coupling Liouvillian took 7.25 seconds
# Weak coupling Liouvillian took 3.65 seconds
# Weak coupling Liouvillian took 3.96 seconds
# Weak coupling Liouvillian took 5.71 seconds
# Weak coupling Liouvillian took 5.41 seconds
# Weak coupling Liouvillian took 4.32 seconds
# Weak coupling Liouvillian took 5.07 seconds
# Weak coupling Liouvillian took 4.64 seconds
# Weak coupling Liouvillian took 4.58 seconds
# Weak coupling Liouvillian took 5.26 seconds
# Weak coupling Liouvillian took 5.05 seconds
# Weak coupling Liouvillian took 7.55 seconds
# Weak coupling Liouvillian took 6.79 seconds
# Weak coupling Liouvillian took 5.51 seconds
# Weak coupling Liouvillian took 5.53 seconds

# %% [markdown]
# # Plotting T vs $\alpha$

# %%
heatmap_plotter(num=2, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_x')
"""heatmap_plotter(num=2, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_x_equiv')
heatmap_plotter(num=2, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='eig_y')"""
heatmap_plotter(num=2, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='OO')
heatmap_plotter(num=2, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='XO')
heatmap_plotter(num=2, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='OX')
heatmap_plotter(num=2, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='sigma_z')
heatmap_plotter(num=2, plot_SD=False, dir_name="heatmap_TphvAlpha",
                print_params=False, observable='sigma_x')

# %%
def populations_plotter(ss_info_params=False, num=-1, plot_SD=True, dir_name="heatmap", 
                     print_params=False, observable='sigma_x'):
    if num>=0:
        ss_array, PARAMS, info_array = heatmap_loader(num, dir_name=dir_name)
        
    if ss_info_params:
        if num>=0:
            print "Not loading saved data, using data from arguments instead"
        ss_array,info_array, PARAMS = ss_info_params[0], ss_info_params[1], ss_info_params[2]
    info = info_array[0][0]
    #print info
    
    try:
        # To catch an old bug where these were in "info" not in PARAMS
        keys = ['x_values', 'y_values', 'y_axis_parameters', 'x_axis_parameters']
        PARAMS.update(dict((key, info[key]) for key in keys))
    except Exception as err:
        print "plotting in new style"
    if plot_SD:
        plot_UD_SD(PARAMS["Gamma_1"], PARAMS["alpha_1"], PARAMS["w0_1"], eps=8000.)
    #print PARAMS
    ss_array = steadystate_observable(ss_array, PARAMS, observable)
    
    f, axes = plt.subplots(1,1, figsize=(13,6))
    for i, y_val in enumerate(PARAMS['y_values']):
        x_values = PARAMS['x_values']

        axes.plot(x_values, ss_array[i], 
                  label=str(PARAMS['y_axis_parameters'])+"="+str(y_val))
    if print_params:
        print_PARAMS(PARAMS)
    
    plt.xlabel(r', ($cm^{-1}$)'.join(r"\\"+PARAMS['x_axis_parameters']))
    plt.ylabel("Steadystate "+observable)
    #plt.ylabel(', '.join(info['y_axis_parameters']))
    plt.legend()
    plt.grid()
    plot_filename = 'PLOTS/'+dir_name+'_'+str(num)+'.pdf'
    plt.savefig(plot_filename)
    print "saved at {}".format(plot_filename)
    plt.show()

# %%
ss_info_params = [ss_array, info_array, PARAMS]

heatmap_plotter(ss_info_params=ss_info_params, plot_SD=False,
                print_params=False, observable='sigma_x')

# %% [markdown]
# # Comparing SS solution methods (direct, inverse power, eigen)

# %%
from qutip import build_preconditioner

def method_plotter(N_vals, data_dict, info_dict, ax1, ax2, linestyle="solid"):
    lw=1.
    if linestyle == 'dashed':
        lw=1.8
    for i, key in enumerate(data_dict.keys()):
        ax1.plot(N_vals, data_dict[key], label=key, color=colourWheel[i], ls=linestyle, linewidth=lw)
        #print info_dict[key]
        ax2.plot(N_vals, info_dict[key], label=key, color=colourWheel[i], ls=linestyle, linewidth=lw)
    ax1.legend()
    ax2.legend()
    ax1.set_ylabel("Coherence")
    ax2.set_ylabel("Solution time")


def method_comparison(N_i, N_f, plot=False, site_basis=True):
    methods = ['direct']
    data_dict = dict()
    info_dict = dict()
    N_vals = range(N_i, N_f)
    for exc_diff in [0,3,4]:
        for N in N_vals:
            PARAMS.update({'N_1':N, 'N_2':N, 'exc':int(2*N-exc_diff)})
            H, L = get_H_and_L(PARAMS,silent=False, threshold=1e-7, site_basis=site_basis)
            exps = make_expectation_operators(PARAMS, site_basis=site_basis)
            for method in methods:
                try:
                    M=None

                    if "iterative" in method:
                        ti = time.time()
                        M = build_preconditioner(H[1], [L], use_rcm=True, ILU_MILU='smilu_2')
                        print("Building preconditioner took {} seconds".format(time.time()-ti))
                    ss, full_info = calculate_steadystate(H, L, method=method, persistent=True)
                    info = full_info['solution_time']

                    coh = (exps['sigma_x']*ss).tr().real
                    try:
                        data_dict[exc_diff].append(coh)
                        info_dict[exc_diff].append(info)
                    except KeyError:
                        data_dict[exc_diff] = [coh]
                        info_dict[exc_diff] = [info]
                except Exception as err:
                    print( "{} failed due to : {}".format(method, err))
                    try:
                        data_dict[exc_diff].append(None)
                        info_dict[exc_diff].append(None)
                    except KeyError:
                        data_dict[exc_diff] = [None]
                        info_dict[exc_diff] = [None]
    #if plot:
    #    method_plotter(N_vals, data_dict, info_dict)
    return N_vals, data_dict, info_dict

N_vals, data_dict_sb, info_dict_sb = method_comparison(3,7)
#N_vals, data_dict_eb, info_dict_eb = method_comparison(3,7, site_basis=False)

f, (ax1, ax2) = plt.subplots(2,1, figsize=(10,7))
method_plotter(N_vals, data_dict_sb, info_dict_sb, ax1, ax2)
#method_plotter(N_vals, data_dict_eb, info_dict_eb, ax1, ax2, linestyle="dashed")

# %% [markdown]
# # Plotting methods

# %%
heatmap_plotter(2, plot_SD=False, dir_name='heatmap_excvN', 
                     print_params=False, observable='')
